# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
notebook_key = 'captum--grad-cam-insertion-TP-TN-FP-FN'

history = HeatmapEvaluationHistory.load('../../tmp/risei-history', notebook_key)

# %%
history

# %%
history.description()
# Out:
# evaluated heatmaps: 40
# auc
# 	mean:     0.5839257502859158
# 	median:   0.5754448207805727
# 	max:       0.812200815437538
# 	min:     0.35466186943520467
# 	std:     0.10373434104872871

# %%
history.description(percentage=False)
# Out:
# evaluated heatmaps: 40
# auc
# 	mean:     808,414.8371318355
# 	median:   796,673.4312400222
# 	max:    1,124,449.7945308685
# 	min:     491,010.91581583023
# 	std:     143,614.80099623036

# %%
history.plot_auc()

# %%
history.plot_auc(percentage=False)

# %%
history.list_auc(round_auc=False)
# Out:
# idx:   31, auc:  0.35466186943520467
# idx:    9, auc:   0.4119342169543582
# idx:   35, auc:  0.44538523021003246
# idx:   34, auc:   0.4689993705857871
# idx:   28, auc:   0.4735456924860024
# idx:   25, auc:   0.4881165254301944
# idx:    6, auc:  0.48960203934493945
# idx:   32, auc:    0.491701469039572
# idx:   19, auc:  0.49417418020677695
# idx:   24, auc:    0.508225848416098
# idx:   33, auc:   0.5143883407653496
# idx:   17, auc:   0.5149991124866327
# idx:    7, auc:    0.528571585244897
# idx:   10, auc:   0.5371115261174948
# idx:   39, auc:    0.539282552440535
# idx:   30, auc:   0.5396260130617833
# idx:   27, auc:   0.5413508931091868
# idx:   26, auc:    0.563527960834829
# idx:   20, auc:   0.5640988566381179
# idx:   16, auc:   0.5747307947608291
# idx:   38, auc:   0.5761588468003161
# idx:   22, auc:   0.5796439623984215
# idx:   15, auc:   0.5842284021095563
# idx:   23, auc:   0.5920138206506339
# idx:   37, auc:   0.5940300598443512
# idx:   29, auc:   0.5979045679894023
# idx:   11, auc:   0.6128568738912846
# idx:    8, auc:   0.6167966560513152
# idx:    1, auc:   0.6282907338815014
# idx:   12, auc:   0.6359530941837401
# idx:    4, auc:   0.6507448362119044
# idx:   36, auc:   0.6773061823668496
# idx:   21, auc:    0.681557791566231
# idx:   18, auc:   0.7111485951713399
# idx:    2, auc:   0.7320641830254252
# idx:    0, auc:   0.7326971764630464
# idx:    5, auc:   0.7491759374366106
# idx:    3, auc:   0.7686430536528784
# idx:   13, auc:   0.7795803447356641
# idx:   14, auc:    0.812200815437538

# %%
plt.rcParams["figure.figsize"] = (10, 5)

idx = 10

plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 1
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 2
t = 'AD' if not np.argmax(history.arr_y[idx], axis=0) else 'CN'
history.plot_heatmap_z(idx, title_1=f'MRI snímok ({t})', title_2=f'Tepelná mapa pre MRI snímok')
plt.show(history.plot_evaluation(idx))
