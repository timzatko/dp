# %% [markdown]
# # Experiment - Guided Backprop (Captum)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import datetime

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.evaluation import show_metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False

class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path,
    ROOT_DIR,
    split=(0.8, 0.15, 0.05),
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq

model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../../../tmp\logs\20210504-183251
# Wall time: 4 ms

# %% [markdown]
# ## Model

# %%
import torch

from torchsummary import summary

from src.model.torch import Net3DCNN, load_weights

# %%
net = Net3DCNN()

weights = np.load(os.path.join(ROOT_DIR, 'tf-weights.npy'), allow_pickle=True)
weights_bn = np.load(os.path.join(ROOT_DIR, 'tf-weights-bn.npy'), allow_pickle=True)

load_weights(net, weights, weights_bn)

net.eval()
net.cuda()

summary(net.cuda(), (1, 104, 128, 104))
# Out:
# [Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(32, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), ReLU(), MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), ReLU(), MaxPool3d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False), Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), ReLU(), MaxPool3d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False), Flatten(start_dim=1, end_dim=-1), Dropout(p=0.1, inplace=False), Linear(in_features=10240, out_features=256, bias=True), ReLU(), Dropout(p=0.1, inplace=False), Linear(in_features=256, out_features=2, bias=True)]
# copy trainable parameters...
#
#
# --- conv1.weight / conv3d/kernel:0 ---
# (32, 1, 3, 3, 3)
# torch.Size([32, 1, 3, 3, 3])
#
# --- conv1.bias / conv3d/bias:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.weight / batch_normalization/gamma:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.bias / batch_normalization/beta:0 ---
# (32,)
# torch.Size([32])
#
# --- conv2.weight / conv3d_1/kernel:0 ---
# (64, 32, 3, 3, 3)
# torch.Size([64, 32, 3, 3, 3])
#
# --- conv2.bias / conv3d_1/bias:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.weight / batch_normalization_1/gamma:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.bias / batch_normalization_1/beta:0 ---
# (64,)
# torch.Size([64])
#
# --- conv3.weight / conv3d_2/kernel:0 ---
# (128, 64, 3, 3, 3)
# torch.Size([128, 64, 3, 3, 3])
#
# --- conv3.bias / conv3d_2/bias:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.weight / batch_normalization_2/gamma:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.bias / batch_normalization_2/beta:0 ---
# (128,)
# torch.Size([128])
#
# --- fc1.weight / dense_2/kernel:0 ---
# (256, 10240)
# torch.Size([256, 10240])
#
# --- fc1.bias / dense_2/bias:0 ---
# (256,)
# torch.Size([256])
#
# --- fc2.weight / dense/kernel:0 ---
# (2, 256)
# torch.Size([2, 256])
#
# --- fc2.bias / dense/bias:0 ---
# (2,)
# torch.Size([2])
#
#
# copy batch norm parameters...
#
# (32,) (32) (32,) (32)
# (64,) (64) (64,) (64)
# (128,) (128) (128,) (128)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1    [-1, 32, 104, 128, 104]             896
#        BatchNorm3d-2    [-1, 32, 104, 128, 104]              64
#               ReLU-3    [-1, 32, 104, 128, 104]               0
#          MaxPool3d-4       [-1, 32, 52, 64, 52]               0
#             Conv3d-5       [-1, 64, 52, 64, 52]          55,360
#        BatchNorm3d-6       [-1, 64, 52, 64, 52]             128
#               ReLU-7       [-1, 64, 52, 64, 52]               0
#          MaxPool3d-8       [-1, 64, 17, 21, 17]               0
#             Conv3d-9      [-1, 128, 17, 21, 17]         221,312
#       BatchNorm3d-10      [-1, 128, 17, 21, 17]             256
#              ReLU-11      [-1, 128, 17, 21, 17]               0
#         MaxPool3d-12         [-1, 128, 4, 5, 4]               0
#           Flatten-13                [-1, 10240]               0
#           Dropout-14                [-1, 10240]               0
#            Linear-15                  [-1, 256]       2,621,696
#              ReLU-16                  [-1, 256]               0
#           Dropout-17                  [-1, 256]               0
#            Linear-18                    [-1, 2]             514
# ================================================================
# Total params: 2,900,226
# Trainable params: 2,900,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 5.28
# Forward/backward pass size (MB): 1330.73
# Params size (MB): 11.06
# Estimated Total Size (MB): 1347.08
# ----------------------------------------------------------------

# %% [markdown]
# ## Experiments

# %%
NOTEBOOK_KEY = 'captum--guided-grad-cam'
BATCH_SIZE = 24
VERBOSE = 1
LOG = True
SEED = 42

heatmap_evaluation_options = {
    'evaluation_step_size': 1000,
    'evaluation_max_steps': -1,
    'evaluation_batch_size': BATCH_SIZE
}

MAX_CATEGORY_1 = 10
MAX_CATEGORY_2 = 20
# MAX_CATEGORY_1 = 1
# MAX_CATEGORY_2 = 2

# %%
# from skimage.transform import resize

# from src.heatmaps.evaluation import HeatmapEvaluationV2
# from src.data import tf_predict, torch_predict

# from captum.attr import LayerGradCam


# attribution_method = LayerGradCam(net, net.conv3)

# def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
#     target = np.argmax(image_y, axis=0)
#     image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
#     batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
#     attribution = attribution_method.attribute(batch_x, int(target))
#     attribution = attribution.to('cpu').detach().numpy()[0]
#     attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
#     attribution = resize(attribution, input_shape[:-1]) # resize since the size is of the last conv layer
#     return attribution

# predict_fn = torch_predict(net)

# %%
from src.heatmaps.evaluation import HeatmapEvaluationV2
from src.data import tf_predict, torch_predict

from captum.attr import GuidedBackprop, GuidedGradCam


attribution_method = GuidedGradCam(net, net.conv3)
# attribution_method = GuidedBackprop(net)

def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
    target = np.argmax(image_y, axis=0)
    image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
    batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
    attribution = attribution_method.attribute(batch_x, int(target), interpolate_mode='trilinear')
    attribution = attribution.to('cpu').detach().numpy()[0]
    attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
    return attribution

predict_fn = torch_predict(net)

# %% [markdown]
# ### 10TP 10TN 10FP 10FN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=MAX_CATEGORY_1)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 10, tn: 10, fp: 10, fn: 10
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\captum\attr\_core\guided_backprop_deconvnet.py:61: UserWarning: Setting backward hooks on ReLU activations.The hooks will be removed after the attribution is finished
#   "Setting backward hooks on ReLU activations."
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\torch\nn\functional.py:3063: UserWarning: Default upsampling behavior when mode=trilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 1295585.2622389793 (0:01:07s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1268850.1961231232 (0:01:01s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:05
# auc: 1343997.4237680435 (0:01:06s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:09
# auc: 1354993.6604499817 (0:01:09s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1271139.3290162086 (0:01:02s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:10
# auc: 1290345.2850580215 (0:01:11s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1223219.1295027733 (0:01:04s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1023208.5383832455 (0:01:04s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1229349.3085503578 (0:01:04s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:09
# auc: 1007796.436265111 (0:01:09s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:08
# auc: 1198187.5133812428 (0:01:09s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:08
# auc: 1203077.1029889584 (0:01:09s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1318451.6688585281 (0:01:03s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1361221.5725779533 (0:01:08s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1342133.2394480705 (0:01:02s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:08
# auc: 1160411.3333523273 (0:01:09s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1269776.4638066292 (0:01:02s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1262263.0085349083 (0:01:01s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:10
# auc: 1324139.7676467896 (0:01:10s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 886326.1614143848 (0:01:03s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1294220.7916975021 (0:01:01s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1290536.9406342506 (0:01:03s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1195140.85572958 (0:01:04s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1205364.4956946373 (0:01:03s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1259442.8523480892 (0:00:56s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1220593.723654747 (0:01:03s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1119995.1716661453 (0:01:04s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1170268.0799365044 (0:01:04s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1055103.876888752 (0:01:02s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1198558.7989985943 (0:01:04s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1092311.3999664783 (0:01:03s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 897378.9283931255 (0:01:03s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1047215.9983962774 (0:01:03s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1033537.1841490269 (0:01:03s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1197336.3622426987 (0:00:56s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1069141.5615081787 (0:01:02s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1106694.4422125816 (0:00:57s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1061475.1315265894 (0:00:55s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1120487.5415563583 (0:00:55s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1011566.0639256239 (0:00:57s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-insertion-TP-TN-FP-FN.cls
# Wall time: 42min 36s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 404951.6274482012 (0:01:01s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1137461.2414836884 (0:00:57s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 499214.67749774456 (0:01:02s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 513667.37201809883 (0:01:02s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1252316.503584385 (0:00:55s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 313581.0536816716 (0:01:00s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1158718.9061045647 (0:00:57s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1009982.961088419 (0:00:53s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:52
# auc: 986089.2722308636 (0:00:52s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 274993.1725785136 (0:00:59s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 442660.23141145706 (0:00:59s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 449278.7486463785 (0:00:59s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1266689.5275115967 (0:00:54s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 649522.2780704498 (0:00:59s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:52
# auc: 1197429.6229481697 (0:00:52s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 395589.8508951068 (0:00:58s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1187792.2269105911 (0:00:55s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1240275.0511169434 (0:00:54s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 430174.1223484278 (0:01:01s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 953789.324849844 (0:00:56s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1234473.8943576813 (0:00:53s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1113817.733824253 (0:00:55s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1102570.3982114792 (0:00:50s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1132789.3950343132 (0:00:56s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1091861.2708747387 (0:00:55s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 546982.6599657536 (0:01:01s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 374990.45108258724 (0:01:02s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 377239.7561073303 (0:01:01s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 273469.70815211535 (0:01:01s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 499530.160844326 (0:01:00s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 380454.49294149876 (0:01:00s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 289296.01103812456 (0:01:00s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 247592.86933392286 (0:01:01s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 192780.8788791299 (0:01:00s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1042383.9205503464 (0:00:54s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 276329.2604088783 (0:01:00s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 910555.1151931286 (0:00:55s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 957350.7158458233 (0:00:53s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 995225.6780862808 (0:00:54s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 812621.3324815035 (0:00:56s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-deletion-TP-TN-FP-FN.cls
# Wall time: 38min 34s

# %% [markdown]
# ### 20TP 20TN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=MAX_CATEGORY_2, fp_max=0, fn_max=0)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 20, tn: 20, fp: 0, fn: 0
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\captum\attr\_core\guided_backprop_deconvnet.py:61: UserWarning: Setting backward hooks on ReLU activations.The hooks will be removed after the attribution is finished
#   "Setting backward hooks on ReLU activations."
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\torch\nn\functional.py:3063: UserWarning: Default upsampling behavior when mode=trilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:05
# auc: 1295585.2622389793 (0:01:06s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1268850.1961231232 (0:01:02s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1343997.4237680435 (0:01:07s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:08
# auc: 1354993.6604499817 (0:01:08s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 1271139.3290162086 (0:01:00s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 1290345.2850580215 (0:01:06s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 1223219.1295027733 (0:01:00s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1007796.436265111 (0:01:07s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 1198187.5133812428 (0:01:07s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 1203077.1029889584 (0:01:06s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 1318451.6688585281 (0:00:59s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 1361221.5725779533 (0:01:07s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 1342133.2394480705 (0:01:01s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1160411.3333523273 (0:01:08s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1269776.4638066292 (0:01:03s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1262263.0085349083 (0:01:02s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:09
# auc: 1324139.7676467896 (0:01:10s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1342281.1277508736 (0:01:07s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 1291817.1327114105 (0:01:06s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1294220.7916975021 (0:01:02s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1159389.8772001266 (0:01:08s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 1290536.9406342506 (0:01:00s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1325325.8561491966 (0:01:03s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1078342.3170745373 (0:01:02s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1161885.2520883083 (0:01:02s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 1205364.4956946373 (0:00:58s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1108804.9522936344 (0:01:02s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1304032.2879552841 (0:01:03s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1220508.337378502 (0:01:03s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1262560.1249933243 (0:01:03s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 1240154.122710228 (0:00:58s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1326483.1620454788 (0:00:57s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1330600.9852290154 (0:00:54s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1261822.950720787 (0:00:56s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1316421.235382557 (0:00:55s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1286645.045042038 (0:00:57s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 1307006.3931941986 (0:00:57s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 1336885.5979442596 (0:01:01s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1350899.1403579712 (0:00:57s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1272797.370314598 (0:00:55s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-insertion-TP-TN.cls
# Wall time: 41min 45s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 404951.6274482012 (0:01:02s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1137461.2414836884 (0:00:55s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 499214.67749774456 (0:01:04s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 513667.37201809883 (0:01:03s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1252316.503584385 (0:00:56s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 313581.0536816716 (0:01:03s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1158718.9061045647 (0:00:57s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 274993.1725785136 (0:01:02s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 442660.23141145706 (0:01:01s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 449278.7486463785 (0:01:01s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1266689.5275115967 (0:00:56s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 649522.2780704498 (0:01:00s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1197429.6229481697 (0:00:54s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 395589.8508951068 (0:01:00s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1187792.2269105911 (0:00:55s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1240275.0511169434 (0:00:54s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 430174.1223484278 (0:01:02s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:59
# auc: 594284.6013754606 (0:01:00s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 605176.7067909241 (0:01:02s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1234473.8943576813 (0:00:55s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 421558.81234258413 (0:00:51s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:46
# auc: 1113817.733824253 (0:00:46s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 394712.9072919488 (0:00:51s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 309333.4838449955 (0:00:51s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 371762.2693479061 (0:00:51s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:46
# auc: 1132789.3950343132 (0:00:46s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 397821.68781757355 (0:00:51s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 393321.6409608722 (0:00:53s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 414191.47078692913 (0:01:00s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 459890.6007409096 (0:01:01s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1164531.068265438 (0:00:54s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1151329.1117548943 (0:00:53s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 1276891.2433981895 (0:00:51s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1100654.6022891998 (0:00:54s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1181712.4119997025 (0:00:54s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1207186.8197321892 (0:00:57s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1136451.8393278122 (0:00:55s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 967525.1651704311 (0:00:58s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:52
# auc: 1289065.9763216972 (0:00:52s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 1196024.9825119972 (0:00:52s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-deletion-TP-TN.cls
# Wall time: 37min 46s
