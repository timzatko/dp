# %% [markdown]
# # RISEI Parameters Experiment

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import datetime

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.evaluation import show_metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
import tensorflow as tf

# RANDOM_SEED = 250398
# tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False

class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path,
    ROOT_DIR,
    split=(0.8, 0.15, 0.05),
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq

model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = '3d_cnn'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
    'l2_beta': None,
#     'dropout': 0.05,
    'dropout': 0.10,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
    'batch_norm': True,
    'is_complex': False, # a complex layer from the paper, max batch_size is 3
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00010,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 150,
    'patience': 75,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
#     'augmentations': False,
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0., 0.),
        'shear': (0.2, 0.5), # probability, degrees
        'blur': (0.2, 0.85),
        'noise': (0.2, 0.00020)
    },
    'batch_size': 8,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Model

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()

# %%
load_checkpoint(model, DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL, '20210308-175324', 'cp-0058.ckpt')

# %%
# %%time

# just to test of it is ok to clear the session after loading the weigths
tf.keras.backend.clear_session()

show_metrics(model, test_seq, class_names)

# %% [markdown]
# ## Experiments

# %%
import time

from src.heatmaps.evaluation import get_heatmap
from src.risei import RISEI
from src.data import tf_predict

# %%
from src.data import select_from_dataset, numpy_to_sequence

BATCH_SIZE = 24
images_x, images_y, images_y_pred = select_from_dataset(tf_predict(model), test_seq, max_category=5, fn_max=0, fp_max=0)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)

# %%
BATCH_SIZE = 24
VERBOSE = 1
LOG = True
SEED = 42
RISEI_BATCH_SIZE = 480

heatmap_evaluation_options = {
    'evaluation_step_size': 1000,
    'evaluation_max_steps': -1,
    'evaluation_batch_size': BATCH_SIZE
}

# risei config
risei_config = {
    's': 8, 
    'p1': 1/3, 
    'b1': 0.5,
    'b2': 1,
    'b2_value': 0,
    'in_paint': '2d', 
    'in_paint_blending': True, 
    'in_paint_radius': 5,
    'in_paint_2d_to_3d': True,
    'processes': 8,
}

# %%
import itertools

p1_options = [1/4, 1/3, 1/2, 2/3, 3/4]
masks_counts = [8, 16, 32, 64, 128, 256, 512, 1024, 2048]
masks_counts = [1024, 2048]

def map_fn(config, value):
    config.update({ 'p1': value })
    return config

experiments = itertools.product(masks_counts, p1_options)
# m - masks_count
# p1 - p1 in rise config
experiments = [(masks_count, f"m+{masks_count}-p1+{value}", map_fn(risei_config.copy(), value)) 
               for masks_count, value in experiments]

# %%
experiments[0]

# %%
from src.heatmaps.evaluation import HeatmapEvaluationV2
from src.heatmaps.heatmaps import get_heatmap
from src.data import tf_predict, torch_predict
from src.risei import RISEI


def get_heatmap_fn(risei, masks_count):
    def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed, evaluation_idx
        seed = kwargs.get('seed', None)
        evaluation_idx = kwargs.get('evaluation_idx', None)
        log = kwargs.get('log', None)
        heatmap_seed = None if seed is None else seed + evaluation_idx
        print(f"generating heatmap (masks_count={masks_count}; seed={heatmap_seed})")
        heatmap, _, _ = get_heatmap(
            image_x,
            image_y,
            model,
            risei,
            batch_size=BATCH_SIZE,
            masks_count=masks_count,
            risei_batch_size=RISEI_BATCH_SIZE,
            debug=False,
            seed=heatmap_seed,
            log=log
        )
        # print(f'{image_x.shape} {heatmap.shape}')
        return heatmap.reshape(input_shape)
    return heatmap_fn

predict_fn = tf_predict(model)

# %%
def run(experiments):
    for masks_count, history_fname, risei_config in experiments:
        print(f'\n*********\nrunning experiment: {history_fname}\n---------\n')
        risei = RISEI(input_shape[:-1], debug=False, **risei_config)
        heatmap_fn = get_heatmap_fn(risei, masks_count)
        he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)
        
        for method in ['insertion', 'deletion']:
            print('\n')
            history = he.evaluate(method, log=LOG, verbose=VERBOSE, seed=SEED)
            history.save(os.path.join(ROOT_DIR, 'risei-history/hmap-parameters'), f'hmap-parameters--{method}--{history_fname}')
        
        tf.keras.backend.clear_session()

# %%
print(f'number of experiments: {len(experiments) * 2}')

# %%
# %%time

# run(experiments[0:])

# %%
# %%time

run(experiments[40:])

# %%
# %%time

# run(experiments[0:])
# Out:
# *********
# running experiment: m+128-p1+0.25
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:02:08s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 806009.8181664944 (0:04:15s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 701537.1916890144 (0:04:13s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:02:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 756034.3935489655 (0:04:10s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:02:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 806826.0120302439 (0:04:11s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:02:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 1016043.1104302406 (0:04:10s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:02:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 821120.4208806157 (0:04:08s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:02:07s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 694231.8856716156 (0:04:11s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:10
# auc: 449981.63881897926 (0:04:17s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 848343.8092172146 (0:04:10s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:02:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 998043.3775186539 (0:04:11s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+128-p1+0.25.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:02:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:42
# auc: 895795.1929569244 (0:03:48s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:02:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 838816.957950592 (0:03:50s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 794618.5683310032 (0:03:51s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 948640.0758624077 (0:03:51s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:02:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 973208.7516188622 (0:03:48s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:02:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 715708.5686922073 (0:03:50s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:02:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 666361.5927696228 (0:03:49s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:02:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 629420.2787280083 (0:03:48s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 829695.6417262554 (0:03:50s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:02:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 866018.4772610664 (0:03:51s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+128-p1+0.25.cls
#
# *********
# running experiment: m+128-p1+0.3333333333333333
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 824365.12196064 (0:04:03s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:58s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 746114.2421364784 (0:04:05s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 762748.8000690937 (0:03:59s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 811515.4774487019 (0:04:00s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:56s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 987044.7553992271 (0:04:04s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 768669.1401004791 (0:04:03s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:58s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 789215.6466245651 (0:04:03s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:56s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 514536.51943057775 (0:04:02s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 1002040.4629707336 (0:04:02s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:56s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 962561.1864030361 (0:04:00s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+128-p1+0.3333333333333333.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:42
# auc: 893895.2086567879 (0:03:38s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:56s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 764948.9880204201 (0:03:41s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:56s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 838956.3507735729 (0:03:41s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 985945.8688795567 (0:03:40s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 950867.8500950336 (0:03:39s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 720297.0500662923 (0:03:39s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 668392.7605748177 (0:03:40s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:52s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 648244.4584071636 (0:03:37s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 767385.8805000782 (0:03:40s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:59s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 803222.4858999252 (0:03:43s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+128-p1+0.3333333333333333.cls
#
# *********
# running experiment: m+128-p1+0.5
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:36s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:02
# auc: 589159.3890488148 (0:03:39s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 643800.1400530338 (0:03:43s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 841081.8871557713 (0:03:40s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 886864.8464381695 (0:03:40s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 856068.4796571732 (0:03:43s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:36s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 718125.7209777832 (0:03:42s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:37s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 744392.1900689602 (0:03:42s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:37s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 456288.4253077209 (0:03:42s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:37s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 970617.375522852 (0:03:42s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:37s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 986928.0475378036 (0:03:43s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+128-p1+0.5.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 1047834.4351351261 (0:03:21s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:38s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 772131.7451298237 (0:03:23s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:36s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 908118.2603538036 (0:03:21s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 869459.1346383095 (0:03:20s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:36s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 915761.4426016808 (0:03:21s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 717267.1950906515 (0:03:20s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 775396.9827890396 (0:03:20s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:35s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 852852.3674607277 (0:03:20s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:36s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 849301.6013503075 (0:03:22s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:36s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 887944.96768713 (0:03:21s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+128-p1+0.5.cls
#
# *********
# running experiment: m+128-p1+0.6666666666666666
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:15s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 777964.4735008478 (0:03:20s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 688244.0015971661 (0:03:21s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:11s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 646754.959911108 (0:03:19s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:12s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 806409.1888964176 (0:03:17s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 828830.8981359005 (0:03:18s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:15s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 625998.466938734 (0:03:20s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:15s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 691900.8631855249 (0:03:21s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 383038.49881887436 (0:03:21s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 1092576.565682888 (0:03:18s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 961820.6748068333 (0:03:18s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+128-p1+0.6666666666666666.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 1059898.2807695866 (0:02:57s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 759979.5845746994 (0:02:58s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 1016860.9279096127 (0:02:58s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 936974.6807813644 (0:02:58s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 936395.0143158436 (0:02:59s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 818584.2321813107 (0:02:59s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:15s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 715974.6456742287 (0:03:00s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 873851.9790172577 (0:02:57s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:11s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 790103.139847517 (0:02:56s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:13s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 1043822.0196962357 (0:02:58s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+128-p1+0.6666666666666666.cls
#
# *********
# running experiment: m+128-p1+0.75
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:02
# auc: 833341.0489857197 (0:03:05s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 680734.1832816601 (0:03:06s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 591716.4523005486 (0:03:06s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 707497.1896260977 (0:03:11s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 902459.424585104 (0:03:05s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 619179.4710755348 (0:03:09s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:01s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 640270.7869112492 (0:03:06s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 364241.7344003916 (0:03:06s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 1001598.3659923077 (0:03:08s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 1018661.9182825089 (0:03:10s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+128-p1+0.75.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=42)
# ...finished in 0:01:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 1066426.2722730637 (0:02:47s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=43)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 745201.6078531742 (0:02:47s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=44)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 1052458.4232866764 (0:02:47s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=45)
# ...finished in 0:01:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 811015.1951014996 (0:02:48s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=46)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 962419.5096492767 (0:02:47s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=47)
# ...finished in 0:01:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 734915.3674244881 (0:02:47s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=48)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 591792.4847900867 (0:02:47s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=49)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 753555.9858083725 (0:02:46s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=50)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 754902.2604525089 (0:02:46s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=128; seed=51)
# ...finished in 0:01:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 929705.2299082279 (0:02:47s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+128-p1+0.75.cls
#
# *********
# running experiment: m+256-p1+0.25
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:04:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 730428.5448938608 (0:06:10s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:04:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 697995.2232539654 (0:06:14s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:04:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 611476.114064455 (0:06:05s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:04:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 780492.508456111 (0:06:07s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:04:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 889892.4489021301 (0:06:12s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 628710.8671963215 (0:06:12s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 795462.7452194691 (0:06:09s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:04:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 476076.07282698154 (0:06:10s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:04:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 750661.9729995728 (0:06:09s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:04:02s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:07
# auc: 1092927.019417286 (0:06:10s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+256-p1+0.25.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:04:01s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 943012.2992694378 (0:05:45s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 842088.2860422134 (0:05:49s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:04:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 810188.5071098804 (0:05:44s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:04:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 838064.4077956676 (0:05:45s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 1047886.1111402512 (0:05:49s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:04:01s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 977370.9564208984 (0:05:46s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 496572.2821354866 (0:05:48s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:03:58s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 859789.1381978989 (0:05:42s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:46
# auc: 878358.4939837456 (0:05:50s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:04:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 1040154.0452241898 (0:05:47s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+256-p1+0.25.cls
#
# *********
# running experiment: m+256-p1+0.3333333333333333
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:03:40s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 572351.7341017723 (0:05:45s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:03:42s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 615619.1343963146 (0:05:48s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:03:47s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 608809.7499161959 (0:05:53s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:03:45s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 782860.91786623 (0:05:53s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:03:44s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 915622.1850514412 (0:05:52s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:03:43s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 692806.2656223774 (0:05:47s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:03:44s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 767309.0444803238 (0:05:49s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:03:43s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 528250.2511441708 (0:05:49s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:03:43s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 765990.7627403736 (0:05:49s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:03:44s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 1078419.9425280094 (0:05:50s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+256-p1+0.3333333333333333.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:03:47s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 968424.554258585 (0:05:32s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:03:43s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 771377.8193891048 (0:05:28s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:03:39s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 821620.3837096691 (0:05:24s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:03:42s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 918917.4969643354 (0:05:27s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:03:42s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 1071915.1811599731 (0:05:27s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:03:46s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 966312.1367394924 (0:05:32s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:03:45s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 558446.9058811665 (0:05:30s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:03:41s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 824197.9638636112 (0:05:26s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:03:45s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:48
# auc: 855113.3262217045 (0:05:33s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:03:44s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 1020656.399846077 (0:05:29s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+256-p1+0.3333333333333333.cls
#
# *********
# running experiment: m+256-p1+0.5
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:03:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:04
# auc: 524777.2318720818 (0:05:08s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:03:07s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 642578.9549797773 (0:05:13s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:03:08s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:08
# auc: 605863.4100705385 (0:05:17s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:03:01s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 762722.0522761345 (0:05:07s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:03:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 860749.0479648113 (0:05:11s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:03:07s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:09
# auc: 602385.3978514671 (0:05:16s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:03:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 750288.6320352554 (0:05:11s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:03:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 461994.9678555131 (0:05:11s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:03:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:05
# auc: 721762.8422379494 (0:05:11s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:03:07s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:06
# auc: 1039672.3991632462 (0:05:13s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+256-p1+0.5.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:03:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:43
# auc: 1065760.6765925884 (0:04:47s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:03:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 659646.6807126999 (0:04:50s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:03:06s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 892994.8274046183 (0:04:51s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:03:05s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 865239.4380271435 (0:04:51s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:03:01s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:46
# auc: 935122.8141784668 (0:04:47s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:03:01s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 927428.4431785345 (0:04:46s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:03:07s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 724554.1201531887 (0:04:52s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:03:03s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:44
# auc: 912328.3409774303 (0:04:47s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:03:04s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:45
# auc: 830576.7646729946 (0:04:49s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:02:22s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:41
# auc: 978054.8971891403 (0:03:04s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+256-p1+0.5.cls
#
# *********
# running experiment: m+256-p1+0.6666666666666666
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:01:43s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 768416.1478281021 (0:02:33s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:01:34s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:42
# auc: 693262.1288597584 (0:03:16s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:02:18s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:02
# auc: 516627.812191844 (0:04:21s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:02:19s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 732583.2661539316 (0:04:19s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:02:18s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:57
# auc: 748419.2916154861 (0:04:15s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:02:15s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 579303.9927184582 (0:04:14s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:02:18s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:56
# auc: 728745.9313571453 (0:04:14s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:02:14s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:56
# auc: 373033.1095904112 (0:04:11s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:02:20s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 724385.6656253338 (0:04:20s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:02:21s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:00
# auc: 853860.6407642365 (0:04:21s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+256-p1+0.6666666666666666.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:02:17s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:38
# auc: 967463.4765386581 (0:03:55s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:02:16s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 828633.0766379833 (0:03:55s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:02:17s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:40
# auc: 1021784.2012345791 (0:03:57s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:02:19s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 963271.2224125862 (0:03:58s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:02:20s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:40
# auc: 937476.3368368149 (0:04:00s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:02:20s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 893027.5153070688 (0:04:00s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:02:18s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:38
# auc: 658897.5425958633 (0:03:57s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:02:16s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 821895.2918052673 (0:03:56s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:02:18s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:38
# auc: 842926.4485836029 (0:03:57s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:02:21s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 1001573.6393332481 (0:04:00s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+256-p1+0.6666666666666666.cls
#
# *********
# running experiment: m+256-p1+0.75
# ---------
#
#
#
# sequence len: 10, method: insertion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:58
# auc: 778292.6286160946 (0:03:55s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:01:58s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:02
# auc: 722553.8321137428 (0:04:00s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:03
# auc: 505605.0881296396 (0:04:00s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:02
# auc: 685444.7475075722 (0:03:58s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:01:54s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 768719.4473147392 (0:03:54s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:01:56s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 580891.3361430168 (0:03:55s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:01:58s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 834914.2896533012 (0:03:58s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:59
# auc: 426070.26191055775 (0:03:54s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:01:53s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:03
# auc: 754559.1822862625 (0:03:57s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:02:02
# auc: 971348.5023975372 (0:03:58s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--insertion--m+256-p1+0.75.cls
#
#
# sequence len: 10, method: deletion
# evaluation 1/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=42)
# ...finished in 0:01:54s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:37
# auc: 941353.38139534 (0:03:32s)
#
# evaluation 2/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=43)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 928605.9680879116 (0:03:34s)
#
# evaluation 3/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=44)
# ...finished in 0:01:54s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 1011146.7838585377 (0:03:33s)
#
# evaluation 4/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=45)
# ...finished in 0:01:58s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 883008.0118179321 (0:03:38s)
#
# evaluation 5/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=46)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 1002371.6050982475 (0:03:37s)
#
# evaluation 6/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=47)
# ...finished in 0:01:53s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 874809.0052306652 (0:03:32s)
#
# evaluation 7/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=48)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 644972.5357443094 (0:03:34s)
#
# evaluation 8/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=49)
# ...finished in 0:01:54s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:38
# auc: 858667.5039976835 (0:03:32s)
#
# evaluation 9/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=50)
# ...finished in 0:01:55s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 764535.1339876652 (0:03:35s)
#
# evaluation 10/10
# generating heatmap...
# generating heatmap (masks_count=256; seed=51)
# ...finished in 0:01:57s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:39
# auc: 930894.0576612949 (0:03:36s)
#
# saved to: ../../../../tmp\risei-history/hmap-parameters\hmap-parameters--deletion--m+256-p1+0.75.cls
# Wall time: 13h 57min 43s

# %%
# %%time

run(experiments[30:40])
