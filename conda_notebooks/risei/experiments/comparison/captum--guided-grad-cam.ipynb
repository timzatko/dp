# %% [markdown]
# # Experiment - Guided Backprop (Captum)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import datetime

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.evaluation import show_metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False

class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path,
    ROOT_DIR,
    split=(0.8, 0.15, 0.05),
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq

model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../../../tmp\logs\20210409-233815
# Wall time: 0 ns

# %% [markdown]
# ## Model

# %%
import torch

from torchsummary import summary

from src.model.torch import Net3DCNN, load_weights

# %%
net = Net3DCNN()

weights = np.load(os.path.join(ROOT_DIR, 'tf-weights.npy'), allow_pickle=True)
weights_bn = np.load(os.path.join(ROOT_DIR, 'tf-weights-bn.npy'), allow_pickle=True)

load_weights(net, weights, weights_bn)

net.eval()
net.cuda()

summary(net.cuda(), (1, 104, 128, 104))
# Out:
# [Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(32, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False), Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False), Flatten(start_dim=1, end_dim=-1), Dropout(p=0.1, inplace=False), Linear(in_features=10240, out_features=256, bias=True), Dropout(p=0.1, inplace=False), Linear(in_features=256, out_features=2, bias=True)]
# copy trainable parameters...
#
#
# --- conv1.weight / conv3d/kernel:0 ---
# (32, 1, 3, 3, 3)
# torch.Size([32, 1, 3, 3, 3])
#
# --- conv1.bias / conv3d/bias:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.weight / batch_normalization/gamma:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.bias / batch_normalization/beta:0 ---
# (32,)
# torch.Size([32])
#
# --- conv2.weight / conv3d_1/kernel:0 ---
# (64, 32, 3, 3, 3)
# torch.Size([64, 32, 3, 3, 3])
#
# --- conv2.bias / conv3d_1/bias:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.weight / batch_normalization_1/gamma:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.bias / batch_normalization_1/beta:0 ---
# (64,)
# torch.Size([64])
#
# --- conv3.weight / conv3d_2/kernel:0 ---
# (128, 64, 3, 3, 3)
# torch.Size([128, 64, 3, 3, 3])
#
# --- conv3.bias / conv3d_2/bias:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.weight / batch_normalization_2/gamma:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.bias / batch_normalization_2/beta:0 ---
# (128,)
# torch.Size([128])
#
# --- fc1.weight / dense_2/kernel:0 ---
# (256, 10240)
# torch.Size([256, 10240])
#
# --- fc1.bias / dense_2/bias:0 ---
# (256,)
# torch.Size([256])
#
# --- fc2.weight / dense/kernel:0 ---
# (2, 256)
# torch.Size([2, 256])
#
# --- fc2.bias / dense/bias:0 ---
# (2,)
# torch.Size([2])
#
#
# copy batch norm parameters...
#
# (32,) (32) (32,) (32)
# (64,) (64) (64,) (64)
# (128,) (128) (128,) (128)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1    [-1, 32, 104, 128, 104]             896
#        BatchNorm3d-2    [-1, 32, 104, 128, 104]              64
#          MaxPool3d-3       [-1, 32, 52, 64, 52]               0
#             Conv3d-4       [-1, 64, 52, 64, 52]          55,360
#        BatchNorm3d-5       [-1, 64, 52, 64, 52]             128
#          MaxPool3d-6       [-1, 64, 17, 21, 17]               0
#             Conv3d-7      [-1, 128, 17, 21, 17]         221,312
#        BatchNorm3d-8      [-1, 128, 17, 21, 17]             256
#          MaxPool3d-9         [-1, 128, 4, 5, 4]               0
#           Flatten-10                [-1, 10240]               0
#           Dropout-11                [-1, 10240]               0
#            Linear-12                  [-1, 256]       2,621,696
#           Dropout-13                  [-1, 256]               0
#            Linear-14                    [-1, 2]             514
# ================================================================
# Total params: 2,900,226
# Trainable params: 2,900,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 5.28
# Forward/backward pass size (MB): 902.31
# Params size (MB): 11.06
# Estimated Total Size (MB): 918.65
# ----------------------------------------------------------------

# %% [markdown]
# ## Experiments

# %%
NOTEBOOK_KEY = 'captum--guided-grad-cam'
BATCH_SIZE = 24
VERBOSE = 1
LOG = True
SEED = 42

heatmap_evaluation_options = {
    'evaluation_step_size': 1000,
    'evaluation_max_steps': -1,
    'evaluation_batch_size': BATCH_SIZE
}

MAX_CATEGORY_1 = 10
MAX_CATEGORY_2 = 20
# MAX_CATEGORY_1 = 1
# MAX_CATEGORY_2 = 2

# %%
# from skimage.transform import resize

# from src.heatmaps.evaluation import HeatmapEvaluationV2
# from src.data import tf_predict, torch_predict

# from captum.attr import LayerGradCam


# attribution_method = LayerGradCam(net, net.conv3)

# def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
#     target = np.argmax(image_y, axis=0)
#     image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
#     batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
#     attribution = attribution_method.attribute(batch_x, int(target))
#     attribution = attribution.to('cpu').detach().numpy()[0]
#     attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
#     attribution = resize(attribution, input_shape[:-1]) # resize since the size is of the last conv layer
#     return attribution

# predict_fn = torch_predict(net)

# %%
from src.heatmaps.evaluation import HeatmapEvaluationV2
from src.data import tf_predict, torch_predict

from captum.attr import GuidedBackprop, GuidedGradCam


attribution_method = GuidedGradCam(net, net.conv3)
# attribution_method = GuidedBackprop(net)

def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
    target = np.argmax(image_y, axis=0)
    image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
    batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
    attribution = attribution_method.attribute(batch_x, int(target))
    attribution = attribution.to('cpu').detach().numpy()[0]
    attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
    return attribution

predict_fn = torch_predict(net)

# %% [markdown]
# ### 10TP 10TN 10FP 10FN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=MAX_CATEGORY_1)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 10, tn: 10, fp: 10, fn: 10
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\captum\attr\_core\guided_backprop_deconvnet.py:61: UserWarning: Setting backward hooks on ReLU activations.The hooks will be removed after the attribution is finished
#   "Setting backward hooks on ReLU activations."
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 843620.5043494701 (0:00:57s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1143013.7212872505 (0:00:49s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 1014613.7747168541 (0:00:56s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1031212.8122746944 (0:00:57s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1262310.2798461914 (0:00:50s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 877719.1976308823 (0:00:58s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1186789.3314957619 (0:00:50s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 983550.9051978588 (0:00:50s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1130604.4369339943 (0:00:49s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 497437.97597289085 (0:00:57s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 747732.0929765701 (0:00:57s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 716952.005520463 (0:00:57s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1293859.586238861 (0:00:49s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 1170521.6863751411 (0:00:58s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1298390.868127346 (0:00:49s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 577233.5115373135 (0:00:57s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1214040.5687689781 (0:00:49s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1256054.9609661102 (0:00:49s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 952238.0355298519 (0:00:57s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 977341.383844614 (0:00:49s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1268614.2737269402 (0:00:49s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1288954.9043178558 (0:00:49s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1156842.0308232307 (0:00:49s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1139507.263660431 (0:00:50s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1160605.7226359844 (0:00:49s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 711189.3107146025 (0:00:56s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 588763.1877213717 (0:00:57s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 685363.9205098152 (0:00:57s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 488878.81603837013 (0:00:57s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 759333.144724369 (0:00:57s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 582558.7612241507 (0:00:57s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 445207.80269801617 (0:00:58s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 380904.2776674032 (0:00:57s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 432668.4825569391 (0:00:58s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1079437.271475792 (0:00:48s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 409160.05889326334 (0:00:57s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1177815.8967494965 (0:00:49s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:47
# auc: 1232097.6821631193 (0:00:48s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1154784.6772372723 (0:00:48s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1020663.8620048761 (0:00:48s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-insertion-TP-TN-FP-FN.cls
# Wall time: 35min 43s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 289856.3670963049 (0:00:50s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1132829.3912410736 (0:00:43s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 429301.7886132002 (0:00:50s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 530186.9071573019 (0:00:50s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1217483.9546084404 (0:00:43s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 263726.83899104595 (0:00:50s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1184035.5995893478 (0:00:43s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 867413.9486551285 (0:00:43s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1003232.2282493114 (0:00:42s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 161427.2238947451 (0:00:50s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 305249.9621063471 (0:00:51s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 331848.508939147 (0:00:50s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1270690.466582775 (0:00:43s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 481079.1837349534 (0:00:51s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1240379.9485564232 (0:00:43s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 262188.02707642317 (0:00:51s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1226343.5485959053 (0:00:43s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1191138.3011937141 (0:00:43s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 313597.07836806774 (0:00:51s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:43
# auc: 1082197.0905065536 (0:00:43s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1245965.531885624 (0:00:43s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1082524.6141552925 (0:00:43s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1115368.5509860516 (0:00:42s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1094326.4076709747 (0:00:43s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1096398.6131250858 (0:00:42s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 402015.31264185905 (0:00:50s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 269679.8043176532 (0:00:51s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 259682.1505650878 (0:00:51s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 154176.5971519053 (0:00:51s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 326113.7748211622 (0:00:51s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 293608.18476974964 (0:00:51s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 187709.29903537035 (0:00:51s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 148357.80503600836 (0:00:51s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 140818.18141788244 (0:00:51s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1048570.4927742481 (0:00:42s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 151165.5155979097 (0:00:50s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1012376.6860365868 (0:00:43s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:41
# auc: 1075416.6425019503 (0:00:41s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:41
# auc: 970217.4144238234 (0:00:42s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 705714.1768336296 (0:00:42s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-deletion-TP-TN-FP-FN.cls
# Wall time: 31min 23s

# %% [markdown]
# ### 20TP 20TN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=MAX_CATEGORY_2, fp_max=0, fn_max=0)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 20, tn: 20, fp: 0, fn: 0
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\captum\attr\_core\guided_backprop_deconvnet.py:61: UserWarning: Setting backward hooks on ReLU activations.The hooks will be removed after the attribution is finished
#   "Setting backward hooks on ReLU activations."
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 843620.5043494701 (0:00:58s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1143013.7212872505 (0:00:50s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 1014613.7747168541 (0:00:57s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 1031212.8122746944 (0:00:58s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1262310.2798461914 (0:00:49s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 877719.1976308823 (0:00:58s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1186789.3314957619 (0:00:49s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 497437.97597289085 (0:00:57s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 747732.0929765701 (0:00:58s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 716952.005520463 (0:00:58s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1293859.586238861 (0:00:50s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 1170521.6863751411 (0:00:59s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1298390.868127346 (0:00:49s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 577233.5115373135 (0:00:58s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 1214040.5687689781 (0:00:50s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1256054.9609661102 (0:00:49s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 952238.0355298519 (0:00:59s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 1055321.7911720276 (0:00:58s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 936480.7412028313 (0:00:57s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1268614.2737269402 (0:00:50s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 662653.3623337746 (0:00:58s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1288954.9043178558 (0:00:50s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 889291.9738292694 (0:00:57s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 612424.5610833168 (0:00:58s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 744165.5810773373 (0:00:58s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1139507.263660431 (0:00:50s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 642663.5898798704 (0:00:57s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 856749.7626245022 (0:00:58s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:58
# auc: 764350.4841029644 (0:00:59s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 867251.9711256027 (0:00:58s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 1129345.2417254448 (0:00:50s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1302884.8190307617 (0:00:50s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:47
# auc: 1301318.3948993683 (0:00:48s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1191948.1109976768 (0:00:49s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:48
# auc: 1273547.442138195 (0:00:48s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1241532.2360992432 (0:00:49s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1273777.447462082 (0:00:50s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 1218901.1806249619 (0:00:51s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 1315667.828977108 (0:00:49s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:47
# auc: 1201197.4212527275 (0:00:48s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-insertion-TP-TN.cls
# Wall time: 36min 8s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 289856.3670963049 (0:00:50s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1132829.3912410736 (0:00:43s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 429301.7886132002 (0:00:50s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 530186.9071573019 (0:00:50s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1217483.9546084404 (0:00:43s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 263726.83899104595 (0:00:51s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1184035.5995893478 (0:00:43s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 161427.2238947451 (0:00:51s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 305249.9621063471 (0:00:51s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 331848.508939147 (0:00:51s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:43
# auc: 1270690.466582775 (0:00:43s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:51
# auc: 481079.1837349534 (0:00:51s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1240379.9485564232 (0:00:43s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 262188.02707642317 (0:00:51s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1226343.5485959053 (0:00:43s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:41
# auc: 1191138.3011937141 (0:00:42s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 313597.07836806774 (0:00:51s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 549014.3971145153 (0:00:50s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 606849.6104627848 (0:00:50s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1245965.531885624 (0:00:43s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 351138.3810043335 (0:00:50s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:43
# auc: 1082524.6141552925 (0:00:43s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:49
# auc: 428331.4683586359 (0:00:50s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 213980.26222735643 (0:00:51s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 321210.93690395355 (0:00:51s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:43
# auc: 1094326.4076709747 (0:00:43s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 283411.9584187865 (0:00:50s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 266000.29696151614 (0:00:51s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 408803.0279427767 (0:00:51s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:50
# auc: 431962.11967617273 (0:00:51s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:43
# auc: 1149627.4658739567 (0:00:43s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1181818.4477686882 (0:00:42s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:41
# auc: 1246065.6123161316 (0:00:41s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1136485.601902008 (0:00:42s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:41
# auc: 1209555.4885864258 (0:00:41s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1139514.8459076881 (0:00:43s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1198047.7857589722 (0:00:42s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:44
# auc: 845855.6416332722 (0:00:44s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:42
# auc: 1272627.0023584366 (0:00:42s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:40
# auc: 1176000.7578134537 (0:00:41s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam-deletion-TP-TN.cls
# Wall time: 31min 25s
