# %% [markdown]
# # Experiment - Guided Backprop (Captum)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import datetime

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.evaluation import show_metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False

class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path,
    ROOT_DIR,
    split=(0.8, 0.15, 0.05),
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq

model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../../../tmp\logs\20210415-115544
# Wall time: 0 ns

# %% [markdown]
# ## Model

# %%
import torch

from torchsummary import summary

from src.model.torch import Net3DCNN, load_weights

# %%
net = Net3DCNN()

weights = np.load(os.path.join(ROOT_DIR, 'tf-weights.npy'), allow_pickle=True)
weights_bn = np.load(os.path.join(ROOT_DIR, 'tf-weights-bn.npy'), allow_pickle=True)

load_weights(net, weights, weights_bn)

net.eval()
net.cuda()

summary(net.cuda(), (1, 104, 128, 104))
# Out:
# [Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(32, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False), Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False), Flatten(start_dim=1, end_dim=-1), Dropout(p=0.1, inplace=False), Linear(in_features=10240, out_features=256, bias=True), Dropout(p=0.1, inplace=False), Linear(in_features=256, out_features=2, bias=True)]
# copy trainable parameters...
#
#
# --- conv1.weight / conv3d/kernel:0 ---
# (32, 1, 3, 3, 3)
# torch.Size([32, 1, 3, 3, 3])
#
# --- conv1.bias / conv3d/bias:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.weight / batch_normalization/gamma:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.bias / batch_normalization/beta:0 ---
# (32,)
# torch.Size([32])
#
# --- conv2.weight / conv3d_1/kernel:0 ---
# (64, 32, 3, 3, 3)
# torch.Size([64, 32, 3, 3, 3])
#
# --- conv2.bias / conv3d_1/bias:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.weight / batch_normalization_1/gamma:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.bias / batch_normalization_1/beta:0 ---
# (64,)
# torch.Size([64])
#
# --- conv3.weight / conv3d_2/kernel:0 ---
# (128, 64, 3, 3, 3)
# torch.Size([128, 64, 3, 3, 3])
#
# --- conv3.bias / conv3d_2/bias:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.weight / batch_normalization_2/gamma:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.bias / batch_normalization_2/beta:0 ---
# (128,)
# torch.Size([128])
#
# --- fc1.weight / dense_2/kernel:0 ---
# (256, 10240)
# torch.Size([256, 10240])
#
# --- fc1.bias / dense_2/bias:0 ---
# (256,)
# torch.Size([256])
#
# --- fc2.weight / dense/kernel:0 ---
# (2, 256)
# torch.Size([2, 256])
#
# --- fc2.bias / dense/bias:0 ---
# (2,)
# torch.Size([2])
#
#
# copy batch norm parameters...
#
# (32,) (32) (32,) (32)
# (64,) (64) (64,) (64)
# (128,) (128) (128,) (128)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1    [-1, 32, 104, 128, 104]             896
#        BatchNorm3d-2    [-1, 32, 104, 128, 104]              64
#          MaxPool3d-3       [-1, 32, 52, 64, 52]               0
#             Conv3d-4       [-1, 64, 52, 64, 52]          55,360
#        BatchNorm3d-5       [-1, 64, 52, 64, 52]             128
#          MaxPool3d-6       [-1, 64, 17, 21, 17]               0
#             Conv3d-7      [-1, 128, 17, 21, 17]         221,312
#        BatchNorm3d-8      [-1, 128, 17, 21, 17]             256
#          MaxPool3d-9         [-1, 128, 4, 5, 4]               0
#           Flatten-10                [-1, 10240]               0
#           Dropout-11                [-1, 10240]               0
#            Linear-12                  [-1, 256]       2,621,696
#           Dropout-13                  [-1, 256]               0
#            Linear-14                    [-1, 2]             514
# ================================================================
# Total params: 2,900,226
# Trainable params: 2,900,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 5.28
# Forward/backward pass size (MB): 902.31
# Params size (MB): 11.06
# Estimated Total Size (MB): 918.65
# ----------------------------------------------------------------

# %% [markdown]
# ## Experiments

# %%
NOTEBOOK_KEY = 'captum--guided-grad-cam--eval-100'
BATCH_SIZE = 24
VERBOSE = 1
LOG = True
SEED = 42

heatmap_evaluation_options = {
    'evaluation_step_size': 100,
    'evaluation_max_steps': -1,
    'evaluation_batch_size': BATCH_SIZE
}

MAX_CATEGORY_1 = 10
MAX_CATEGORY_2 = 20
# MAX_CATEGORY_1 = 1
# MAX_CATEGORY_2 = 2

# %%
# from skimage.transform import resize

# from src.heatmaps.evaluation import HeatmapEvaluationV2
# from src.data import tf_predict, torch_predict

# from captum.attr import LayerGradCam


# attribution_method = LayerGradCam(net, net.conv3)

# def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
#     target = np.argmax(image_y, axis=0)
#     image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
#     batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
#     attribution = attribution_method.attribute(batch_x, int(target))
#     attribution = attribution.to('cpu').detach().numpy()[0]
#     attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
#     attribution = resize(attribution, input_shape[:-1]) # resize since the size is of the last conv layer
#     return attribution

# predict_fn = torch_predict(net)

# %%
from src.heatmaps.evaluation import HeatmapEvaluationV2
from src.data import tf_predict, torch_predict

from captum.attr import GuidedBackprop, GuidedGradCam


attribution_method = GuidedGradCam(net, net.conv3)
# attribution_method = GuidedBackprop(net)

def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
    target = np.argmax(image_y, axis=0)
    image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
    batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
    attribution = attribution_method.attribute(batch_x, int(target))
    attribution = attribution.to('cpu').detach().numpy()[0]
    attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
    return attribution

predict_fn = torch_predict(net)

# %% [markdown]
# ### 10TP 10TN 10FP 10FN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=MAX_CATEGORY_1)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 10, tn: 10, fp: 10, fn: 10
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\captum\attr\_core\guided_backprop_deconvnet.py:61: UserWarning: Setting backward hooks on ReLU activations.The hooks will be removed after the attribution is finished
#   "Setting backward hooks on ReLU activations."
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:06
# auc: 843127.615994215 (0:07:06s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:55
# auc: 1142867.7682042122 (0:06:55s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:02
# auc: 1014002.3910313845 (0:07:03s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:06
# auc: 1030548.2929259539 (0:07:07s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:57
# auc: 1261899.5833277702 (0:06:57s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:04
# auc: 877123.1573700905 (0:07:04s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:57
# auc: 1186664.7740483284 (0:06:58s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:55
# auc: 983767.2910392284 (0:06:55s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:54
# auc: 1130681.708097458 (0:06:54s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:03
# auc: 496872.518157959 (0:07:03s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:05
# auc: 747116.7782813311 (0:07:06s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:05
# auc: 716327.3299351335 (0:07:05s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:55
# auc: 1293411.11677289 (0:06:56s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:05
# auc: 1169843.4797495604 (0:07:05s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:54
# auc: 1298112.0052993298 (0:06:54s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:03
# auc: 576633.8684402406 (0:07:03s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1213757.744896412 (0:06:54s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1256008.5782051086 (0:06:54s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:02
# auc: 951578.4109979868 (0:07:03s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 977603.9392054081 (0:06:54s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1268292.115753889 (0:06:53s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1288943.261551857 (0:06:54s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1156916.330164671 (0:06:53s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1139383.5696101189 (0:06:54s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:54
# auc: 1160759.7906827927 (0:06:54s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:01
# auc: 711117.1411499381 (0:07:02s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:03
# auc: 588532.2293534875 (0:07:03s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:03
# auc: 685097.7182120085 (0:07:03s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:03
# auc: 488919.4329857826 (0:07:04s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:04
# auc: 759068.9864426851 (0:07:05s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:05
# auc: 582247.3954916 (0:07:05s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:06
# auc: 445157.21248984337 (0:07:06s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:04
# auc: 380595.4766385257 (0:07:04s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:02
# auc: 432172.6456694305 (0:07:03s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:52
# auc: 1079589.0654563904 (0:06:53s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:01
# auc: 408910.3609293699 (0:07:02s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1177838.5728508234 (0:06:54s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:52
# auc: 1232540.4590979218 (0:06:53s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:52
# auc: 1155123.74830544 (0:06:53s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:53
# auc: 1020943.2685509324 (0:06:54s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam--eval-100-insertion-TP-TN-FP-FN.cls
# Wall time: 4h 39min 50s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:12
# auc: 289933.1343822181 (0:06:13s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:03
# auc: 1132396.2104976177 (0:06:04s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:08
# auc: 429455.70439621806 (0:06:09s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:06
# auc: 530402.6962459087 (0:06:07s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:56
# auc: 1217256.523269415 (0:05:56s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:07
# auc: 263958.83095636964 (0:06:07s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:59
# auc: 1183564.2453312874 (0:05:59s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:57
# auc: 866640.5620574951 (0:05:58s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:56
# auc: 1002783.8569879532 (0:05:57s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:06
# auc: 161438.03586550057 (0:06:07s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:09
# auc: 305179.73041161895 (0:06:09s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:05
# auc: 331844.61225420237 (0:06:05s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:56
# auc: 1270499.7534632683 (0:05:57s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:05
# auc: 481423.6531428993 (0:06:06s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:56
# auc: 1240001.432055235 (0:05:56s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:05
# auc: 262398.8710179925 (0:06:05s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:57
# auc: 1225921.654716134 (0:05:58s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:05:57
# auc: 1190536.1412346363 (0:05:57s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:06
# auc: 313580.7290762663 (0:06:06s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:17
# auc: 1081612.6480907202 (0:06:17s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:18
# auc: 1245610.801166296 (0:06:18s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:13
# auc: 1081892.8194910288 (0:06:14s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:14
# auc: 1114678.1574606895 (0:06:15s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:16
# auc: 1093653.494632244 (0:06:17s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:18
# auc: 1095643.173122406 (0:06:19s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:33
# auc: 401671.36986106634 (0:06:33s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:28
# auc: 269526.34116634727 (0:06:28s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:26
# auc: 259551.69031769037 (0:06:27s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:29
# auc: 153875.28068982065 (0:06:29s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:26
# auc: 326152.59618237615 (0:06:26s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:27
# auc: 293527.92969048023 (0:06:27s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:24
# auc: 187407.36028179526 (0:06:25s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:28
# auc: 148210.82501113415 (0:06:29s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:26
# auc: 140736.21155284345 (0:06:27s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:14
# auc: 1048012.9751235247 (0:06:14s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:27
# auc: 150903.7494648248 (0:06:28s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:14
# auc: 1011738.7921273708 (0:06:14s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:12
# auc: 1074565.5109480023 (0:06:12s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:13
# auc: 969370.254778862 (0:06:14s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:06:15
# auc: 704692.8821563721 (0:06:15s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam--eval-100-deletion-TP-TN-FP-FN.cls
# Wall time: 4h 8min 48s

# %% [markdown]
# ### 20TP 20TN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=MAX_CATEGORY_2, fp_max=0, fn_max=0)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 20, tn: 20, fp: 0, fn: 0
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\captum\attr\_core\guided_backprop_deconvnet.py:61: UserWarning: Setting backward hooks on ReLU activations.The hooks will be removed after the attribution is finished
#   "Setting backward hooks on ReLU activations."
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:35
# auc: 843127.615994215 (0:07:36s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:23
# auc: 1142867.7682042122 (0:07:24s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:36
# auc: 1014002.3910313845 (0:07:37s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:34
# auc: 1030548.2929259539 (0:07:34s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:26
# auc: 1261899.5833277702 (0:07:27s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:36
# auc: 877123.1573700905 (0:07:36s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:25
# auc: 1186664.7740483284 (0:07:25s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:32
# auc: 496872.518157959 (0:07:33s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:38
# auc: 747116.7782813311 (0:07:38s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:35
# auc: 716327.3299351335 (0:07:35s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:27
# auc: 1293411.11677289 (0:07:27s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:40
# auc: 1169843.4797495604 (0:07:41s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:21
# auc: 1298112.0052993298 (0:07:22s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:39
# auc: 576633.8684402406 (0:07:40s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:24
# auc: 1213757.744896412 (0:07:24s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:25
# auc: 1256008.5782051086 (0:07:25s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:33
# auc: 951578.4109979868 (0:07:34s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:37
# auc: 1054623.2111692429 (0:07:38s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:33
# auc: 935806.170296669 (0:07:34s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:27
# auc: 1268292.115753889 (0:07:27s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:36
# auc: 662082.589828968 (0:07:37s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:24
# auc: 1288943.261551857 (0:07:25s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:32
# auc: 888670.6657171249 (0:07:33s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:37
# auc: 611749.889805913 (0:07:37s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:07:36
# auc: 743579.7503679991 (0:07:37s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:00
# auc: 1139383.5696101189 (0:08:01s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:10:19
# auc: 642416.245046258 (0:10:19s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:59
# auc: 856268.0860936642 (0:10:00s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:44
# auc: 763805.109141767 (0:09:44s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:52
# auc: 866577.1893426776 (0:09:52s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:35
# auc: 1129232.847470045 (0:09:36s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:37
# auc: 1302526.7850637436 (0:09:38s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:39
# auc: 1301020.2261090279 (0:09:40s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:32
# auc: 1191746.6946065426 (0:09:33s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:41
# auc: 1273283.311367035 (0:09:41s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:33
# auc: 1241396.708112955 (0:09:34s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:37
# auc: 1273586.0466301441 (0:09:37s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:46
# auc: 1218447.9948878288 (0:09:46s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:32
# auc: 1315409.3964219093 (0:09:33s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:09:35
# auc: 1200636.9871675968 (0:09:36s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam--eval-100-insertion-TP-TN.cls
# Wall time: 5h 32min 58s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:27
# auc: 289933.1343822181 (0:08:27s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:11
# auc: 1132396.2104976177 (0:08:12s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:27
# auc: 429455.70439621806 (0:08:27s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:15
# auc: 530402.6962459087 (0:08:15s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:15
# auc: 1217256.523269415 (0:08:15s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:13
# auc: 263958.83095636964 (0:08:14s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:15
# auc: 1183564.2453312874 (0:08:16s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:14
# auc: 161438.03586550057 (0:08:15s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:25
# auc: 305179.73041161895 (0:08:25s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:25
# auc: 331844.61225420237 (0:08:25s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:06
# auc: 1270499.7534632683 (0:08:07s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:15
# auc: 481423.6531428993 (0:08:16s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:09
# auc: 1240001.432055235 (0:08:10s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:17
# auc: 262398.8710179925 (0:08:18s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:08
# auc: 1225921.654716134 (0:08:09s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:05
# auc: 1190536.1412346363 (0:08:06s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:19
# auc: 313580.7290762663 (0:08:19s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:27
# auc: 549370.7378029823 (0:08:27s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:14
# auc: 607032.1037754416 (0:08:15s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:07
# auc: 1245610.801166296 (0:08:08s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:19
# auc: 351121.893235296 (0:08:19s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:04
# auc: 1081892.8194910288 (0:08:04s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:22
# auc: 428685.5811536312 (0:08:22s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:13
# auc: 214036.01744771004 (0:08:14s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:40
# auc: 321310.6308333576 (0:08:40s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:05
# auc: 1093653.494632244 (0:08:05s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:27
# auc: 283362.5340975821 (0:08:27s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:28
# auc: 266022.51706011593 (0:08:28s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:28
# auc: 408993.4025287628 (0:08:28s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:27
# auc: 432127.5439828634 (0:08:27s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:07
# auc: 1149048.9190906286 (0:08:08s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:09
# auc: 1181520.2196776867 (0:08:09s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:21
# auc: 1245657.6555490494 (0:08:21s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:09
# auc: 1136093.9771294594 (0:08:10s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:03
# auc: 1209136.2929344177 (0:08:04s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:22
# auc: 1139109.35921669 (0:08:23s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:05
# auc: 1197473.4721541405 (0:08:06s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:25
# auc: 845638.1094306707 (0:08:25s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:05
# auc: 1272232.407873869 (0:08:06s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1384500, step_size: 100, max_steps: -1)...
# ...finished in 0:08:07
# auc: 1175731.82605505 (0:08:08s)
#
# saved to: ../../../../tmp\risei-history\captum--guided-grad-cam--eval-100-deletion-TP-TN.cls
# Wall time: 5h 31min 22s
