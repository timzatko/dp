# %% [markdown]
# # Experiment - Grad Cam (Captum)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import datetime

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.evaluation import show_metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False

class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path,
    ROOT_DIR,
    split=(0.8, 0.15, 0.05),
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq

model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../../../tmp\logs\20210409-152450
# Wall time: 6 ms

# %% [markdown]
# ## Model

# %%
import torch

from torchsummary import summary

from src.model.torch import Net3DCNN, load_weights

# %%
net = Net3DCNN()

weights = np.load(os.path.join(ROOT_DIR, 'tf-weights.npy'), allow_pickle=True)
weights_bn = np.load(os.path.join(ROOT_DIR, 'tf-weights-bn.npy'), allow_pickle=True)

load_weights(net, weights, weights_bn)

net.eval()
net.cuda()

summary(net.cuda(), (1, 104, 128, 104))
# Out:
# [Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(32, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False), Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False), Flatten(start_dim=1, end_dim=-1), Dropout(p=0.1, inplace=False), Linear(in_features=10240, out_features=256, bias=True), Dropout(p=0.1, inplace=False), Linear(in_features=256, out_features=2, bias=True)]
# copy trainable parameters...
#
#
# --- conv1.weight / conv3d/kernel:0 ---
# (32, 1, 3, 3, 3)
# torch.Size([32, 1, 3, 3, 3])
#
# --- conv1.bias / conv3d/bias:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.weight / batch_normalization/gamma:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.bias / batch_normalization/beta:0 ---
# (32,)
# torch.Size([32])
#
# --- conv2.weight / conv3d_1/kernel:0 ---
# (64, 32, 3, 3, 3)
# torch.Size([64, 32, 3, 3, 3])
#
# --- conv2.bias / conv3d_1/bias:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.weight / batch_normalization_1/gamma:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.bias / batch_normalization_1/beta:0 ---
# (64,)
# torch.Size([64])
#
# --- conv3.weight / conv3d_2/kernel:0 ---
# (128, 64, 3, 3, 3)
# torch.Size([128, 64, 3, 3, 3])
#
# --- conv3.bias / conv3d_2/bias:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.weight / batch_normalization_2/gamma:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.bias / batch_normalization_2/beta:0 ---
# (128,)
# torch.Size([128])
#
# --- fc1.weight / dense_2/kernel:0 ---
# (256, 10240)
# torch.Size([256, 10240])
#
# --- fc1.bias / dense_2/bias:0 ---
# (256,)
# torch.Size([256])
#
# --- fc2.weight / dense/kernel:0 ---
# (2, 256)
# torch.Size([2, 256])
#
# --- fc2.bias / dense/bias:0 ---
# (2,)
# torch.Size([2])
#
#
# copy batch norm parameters...
#
# (32,) (32) (32,) (32)
# (64,) (64) (64,) (64)
# (128,) (128) (128,) (128)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1    [-1, 32, 104, 128, 104]             896
#        BatchNorm3d-2    [-1, 32, 104, 128, 104]              64
#          MaxPool3d-3       [-1, 32, 52, 64, 52]               0
#             Conv3d-4       [-1, 64, 52, 64, 52]          55,360
#        BatchNorm3d-5       [-1, 64, 52, 64, 52]             128
#          MaxPool3d-6       [-1, 64, 17, 21, 17]               0
#             Conv3d-7      [-1, 128, 17, 21, 17]         221,312
#        BatchNorm3d-8      [-1, 128, 17, 21, 17]             256
#          MaxPool3d-9         [-1, 128, 4, 5, 4]               0
#           Flatten-10                [-1, 10240]               0
#           Dropout-11                [-1, 10240]               0
#            Linear-12                  [-1, 256]       2,621,696
#           Dropout-13                  [-1, 256]               0
#            Linear-14                    [-1, 2]             514
# ================================================================
# Total params: 2,900,226
# Trainable params: 2,900,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 5.28
# Forward/backward pass size (MB): 902.31
# Params size (MB): 11.06
# Estimated Total Size (MB): 918.65
# ----------------------------------------------------------------

# %% [markdown]
# ## Experiments

# %%
NOTEBOOK_KEY = 'captum--grad-cam'
BATCH_SIZE = 24
VERBOSE = 1
LOG = True
SEED = 42

heatmap_evaluation_options = {
    'evaluation_step_size': 1000,
    'evaluation_max_steps': -1,
    'evaluation_batch_size': BATCH_SIZE
}

# %%
from skimage.transform import resize

from src.heatmaps.evaluation import HeatmapEvaluationV2
from src.data import tf_predict, torch_predict

from captum.attr import LayerGradCam


attribution_method = LayerGradCam(net, net.conv3)

def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
    target = np.argmax(image_y, axis=0)
    image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
    batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
    attribution = attribution_method.attribute(batch_x, int(target))
    attribution = attribution.to('cpu').detach().numpy()[0]
    attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
    attribution = resize(attribution, input_shape[:-1]) # resize since the size is of the last conv layer
    return attribution

predict_fn = torch_predict(net)

# %%
# from src.heatmaps.evaluation import HeatmapEvaluationV2
# from src.data import tf_predict, torch_predict

# from captum.attr import GuidedBackprop, GuidedGradCam


# attribution_method = GuidedGradCam(net, net.conv3)
# attribution_method = GuidedBackprop(net)

# def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
#     target = np.argmax(image_y, axis=0)
#     image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
#     batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
#     attribution = attribution_method.attribute(batch_x, int(target))
#     attribution = attribution.to('cpu').detach().numpy()[0]
#     attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
#     return attribution

# predict_fn = torch_predict(net)

# %% [markdown]
# ### 10TP 10TN 10FP 10FN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=10)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 10, tn: 10, fp: 10, fn: 10
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 1024794.3677008152 (0:00:17s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 867735.9223365784 (0:00:18s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1023543.0687665939 (0:00:19s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1082309.5202445984 (0:00:18s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 910687.5248253345 (0:00:18s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1056549.5178103447 (0:00:19s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 677803.27424407 (0:00:18s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 726325.9772211313 (0:00:18s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 852036.6914570332 (0:00:18s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 581332.0718705654 (0:00:18s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 754176.3953864574 (0:00:18s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 854608.216881752 (0:00:18s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 893201.9330561161 (0:00:18s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1096535.3265404701 (0:00:18s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1132504.4751167297 (0:00:18s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 827686.745673418 (0:00:18s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 802403.113245964 (0:00:18s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 716178.4034222364 (0:00:18s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 996118.9895868301 (0:00:18s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 679695.8182007074 (0:00:18s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 789688.4005516768 (0:00:18s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 939922.0533668995 (0:00:18s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 794579.6929299831 (0:00:18s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 825478.021800518 (0:00:18s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 698381.6724270582 (0:00:18s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 676917.339861393 (0:00:18s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 785237.9389107227 (0:00:18s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 750056.3241541386 (0:00:18s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 655024.1351127625 (0:00:18s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 829560.2172613144 (0:00:18s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 753853.0990481377 (0:00:18s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 493220.73590010405 (0:00:18s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 687297.1627861261 (0:00:18s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 722463.5604768991 (0:00:18s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 645289.4538640976 (0:00:17s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 627741.4210140705 (0:00:18s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 930996.0760176182 (0:00:18s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 814007.2036534548 (0:00:17s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 783030.5874347687 (0:00:18s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 732273.168489337 (0:00:18s)
#
# saved to: ../../../../tmp\risei-history\captum-grad--cam-insertion-TP-TN-FP-FN.cls

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 504475.6608083844 (0:00:16s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 650396.5310752392 (0:00:17s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 754265.8120393753 (0:00:17s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 743865.804746747 (0:00:17s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 1095923.4088659286 (0:00:17s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 439011.7848291993 (0:00:18s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 726583.1485390663 (0:00:18s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 479723.1648117304 (0:00:18s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 639353.3669412136 (0:00:17s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 563276.151008904 (0:00:17s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 647142.1409398317 (0:00:17s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 682862.5680878758 (0:00:17s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 877130.0569176674 (0:00:17s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 682667.7666977048 (0:00:17s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 837406.5160751343 (0:00:17s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 711258.0336630344 (0:00:17s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 775527.2336304188 (0:00:17s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 733639.295399189 (0:00:17s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 508455.0876170397 (0:00:17s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 532178.6113083363 (0:00:17s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 941746.5887963772 (0:00:17s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 677420.587092638 (0:00:17s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 416069.26657259464 (0:00:17s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 741604.3877601624 (0:00:17s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 536060.6573522091 (0:00:17s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 731488.3887767792 (0:00:17s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 390089.0516117215 (0:00:17s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 553160.5811789632 (0:00:17s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 439985.1026944816 (0:00:17s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 823189.9153441191 (0:00:17s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 505305.6437522173 (0:00:17s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 529588.0638062954 (0:00:17s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 443567.49784201384 (0:00:17s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 392579.93632927537 (0:00:17s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 600432.6231777668 (0:00:17s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 421741.3431033492 (0:00:17s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 324016.28606021404 (0:00:17s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:16
# auc: 341202.6287987828 (0:00:17s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 319480.0576195121 (0:00:17s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 228734.38075184822 (0:00:17s)
#
# saved to: ../../../../tmp\risei-history\captum-grad--cam-deletion-TP-TN-FP-FN.cls

# %% [markdown]
# ### 20TP 20TN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=20, fp_max=0, fn_max=0)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 20, tn: 20, fp: 0, fn: 0
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 1024794.3677008152 (0:00:17s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 867735.9223365784 (0:00:18s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1023543.0687665939 (0:00:19s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 1082309.5202445984 (0:00:18s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 910687.5248253345 (0:00:19s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1056549.5178103447 (0:00:19s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:21
# auc: 677803.27424407 (0:00:21s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 581332.0718705654 (0:00:18s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 754176.3953864574 (0:00:18s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 854608.216881752 (0:00:18s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 893201.9330561161 (0:00:19s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 1096535.3265404701 (0:00:19s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:22
# auc: 1132504.4751167297 (0:00:22s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 827686.745673418 (0:00:20s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 802403.113245964 (0:00:19s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 716178.4034222364 (0:00:18s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:36
# auc: 996118.9895868301 (0:00:36s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 1143919.3353056908 (0:00:21s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 878396.9558775425 (0:00:18s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 789688.4005516768 (0:00:21s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 716937.8481805325 (0:00:18s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 939922.0533668995 (0:00:18s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1088025.963306427 (0:00:18s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 820453.1446099281 (0:00:18s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 891013.7735307217 (0:00:18s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 825478.021800518 (0:00:20s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 660041.2368774414 (0:00:18s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 983328.3118903637 (0:00:21s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:23
# auc: 986490.0276064873 (0:00:24s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 911570.3225135803 (0:00:20s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 695119.103603065 (0:00:19s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:31
# auc: 1095955.1945328712 (0:00:31s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:30
# auc: 912986.4931106567 (0:00:31s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:29
# auc: 726980.4868847132 (0:00:30s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 900831.8118751049 (0:00:20s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:21
# auc: 957498.0705976486 (0:00:21s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 865506.2802135944 (0:00:20s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 1070116.9401407242 (0:00:21s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:23
# auc: 948244.8786497116 (0:00:23s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 1087442.6901340485 (0:00:20s)
#
# saved to: ../../../../tmp\risei-history\captum-grad--cam-insertion-TP-TN.cls
# Wall time: 14min 10s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 504475.6608083844 (0:00:19s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 650396.5310752392 (0:00:19s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 754265.8120393753 (0:00:21s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 743865.804746747 (0:00:20s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 1095923.4088659286 (0:00:21s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:22
# auc: 439011.7848291993 (0:00:22s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 726583.1485390663 (0:00:19s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 563276.151008904 (0:00:21s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 647142.1409398317 (0:00:20s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 682862.5680878758 (0:00:20s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 877130.0569176674 (0:00:19s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 682667.7666977048 (0:00:20s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 837406.5160751343 (0:00:20s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:23
# auc: 711258.0336630344 (0:00:23s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:22
# auc: 775527.2336304188 (0:00:23s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:23
# auc: 733639.295399189 (0:00:24s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:21
# auc: 508455.0876170397 (0:00:21s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 593270.1047509909 (0:00:19s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 674067.2744810581 (0:00:20s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 941746.5887963772 (0:00:20s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:22
# auc: 776113.5678738356 (0:00:22s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:21
# auc: 677420.587092638 (0:00:21s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 563697.9799717665 (0:00:19s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:21
# auc: 610387.0525956154 (0:00:21s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 635200.0148966908 (0:00:19s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 741604.3877601624 (0:00:20s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 624214.6233096719 (0:00:20s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 528983.0638095737 (0:00:20s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:23
# auc: 703250.5679875612 (0:00:23s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 714226.5692353249 (0:00:19s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 938174.308091402 (0:00:20s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 723399.5445072651 (0:00:19s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:20
# auc: 842643.8398659229 (0:00:20s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:19
# auc: 717692.1866834164 (0:00:20s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:22
# auc: 724474.1298258305 (0:00:22s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 885393.6158120632 (0:00:17s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 616715.3283953667 (0:00:17s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 466821.5984478593 (0:00:19s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:17
# auc: 865415.6312346458 (0:00:18s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1400000, step_size: 25000, max_steps: -1)...
# ...finished in 0:00:18
# auc: 1054862.9984259605 (0:00:18s)
#
# saved to: ../../../../tmp\risei-history\captum-grad--cam-deletion-TP-TN.cls
# Wall time: 13min 48s
