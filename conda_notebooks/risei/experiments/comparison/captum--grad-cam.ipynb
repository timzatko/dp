# %% [markdown]
# # Experiment - Grad Cam (Captum)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import datetime

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.evaluation import show_metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False

class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path,
    ROOT_DIR,
    split=(0.8, 0.15, 0.05),
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq

model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../../../tmp\logs\20210410-144337
# Wall time: 30.8 ms

# %% [markdown]
# ## Model

# %%
import torch

from torchsummary import summary

from src.model.torch import Net3DCNN, load_weights

# %%
net = Net3DCNN()

weights = np.load(os.path.join(ROOT_DIR, 'tf-weights.npy'), allow_pickle=True)
weights_bn = np.load(os.path.join(ROOT_DIR, 'tf-weights-bn.npy'), allow_pickle=True)

load_weights(net, weights, weights_bn)

net.eval()
net.cuda()

summary(net.cuda(), (1, 104, 128, 104))
# Out:
# [Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(32, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False), Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1)), BatchNorm3d(128, eps=0.001, momentum=0.99, affine=True, track_running_stats=True), MaxPool3d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False), Flatten(start_dim=1, end_dim=-1), Dropout(p=0.1, inplace=False), Linear(in_features=10240, out_features=256, bias=True), Dropout(p=0.1, inplace=False), Linear(in_features=256, out_features=2, bias=True)]
# copy trainable parameters...
#
#
# --- conv1.weight / conv3d/kernel:0 ---
# (32, 1, 3, 3, 3)
# torch.Size([32, 1, 3, 3, 3])
#
# --- conv1.bias / conv3d/bias:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.weight / batch_normalization/gamma:0 ---
# (32,)
# torch.Size([32])
#
# --- bn1.bias / batch_normalization/beta:0 ---
# (32,)
# torch.Size([32])
#
# --- conv2.weight / conv3d_1/kernel:0 ---
# (64, 32, 3, 3, 3)
# torch.Size([64, 32, 3, 3, 3])
#
# --- conv2.bias / conv3d_1/bias:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.weight / batch_normalization_1/gamma:0 ---
# (64,)
# torch.Size([64])
#
# --- bn2.bias / batch_normalization_1/beta:0 ---
# (64,)
# torch.Size([64])
#
# --- conv3.weight / conv3d_2/kernel:0 ---
# (128, 64, 3, 3, 3)
# torch.Size([128, 64, 3, 3, 3])
#
# --- conv3.bias / conv3d_2/bias:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.weight / batch_normalization_2/gamma:0 ---
# (128,)
# torch.Size([128])
#
# --- bn3.bias / batch_normalization_2/beta:0 ---
# (128,)
# torch.Size([128])
#
# --- fc1.weight / dense_2/kernel:0 ---
# (256, 10240)
# torch.Size([256, 10240])
#
# --- fc1.bias / dense_2/bias:0 ---
# (256,)
# torch.Size([256])
#
# --- fc2.weight / dense/kernel:0 ---
# (2, 256)
# torch.Size([2, 256])
#
# --- fc2.bias / dense/bias:0 ---
# (2,)
# torch.Size([2])
#
#
# copy batch norm parameters...
#
# (32,) (32) (32,) (32)
# (64,) (64) (64,) (64)
# (128,) (128) (128,) (128)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1    [-1, 32, 104, 128, 104]             896
#        BatchNorm3d-2    [-1, 32, 104, 128, 104]              64
#          MaxPool3d-3       [-1, 32, 52, 64, 52]               0
#             Conv3d-4       [-1, 64, 52, 64, 52]          55,360
#        BatchNorm3d-5       [-1, 64, 52, 64, 52]             128
#          MaxPool3d-6       [-1, 64, 17, 21, 17]               0
#             Conv3d-7      [-1, 128, 17, 21, 17]         221,312
#        BatchNorm3d-8      [-1, 128, 17, 21, 17]             256
#          MaxPool3d-9         [-1, 128, 4, 5, 4]               0
#           Flatten-10                [-1, 10240]               0
#           Dropout-11                [-1, 10240]               0
#            Linear-12                  [-1, 256]       2,621,696
#           Dropout-13                  [-1, 256]               0
#            Linear-14                    [-1, 2]             514
# ================================================================
# Total params: 2,900,226
# Trainable params: 2,900,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 5.28
# Forward/backward pass size (MB): 902.31
# Params size (MB): 11.06
# Estimated Total Size (MB): 918.65
# ----------------------------------------------------------------

# %% [markdown]
# ## Experiments

# %%
NOTEBOOK_KEY = 'captum--grad-cam'
BATCH_SIZE = 24
VERBOSE = 1
LOG = True
SEED = 42

heatmap_evaluation_options = {
    'evaluation_step_size': 1000,
    'evaluation_max_steps': -1,
    'evaluation_batch_size': BATCH_SIZE
}

# %%
from skimage.transform import resize

from src.heatmaps.evaluation import HeatmapEvaluationV2
from src.data import tf_predict, torch_predict

from captum.attr import LayerGradCam


attribution_method = LayerGradCam(net, net.conv3)

def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
    target = np.argmax(image_y, axis=0)
    image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
    batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
    attribution = attribution_method.attribute(batch_x, int(target))
    attribution = attribution.to('cpu').detach().numpy()[0]
    attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
    attribution = resize(attribution, input_shape[:-1]) # resize since the size is of the last conv layer
    return attribution

predict_fn = torch_predict(net)

# %%
# from src.heatmaps.evaluation import HeatmapEvaluationV2
# from src.data import tf_predict, torch_predict

# from captum.attr import GuidedBackprop, GuidedGradCam


# attribution_method = GuidedGradCam(net, net.conv3)
# attribution_method = GuidedBackprop(net)

# def heatmap_fn(image_x, image_y, **kwargs): # kwargs - log, seed
#     target = np.argmax(image_y, axis=0)
#     image_x = np.transpose(image_x, axes=(3, 0, 1, 2)) # transpose to the torch axes
#     batch_x = torch.from_numpy(np.array([image_x])).float().cuda().requires_grad_(True)
#     attribution = attribution_method.attribute(batch_x, int(target))
#     attribution = attribution.to('cpu').detach().numpy()[0]
#     attribution = np.transpose(np.array(attribution), axes=(1, 2, 3, 0)) # transpose back
#     return attribution

# predict_fn = torch_predict(net)

# %% [markdown]
# ### 10TP 10TN 10FP 10FN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=10)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 10, tn: 10, fp: 10, fn: 10
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1014381.1405599117 (0:01:01s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 869835.8499407768 (0:01:03s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1013504.7940611839 (0:01:02s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1064146.3383436203 (0:01:02s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 900922.3870038986 (0:01:01s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:05
# auc: 1037195.1282322407 (0:01:05s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 677828.5641670227 (0:01:03s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 731779.8740491271 (0:01:01s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 853922.8968769312 (0:01:04s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 570301.5027940273 (0:01:02s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 743602.9781103134 (0:01:04s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 848468.4733450413 (0:01:01s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 880443.9893364906 (0:01:03s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1079288.4491086006 (0:01:03s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 1124449.7945308685 (0:01:01s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 808833.842843771 (0:01:03s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 795684.8993450403 (0:01:02s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 712989.4912838936 (0:01:03s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 984548.2502877712 (0:01:01s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 684158.4554389119 (0:01:03s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 780965.533874929 (0:01:03s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 943581.3214182854 (0:01:00s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 802486.9244545698 (0:01:03s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 819612.3499721289 (0:01:01s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 703612.25938797 (0:01:04s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 675771.9473987818 (0:01:01s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 780175.1583218575 (0:01:02s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 749472.1612632275 (0:01:03s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 655599.386870861 (0:01:01s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 827767.783343792 (0:01:03s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 747084.1545313597 (0:01:00s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 491010.91581583023 (0:01:03s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 680735.1154088974 (0:01:02s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 712143.9095959067 (0:01:01s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 649305.2406087518 (0:01:03s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:08
# auc: 616612.691193819 (0:01:09s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:09
# auc: 937695.1895654202 (0:01:10s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 822403.7282913923 (0:01:04s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 797661.963135004 (0:01:04s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 746608.6511611938 (0:01:07s)
#
# saved to: ../../../../tmp\risei-history\captum--grad-cam-insertion-TP-TN-FP-FN.cls
# Wall time: 42min 14s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN-FP-FN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 509256.44458830357 (0:00:54s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 633737.4076247215 (0:00:56s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 760434.4952106476 (0:00:58s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 750248.056024313 (0:00:55s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 1087589.0807509422 (0:00:54s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 438884.04957950115 (0:00:56s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 710848.6463576555 (0:00:55s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 465643.21518689394 (0:00:55s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 629436.9890391827 (0:00:57s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 563687.9453286529 (0:00:58s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 650549.6125668287 (0:00:55s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 689816.1660507321 (0:00:54s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 873651.4060795307 (0:00:56s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 692891.2527039647 (0:00:55s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 828946.1989700794 (0:00:54s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 714577.8783485293 (0:00:57s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 764882.8963041306 (0:00:57s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 719112.8421127796 (0:00:55s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 519349.4310453534 (0:00:53s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 518496.9740062952 (0:00:55s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 935510.8135193586 (0:00:55s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 664029.9980640411 (0:00:55s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 403372.48880416155 (0:00:56s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 729556.3381612301 (0:00:58s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 522179.1485697031 (0:00:56s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 728894.6320712566 (0:00:54s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 392982.7329814434 (0:00:55s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 553889.8957297206 (0:00:55s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 431797.799654305 (0:00:54s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 822924.8749688268 (0:00:55s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 503946.99127972126 (0:00:57s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 518608.1691905856 (0:00:57s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 436469.00502592325 (0:00:55s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 391043.71919855475 (0:00:54s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 581927.472397685 (0:00:56s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 413698.0925872922 (0:00:54s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 311524.51905980706 (0:00:55s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 322273.8178521395 (0:00:57s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 298933.31065401435 (0:00:58s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 209154.35617044568 (0:00:55s)
#
# saved to: ../../../../tmp\risei-history\captum--grad-cam-deletion-TP-TN-FP-FN.cls
# Wall time: 37min 21s

# %% [markdown]
# ### 20TP 20TN

# %%
from src.data import select_from_dataset, numpy_to_sequence

images_x, images_y, images_y_pred = select_from_dataset(torch_predict(net), test_seq, max_category=20, fp_max=0, fn_max=0)
print(images_x.shape)
sequence = numpy_to_sequence(images_x, images_y, batch_size=BATCH_SIZE)
# Out:
# tp: 20, tn: 20, fp: 0, fn: 0
# (40, 104, 128, 104, 1)

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('insertion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-insertion-TP-TN')
# Out:
# sequence len: 40, method: insertion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1014381.1405599117 (0:01:01s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 869835.8499407768 (0:01:03s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1013504.7940611839 (0:01:04s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1064146.3383436203 (0:01:01s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 900922.3870038986 (0:01:03s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 1037195.1282322407 (0:01:07s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 677828.5641670227 (0:01:02s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 570301.5027940273 (0:01:05s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 743602.9781103134 (0:01:01s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 848468.4733450413 (0:01:04s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 880443.9893364906 (0:01:05s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 1079288.4491086006 (0:01:02s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1124449.7945308685 (0:01:03s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 808833.842843771 (0:01:03s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:05
# auc: 795684.8993450403 (0:01:05s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 712989.4912838936 (0:01:05s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 984548.2502877712 (0:01:01s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1125735.3238165379 (0:01:04s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:05
# auc: 864705.5446207523 (0:01:06s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:06
# auc: 780965.533874929 (0:01:06s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 713435.3886544704 (0:01:05s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 943581.3214182854 (0:01:02s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1074866.391569376 (0:01:02s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 803870.732113719 (0:01:04s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 871033.0819487572 (0:01:02s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:01
# auc: 819612.3499721289 (0:01:01s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 650518.295198679 (0:01:03s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 974824.7421681881 (0:01:03s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:07
# auc: 974990.7653033733 (0:01:07s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 898621.5997338295 (0:01:03s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 689025.074057281 (0:01:01s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 1084759.594976902 (0:01:03s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 903831.6764384508 (0:01:04s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 724562.7699494362 (0:01:04s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 894405.9419333935 (0:01:03s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:00
# auc: 952524.2126882076 (0:01:01s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:03
# auc: 861979.4307947159 (0:01:03s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:04
# auc: 1059615.7620549202 (0:01:04s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 938171.6984957457 (0:01:03s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:01:02
# auc: 1069306.0416579247 (0:01:02s)
#
# saved to: ../../../../tmp\risei-history\captum--grad-cam-insertion-TP-TN.cls
# Wall time: 42min 33s

# %%
# %%time

he = HeatmapEvaluationV2(predict_fn, heatmap_fn, sequence, **heatmap_evaluation_options)

history = he.evaluate('deletion', log=LOG, verbose=VERBOSE, seed=SEED)

history.save(os.path.join(ROOT_DIR, 'risei-history'), f'{NOTEBOOK_KEY}-deletion-TP-TN')
# Out:
# sequence len: 40, method: deletion
# evaluation 1/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:52
# auc: 509256.44458830357 (0:00:53s)
#
# evaluation 2/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 633737.4076247215 (0:00:55s)
#
# evaluation 3/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 760434.4952106476 (0:00:57s)
#
# evaluation 4/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 750248.056024313 (0:00:56s)
#
# evaluation 5/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 1087589.0807509422 (0:00:54s)
#
# evaluation 6/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 438884.04957950115 (0:00:53s)
#
# evaluation 7/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 710848.6463576555 (0:00:55s)
#
# evaluation 8/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 563687.9453286529 (0:00:55s)
#
# evaluation 9/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 650549.6125668287 (0:00:54s)
#
# evaluation 10/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 689816.1660507321 (0:00:55s)
#
# evaluation 11/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:57
# auc: 873651.4060795307 (0:00:57s)
#
# evaluation 12/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 692891.2527039647 (0:00:56s)
#
# evaluation 13/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 828946.1989700794 (0:00:55s)
#
# evaluation 14/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 714577.8783485293 (0:00:53s)
#
# evaluation 15/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 764882.8963041306 (0:00:56s)
#
# evaluation 16/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 719112.8421127796 (0:00:55s)
#
# evaluation 17/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 519349.4310453534 (0:00:54s)
#
# evaluation 18/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 602449.8522281647 (0:00:55s)
#
# evaluation 19/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 681270.0674384832 (0:00:57s)
#
# evaluation 20/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 935510.8135193586 (0:00:56s)
#
# evaluation 21/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 782083.0212980509 (0:00:54s)
#
# evaluation 22/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 664029.9980640411 (0:00:56s)
#
# evaluation 23/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 570496.0149899125 (0:00:55s)
#
# evaluation 24/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 615651.0164514184 (0:00:54s)
#
# evaluation 25/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 637490.6858280301 (0:00:55s)
#
# evaluation 26/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 729556.3381612301 (0:00:56s)
#
# evaluation 27/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 630590.6350761652 (0:00:57s)
#
# evaluation 28/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 528538.2463037968 (0:00:55s)
#
# evaluation 29/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 707753.2946914434 (0:00:56s)
#
# evaluation 30/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 720951.8434032798 (0:00:57s)
#
# evaluation 31/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 926782.6686054468 (0:00:55s)
#
# evaluation 32/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:54
# auc: 722852.7173995972 (0:00:54s)
#
# evaluation 33/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 832455.2055597305 (0:00:55s)
#
# evaluation 34/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 710127.2074729204 (0:00:57s)
#
# evaluation 35/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 712011.8288099766 (0:00:55s)
#
# evaluation 36/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 871422.8057265282 (0:00:56s)
#
# evaluation 37/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 602430.6554943323 (0:00:56s)
#
# evaluation 38/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:55
# auc: 460835.99903434515 (0:00:55s)
#
# evaluation 39/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:53
# auc: 856462.0595276356 (0:00:54s)
#
# evaluation 40/40
# generating heatmap...
# ...finished in 0:00:00s
# evaluate heatmaps (voxels: 1385000, step_size: 1000, max_steps: -1)...
# ...finished in 0:00:56
# auc: 1048234.5303297043 (0:00:56s)
#
# saved to: ../../../../tmp\risei-history\captum--grad-cam-deletion-TP-TN.cls
# Wall time: 37min 12s
