# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
history = HeatmapEvaluationHistory.load('../../tmp/risei-history', 'risei_v1')

# %%
history

# %%
history.description()
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     0.4208775367353013
# 	median:   0.5099043047809309
# 	max:      0.7764877431241372
# 	min:     0.01611830168482825
# 	std:     0.24026280417756218

# %%
history.description(percentage=False)
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     582,683.0639781144
# 	median:   705,935.9949453501
# 	max:    1,075,006.9029927254
# 	min:     22,314.950530957103
# 	std:      332,631.3587180175

# %%
history.plot_auc()

# %%
history.plot_auc(percentage=False)

# %%
history.list_auc(round_auc=False)
# Out:
# idx:   20, auc:  0.01611830168482825
# idx:   16, auc:  0.05122989523986089
# idx:   24, auc:  0.09073157281699872
# idx:   17, auc:  0.09576656170025495
# idx:   22, auc:  0.10035520845221337
# idx:   14, auc:  0.10156682428205857
# idx:    4, auc:  0.22517251204861058
# idx:    7, auc:   0.2828712383705349
# idx:    1, auc:   0.2928244143584645
# idx:   12, auc:   0.3264049819705032
# idx:    8, auc:   0.3487943647194453
# idx:    6, auc:   0.4200973093651246
# idx:   21, auc:   0.5099043047809309
# idx:   15, auc:   0.5349834400537502
# idx:   10, auc:   0.5350080727161347
# idx:    0, auc:   0.5954941980452109
# idx:    2, auc:   0.5958625894302373
# idx:    9, auc:   0.6046490043134248
# idx:   19, auc:    0.630372275536272
# idx:   13, auc:   0.6385721510501385
# idx:    3, auc:   0.6514293519810891
# idx:   18, auc:   0.6620658709035715
# idx:    5, auc:   0.6907477497632972
# idx:   11, auc:    0.744428481675439
# idx:   23, auc:   0.7764877431241372

# %%
idx = 20
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 0
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)
