# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
notebook_key = 'captum--guided-grad-cam-insertion-TP-TN-FP-FN'

history = HeatmapEvaluationHistory.load('../../tmp/risei-history', notebook_key)

# %%
history

# %%
history.description()
# Out:
# evaluated heatmaps: 40
# auc
# 	mean:     0.7502324362060773
# 	median:   0.8673033735033926
# 	max:      0.9654798666912492
# 	min:     0.11824727920800483
# 	std:     0.23706639140495367

# %%
history.description(percentage=False)
# Out:
# evaluated heatmaps: 40
# auc
# 	mean:    1,038,657.795840631
# 	median:  1,200,736.420840025
# 	max:    1,336,656.6704809666
# 	min:     163,707.20920496387
# 	std:      328,206.0914478053

# %%
history.plot_auc()

# %%
history.plot_auc(percentage=False)

# %%
history.list_auc(round_auc=False)
# Out:
# idx:    8, auc:  0.11824727920800483
# idx:    4, auc:  0.22569061965799384
# idx:   23, auc:  0.27376367810134217
# idx:   39, auc:   0.2919995052694118
# idx:   21, auc:   0.3425220956669283
# idx:   19, auc:   0.3919962560800323
# idx:    7, auc:   0.4115938351506055
# idx:    1, auc:   0.5501264248644975
# idx:   14, auc:   0.5747273291958475
# idx:   22, auc:   0.5790590596912408
# idx:   17, auc:    0.645692462894093
# idx:    6, auc:   0.7082603116468171
# idx:   24, auc:   0.7906138547556251
# idx:   36, auc:   0.7956283964371775
# idx:   34, auc:   0.7996223371560922
# idx:   29, auc:   0.8197937404905472
# idx:   37, auc:   0.8301328059197663
# idx:    0, auc:   0.8463520028987643
# idx:    9, auc:   0.8486978732171391
# idx:   28, auc:   0.8640740552921256
# idx:   38, auc:   0.8705326917146597
# idx:   20, auc:   0.8751317927494684
# idx:   13, auc:   0.8752913153647671
# idx:    5, auc:   0.8787940407499737
# idx:   25, auc:    0.880747019797536
# idx:   30, auc:   0.8847592034511139
# idx:   32, auc:   0.8863139966394378
# idx:   18, auc:   0.8952282459548118
# idx:   16, auc:   0.8966468559310938
# idx:   31, auc:   0.9123782819720689
# idx:   26, auc:    0.913089357461841
# idx:    2, auc:   0.9161329205828503
# idx:   11, auc:   0.9329767105162361
# idx:   15, auc:   0.9418071267699971
# idx:   33, auc:   0.9454481091053079
# idx:   10, auc:   0.9487045754643416
# idx:    3, auc:   0.9591148013869691
# idx:   12, auc:   0.9597796411959582
# idx:   35, auc:   0.9623469711493524
# idx:   27, auc:   0.9654798666912492

# %%
plt.rcParams["figure.figsize"] = (10, 5)

idx = 10

plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 1
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 2
t = 'AD' if not np.argmax(history.arr_y[idx], axis=0) else 'CN'
history.plot_heatmap_z(idx, title_1=f'MRI snímok ({t})', title_2=f'Tepelná mapa pre MRI snímok')
plt.show(history.plot_evaluation(idx))
