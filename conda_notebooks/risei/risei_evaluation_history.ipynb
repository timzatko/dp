# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
notebook_key = '20201218-193519' # risei_b1_0__b2_1.ipynb
notebook_key = '20201222-151810' # risei_b1_0__b2_1_value_1.ipynb
notebook_key = '20201222-151738' # risei_b1_0__b2_1_value_median.ipynb
notebook_key = '20201218-193452' # risei_b1_1__b2_0.25.ipynb
notebook_key = '20201219-144127' # risei_b1_1__b2_0.5.ipynb
notebook_key = '20201218-213510' # risei_b1_1__b2_0.75.ipynb
notebook_key = '20201219-121724' # risei_b1_1__b2_0.ipynb

history = HeatmapEvaluationHistory.load('../../tmp/risei-history', notebook_key)

# %%
history

# %%
history.description()
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     0.5255744737179863
# 	median:  0.46940927355137435
# 	max:      0.9241229988849506
# 	min:     0.08449009545797143
# 	std:     0.31787551960596416

# %%
history.description(percentage=False)
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     727,630.5289899185
# 	median:   649,872.7299496531
# 	max:    1,279,400.2375602722
# 	min:     116,972.14367659763
# 	std:      440,082.1273674378

# %%
history.plot_auc()

# %%
history.plot_auc(percentage=False)

# %%
history.list_auc(round_auc=False)
# Out:
# idx:    1, auc:  0.08449009545797143
# idx:   16, auc:  0.08485635906929569
# idx:   22, auc:  0.13045628442827387
# idx:   20, auc:  0.13482247592109964
# idx:   17, auc:  0.15108781240787023
# idx:   14, auc:  0.18726937518155096
# idx:    6, auc:   0.2232107507318327
# idx:    8, auc:  0.24070589455269442
# idx:    7, auc:   0.2751799990441881
# idx:   24, auc:  0.29581347156146454
# idx:    4, auc:   0.3499779694607914
# idx:   12, auc:  0.41605814221408427
# idx:    9, auc:  0.46940927355137435
# idx:   23, auc:   0.6696831996656145
# idx:    5, auc:   0.8018925508778555
# idx:   19, auc:   0.8222448002753163
# idx:   21, auc:    0.833957569566929
# idx:   11, auc:   0.8462928153622514
# idx:    2, auc:    0.855940914011599
# idx:    0, auc:   0.8565161759114739
# idx:   15, auc:   0.8618370047878073
# idx:   10, auc:   0.8622739526277687
# idx:    3, auc:   0.8629397547467317
# idx:   13, auc:   0.8983222026488649
# idx:   18, auc:   0.9241229988849506

# %%
idx = 10
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 1
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 2
t = 'AD' if not np.argmax(history.arr_y[idx], axis=0) else 'CN'
history.plot_heatmap_z(idx, title_1=f'MRI snímok ({t})', title_2=f'Tepelná mapa pre MRI snímok')
plt.show(history.plot_evaluation(idx))
