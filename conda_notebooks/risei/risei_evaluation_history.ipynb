# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
history = HeatmapEvaluationHistory.load('../../tmp/risei-history', '20201222-151810')

# %%
history

# %%
history.description()
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     0.6551298634905481
# 	median:      0.6752069163705
# 	max:      0.9402120409698016
# 	min:     0.23932091722093707
# 	std:      0.2256702250628969

# %%
history.description(percentage=False)
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     906,993.2292497623
# 	median:    934,788.864955306
# 	max:      1,301,674.67969656
# 	min:      331,327.3652046919
# 	std:      312,428.6917478775

# %%
history.plot_auc()

# %%
history.plot_auc(percentage=False)

# %%
history.list_auc(round_auc=False)
# Out:
# idx:    1, auc:  0.23932091722093707
# idx:   22, auc:   0.2619546969701612
# idx:   14, auc:  0.29175315801603036
# idx:   16, auc:  0.29255356145859507
# idx:   17, auc:    0.438536042840292
# idx:   24, auc:   0.4585201380361802
# idx:    6, auc:   0.4801868600050568
# idx:    9, auc:   0.5520229956426881
# idx:   20, auc:   0.5591000170146229
# idx:    7, auc:   0.5671617753105453
# idx:    8, auc:   0.5858068945610134
# idx:   23, auc:   0.6590490158820889
# idx:    4, auc:      0.6752069163705
# idx:   12, auc:   0.7224142463464833
# idx:   21, auc:   0.8337203813296572
# idx:   10, auc:   0.8455018832400985
# idx:   11, auc:   0.8505365650958971
# idx:    2, auc:   0.8539669751689064
# idx:    5, auc:   0.8595183218492487
# idx:    0, auc:   0.8600979352453599
# idx:    3, auc:   0.8704234792894998
# idx:   19, auc:    0.878230216903023
# idx:   15, auc:   0.8853114532622283
# idx:   13, auc:   0.9171400992347881
# idx:   18, auc:   0.9402120409698016

# %%
idx = 20
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 0
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)
