# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
history = HeatmapEvaluationHistory.load('../../tmp/risei-history', 'risei_v1')

# %%
history.description()
# Out:
# evaluated heatmaps: 11
# auc
# 	mean:     705,022.7059256445
# 	median: 1,016,361.8948310614
# 	max:    1,275,051.1795282364
# 	min:     32,402.251526946202
# 	std:      492,296.1963672958

# %%
history.plot_auc()

# %%
history.list_auc(round_auc=True)
# Out:
# idx:    7, auc:             32,402.0
# idx:    1, auc:            116,647.0
# idx:    6, auc:            131,611.0
# idx:    8, auc:            147,037.0
# idx:    4, auc:            507,125.0
# idx:   10, auc:          1,016,362.0
# idx:    2, auc:          1,019,987.0
# idx:    9, auc:          1,058,175.0
# idx:    5, auc:          1,208,538.0
# idx:    3, auc:          1,242,315.0
# idx:    0, auc:          1,275,051.0

# %%
idx = 3
x = history.arr_x[idx]
x.shape

import ipyvolume

ipyvolume.volshow(x.reshape(x.shape[:-1]))
# Out:
# Volume(data=array([[[0.03893261, 0.03893261, 0.03893261, ..., 0.03893261,
#          0.03893261, 0.03893261],
#   …

# %%
idx = 7
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 0
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)
