# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
history = HeatmapEvaluationHistory.load('../../tmp/risei-history', 'risei_v1')

# %%
history.description()
# Out:
# evaluated heatmaps: 25
# auc
# 	mean:     582,683.0639781144
# 	median:   705,935.9949453501
# 	max:    1,075,006.9029927254
# 	min:     22,314.950530957103
# 	std:      332,631.3587180175

# %%
history.plot_auc()

# %%
history.list_auc(round_auc=True)
# Out:
# idx:   20, auc:             22,315.0
# idx:   16, auc:             70,925.0
# idx:   24, auc:            125,613.0
# idx:   17, auc:            132,584.0
# idx:   22, auc:            138,937.0
# idx:   14, auc:            140,614.0
# idx:    4, auc:            311,740.0
# idx:    7, auc:            391,621.0
# idx:    1, auc:            405,400.0
# idx:   12, auc:            451,891.0
# idx:    8, auc:            482,888.0
# idx:    6, auc:            581,603.0
# idx:   21, auc:            705,936.0
# idx:   15, auc:            740,657.0
# idx:   10, auc:            740,691.0
# idx:    0, auc:            824,431.0
# idx:    2, auc:            824,941.0
# idx:    9, auc:            837,105.0
# idx:   19, auc:            872,718.0
# idx:   13, auc:            884,070.0
# idx:    3, auc:            901,870.0
# idx:   18, auc:            916,596.0
# idx:    5, auc:            956,304.0
# idx:   11, auc:          1,030,623.0
# idx:   23, auc:          1,075,007.0

# %%
idx = 7
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 0
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)
