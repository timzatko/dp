# %% [markdown]
# # RISEI Evaluation History

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import os
import numpy as np

from src.heatmaps.evaluation import HeatmapEvaluationHistory

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['image.cmap'] = 'viridis'

# %config InlineBackend.figure_format='retina'
plt.rcParams.update({'font.size': 15})

# %%
notebook_key = 'captum--guided-backprop-insertion-TP-TN-FP-FN'
# notebook_key = 'captum--guided-backprop-deletion-TP-TN-FP-FN'

history = HeatmapEvaluationHistory.load('../../tmp/risei-history', notebook_key)

# %%
history

# %%
history.description()
# Out:
# evaluated heatmaps: 40
# auc
# 	mean:     0.6867743871514946
# 	median:   0.7876897516487147
# 	max:      0.9529636849490126
# 	min:      0.2949483789009412
# 	std:     0.22634031838755617

# %%
history.description(percentage=False)
# Out:
# evaluated heatmaps: 40
# auc
# 	mean:     950,803.4267431125
# 	median: 1,090,515.5012905598
# 	max:    1,319,328.6677002907
# 	min:     408,340.69327265024
# 	std:     313,356.40111101535

# %%
history.plot_auc()

# %%
history.plot_auc(percentage=False)

# %%
history.list_auc(round_auc=False)
# Out:
# idx:   31, auc:   0.2949483789009412
# idx:   32, auc:   0.3033860386075013
# idx:   33, auc:  0.33585715791775045
# idx:   28, auc:    0.337532917883813
# idx:   35, auc:  0.36307200228901493
# idx:    9, auc:   0.3689461341067479
# idx:   30, auc:  0.40675527964880176
# idx:   26, auc:   0.4175549390940712
# idx:   15, auc:  0.43538094251265075
# idx:   27, auc:   0.4448960027740972
# idx:   11, auc:     0.46886246315899
# idx:   29, auc:   0.4977656548222652
# idx:   10, auc:   0.5145464404734966
# idx:   25, auc:   0.5625096266760667
# idx:    0, auc:   0.5636523888480316
# idx:    5, auc:   0.5974451171193953
# idx:   18, auc:   0.6201330677480623
# idx:    2, auc:    0.652830519276215
# idx:    3, auc:   0.6988632317753674
# idx:   13, auc:    0.715059256355055
# idx:   20, auc:   0.8603202469423744
# idx:   17, auc:   0.8627639816245257
# idx:    7, auc:   0.8669392011907109
# idx:   39, auc:     0.86704026797682
# idx:    6, auc:   0.8676376536205417
# idx:   22, auc:   0.8765510795741293
# idx:    8, auc:   0.8823650744612764
# idx:   38, auc:   0.8859477425579632
# idx:   24, auc:   0.8859895577231635
# idx:   34, auc:   0.8894110434251553
# idx:   16, auc:   0.8902104427061903
# idx:   23, auc:   0.8928959445439598
# idx:   37, auc:   0.8953413446562141
# idx:   19, auc:   0.8973865563149107
# idx:   36, auc:   0.9124309356502097
# idx:    4, auc:    0.914799561698235
# idx:   12, auc:     0.91491813363112
# idx:    1, auc:   0.9161600967150694
# idx:   21, auc:   0.9389053761098705
# idx:   14, auc:   0.9529636849490126

# %%
plt.rcParams["figure.figsize"] = (10, 5)

idx = 10

plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 1
plt.show(history.plot_evaluation(idx))
history.plot_heatmap_z(idx)
history.plot_heatmap_x(idx)
history.plot_heatmap_y(idx)

# %%
idx = 2
t = 'AD' if not np.argmax(history.arr_y[idx], axis=0) else 'CN'
history.plot_heatmap_z(idx, title_1=f'MRI snímok ({t})', title_2=f'Tepelná mapa pre MRI snímok')
plt.show(history.plot_evaluation(idx))
