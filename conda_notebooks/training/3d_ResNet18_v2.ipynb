# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201216-005727
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.10,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
    'batch_norm': False,
#     'batch_norm': True,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 104, 128, 104)     0
# _________________________________________________________________
# my_res_net (MyResNet)        (None, 1024)              12032960
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 12,689,602
# Trainable params: 12,680,002
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201216-005727
# checkpoint dir: ../../tmp\checkpoints\20201216-005727
# log dir: ../../tmp\logs\20201216-005727
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 1.0834 - recall: 0.4975 - precision: 0.4975 - auc: 0.5038 - categorical_accuracy: 0.4975
# Epoch 00001: val_auc improved from -inf to 0.39900, saving model to ../../tmp\checkpoints\20201216-005727\cp-0001.ckpt
# 41/41 [==============================] - 6s 151ms/step - loss: 1.0834 - recall: 0.4975 - precision: 0.4975 - auc: 0.5038 - categorical_accuracy: 0.4975 - val_loss: 0.7811 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3990 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7367 - recall: 0.5275 - precision: 0.5275 - auc: 0.5201 - categorical_accuracy: 0.5275
# Epoch 00002: val_auc did not improve from 0.39900
# 41/41 [==============================] - 4s 108ms/step - loss: 0.7352 - recall: 0.5299 - precision: 0.5299 - auc: 0.5224 - categorical_accuracy: 0.5299 - val_loss: 0.7332 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3942 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6837 - recall: 0.6567 - precision: 0.6567 - auc: 0.6781 - categorical_accuracy: 0.6567
# Epoch 00003: val_auc did not improve from 0.39900
# 41/41 [==============================] - 5s 118ms/step - loss: 0.6837 - recall: 0.6567 - precision: 0.6567 - auc: 0.6781 - categorical_accuracy: 0.6567 - val_loss: 0.7241 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3156 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6245 - recall: 0.7050 - precision: 0.7050 - auc: 0.7476 - categorical_accuracy: 0.7050- ETA: 3s - loss: 0.6835 - recall: 0.6800 - precision: 0.6800 - auc: 0.7032 -
# Epoch 00004: val_auc did not improve from 0.39900
# 41/41 [==============================] - 5s 115ms/step - loss: 0.6246 - recall: 0.7015 - precision: 0.7015 - auc: 0.7467 - categorical_accuracy: 0.7015 - val_loss: 0.7492 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3548 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6735 - recall: 0.6075 - precision: 0.6075 - auc: 0.6631 - categorical_accuracy: 0.6075
# Epoch 00005: val_auc improved from 0.39900 to 0.70715, saving model to ../../tmp\checkpoints\20201216-005727\cp-0005.ckpt
# 41/41 [==============================] - 5s 127ms/step - loss: 0.6734 - recall: 0.6045 - precision: 0.6045 - auc: 0.6614 - categorical_accuracy: 0.6045 - val_loss: 0.6529 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.7071 - val_categorical_accuracy: 0.6300
# Epoch 6/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6041 - recall: 0.7189 - precision: 0.7189 - auc: 0.7456 - categorical_accuracy: 0.7189
# Epoch 00006: val_auc did not improve from 0.70715
# 41/41 [==============================] - 5s 122ms/step - loss: 0.6041 - recall: 0.7189 - precision: 0.7189 - auc: 0.7456 - categorical_accuracy: 0.7189 - val_loss: 0.7175 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6779 - val_categorical_accuracy: 0.6400
# Epoch 7/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5027 - recall: 0.7537 - precision: 0.7537 - auc: 0.8354 - categorical_accuracy: 0.7537- ETA: 1s - loss: 0.5150 - recall: 0.7300 - precision: 0.7300 - auc: 0.8326 - categorica
# Epoch 00007: val_auc did not improve from 0.70715
# 41/41 [==============================] - 5s 112ms/step - loss: 0.5027 - recall: 0.7537 - precision: 0.7537 - auc: 0.8354 - categorical_accuracy: 0.7537 - val_loss: 0.8293 - val_recall: 0.3900 - val_precision: 0.3900 - val_auc: 0.4217 - val_categorical_accuracy: 0.3900
# Epoch 8/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4662 - recall: 0.7750 - precision: 0.7750 - auc: 0.8642 - categorical_accuracy: 0.7750
# Epoch 00008: val_auc did not improve from 0.70715
# 41/41 [==============================] - 5s 117ms/step - loss: 0.4676 - recall: 0.7736 - precision: 0.7736 - auc: 0.8627 - categorical_accuracy: 0.7736 - val_loss: 0.9252 - val_recall: 0.4000 - val_precision: 0.4000 - val_auc: 0.4920 - val_categorical_accuracy: 0.4000
# Epoch 9/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5166 - recall: 0.6950 - precision: 0.6950 - auc: 0.8026 - categorical_accuracy: 0.6950
# Epoch 00009: val_auc did not improve from 0.70715
# 41/41 [==============================] - 5s 115ms/step - loss: 0.5157 - recall: 0.6965 - precision: 0.6965 - auc: 0.8031 - categorical_accuracy: 0.6965 - val_loss: 0.8063 - val_recall: 0.4300 - val_precision: 0.4300 - val_auc: 0.4264 - val_categorical_accuracy: 0.4300
# Epoch 10/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3092 - recall: 0.8575 - precision: 0.8575 - auc: 0.9389 - categorical_accuracy: 0.8575
# Epoch 00010: val_auc improved from 0.70715 to 0.73145, saving model to ../../tmp\checkpoints\20201216-005727\cp-0010.ckpt
# 41/41 [==============================] - 6s 138ms/step - loss: 0.3088 - recall: 0.8582 - precision: 0.8582 - auc: 0.9389 - categorical_accuracy: 0.8582 - val_loss: 1.2620 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7315 - val_categorical_accuracy: 0.6600
# Epoch 11/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1990 - recall: 0.9129 - precision: 0.9129 - auc: 0.9752 - categorical_accuracy: 0.9129
# Epoch 00011: val_auc improved from 0.73145 to 0.75210, saving model to ../../tmp\checkpoints\20201216-005727\cp-0011.ckpt
# 41/41 [==============================] - 6s 137ms/step - loss: 0.1990 - recall: 0.9129 - precision: 0.9129 - auc: 0.9752 - categorical_accuracy: 0.9129 - val_loss: 0.8642 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7521 - val_categorical_accuracy: 0.7000
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1761 - recall: 0.9275 - precision: 0.9275 - auc: 0.9807 - categorical_accuracy: 0.9275
# Epoch 00012: val_auc did not improve from 0.75210
# 41/41 [==============================] - 4s 103ms/step - loss: 0.1796 - recall: 0.9254 - precision: 0.9254 - auc: 0.9798 - categorical_accuracy: 0.9254 - val_loss: 1.1225 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7302 - val_categorical_accuracy: 0.6700
# Epoch 13/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1864 - recall: 0.9279 - precision: 0.9279 - auc: 0.9796 - categorical_accuracy: 0.9279
# Epoch 00013: val_auc did not improve from 0.75210
# 41/41 [==============================] - 5s 115ms/step - loss: 0.1864 - recall: 0.9279 - precision: 0.9279 - auc: 0.9796 - categorical_accuracy: 0.9279 - val_loss: 1.6163 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7400 - val_categorical_accuracy: 0.6900
# Epoch 14/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0794 - recall: 0.9776 - precision: 0.9776 - auc: 0.9951 - categorical_accuracy: 0.9776
# Epoch 00014: val_auc improved from 0.75210 to 0.79120, saving model to ../../tmp\checkpoints\20201216-005727\cp-0014.ckpt
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0794 - recall: 0.9776 - precision: 0.9776 - auc: 0.9951 - categorical_accuracy: 0.9776 - val_loss: 1.5526 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7912 - val_categorical_accuracy: 0.7300
# Epoch 15/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0440 - recall: 0.9826 - precision: 0.9826 - auc: 0.9988 - categorical_accuracy: 0.9826
# Epoch 00015: val_auc improved from 0.79120 to 0.81480, saving model to ../../tmp\checkpoints\20201216-005727\cp-0015.ckpt
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0440 - recall: 0.9826 - precision: 0.9826 - auc: 0.9988 - categorical_accuracy: 0.9826 - val_loss: 0.9323 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8148 - val_categorical_accuracy: 0.7200
# Epoch 16/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0361 - recall: 0.9876 - precision: 0.9876 - auc: 0.9991 - categorical_accuracy: 0.9876
# Epoch 00016: val_auc did not improve from 0.81480
# 41/41 [==============================] - 6s 140ms/step - loss: 0.0361 - recall: 0.9876 - precision: 0.9876 - auc: 0.9991 - categorical_accuracy: 0.9876 - val_loss: 0.9140 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8013 - val_categorical_accuracy: 0.7300
# Epoch 17/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0247 - recall: 0.9900 - precision: 0.9900 - auc: 0.9997 - categorical_accuracy: 0.9900
# Epoch 00017: val_auc did not improve from 0.81480
# 41/41 [==============================] - 5s 125ms/step - loss: 0.0247 - recall: 0.9900 - precision: 0.9900 - auc: 0.9997 - categorical_accuracy: 0.9900 - val_loss: 1.2440 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7528 - val_categorical_accuracy: 0.7000
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0520 - recall: 0.9875 - precision: 0.9875 - auc: 0.9930 - categorical_accuracy: 0.9875
# Epoch 00018: val_auc improved from 0.81480 to 0.83410, saving model to ../../tmp\checkpoints\20201216-005727\cp-0018.ckpt
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0517 - recall: 0.9876 - precision: 0.9876 - auc: 0.9930 - categorical_accuracy: 0.9876 - val_loss: 0.7502 - val_recall: 0.7900 - val_precision: 0.7900 - val_auc: 0.8341 - val_categorical_accuracy: 0.7900
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0132 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950
# Epoch 00019: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 114ms/step - loss: 0.0131 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950 - val_loss: 1.3358 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7873 - val_categorical_accuracy: 0.6800
# Epoch 20/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0026 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00020: val_auc did not improve from 0.83410
# 41/41 [==============================] - 4s 109ms/step - loss: 0.0026 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1269 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8086 - val_categorical_accuracy: 0.7300
# Epoch 21/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0057 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00021: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 113ms/step - loss: 0.0057 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1211 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.8047 - val_categorical_accuracy: 0.7000
# Epoch 22/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0032 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00022: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 115ms/step - loss: 0.0032 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2607 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8066 - val_categorical_accuracy: 0.7200
# Epoch 23/200
# 40/41 [============================>.] - ETA: 0s - loss: 9.3417e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00023: val_auc did not improve from 0.83410
# 41/41 [==============================] - 4s 105ms/step - loss: 9.3005e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3138 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7964 - val_categorical_accuracy: 0.7100
# Epoch 24/200
# 41/41 [==============================] - ETA: 0s - loss: 5.4026e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00024: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 125ms/step - loss: 5.4026e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2713 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7991 - val_categorical_accuracy: 0.7000
# Epoch 25/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0044 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00025: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0043 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1739 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7834 - val_categorical_accuracy: 0.7200
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0019 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00026: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0019 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0021 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8090 - val_categorical_accuracy: 0.7500
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 8.3804e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00027: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 115ms/step - loss: 8.3686e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0262 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.8168 - val_categorical_accuracy: 0.7600
# Epoch 28/200
# 40/41 [============================>.] - ETA: 0s - loss: 5.3743e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00028: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 128ms/step - loss: 5.3513e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0705 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8177 - val_categorical_accuracy: 0.7400
# Epoch 29/200
# 40/41 [============================>.] - ETA: 0s - loss: 3.8437e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00029: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 119ms/step - loss: 3.8531e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0988 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8176 - val_categorical_accuracy: 0.7400
# Epoch 30/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0062 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950
# Epoch 00030: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 113ms/step - loss: 0.0062 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950 - val_loss: 1.2104 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8296 - val_categorical_accuracy: 0.7400
# Epoch 31/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0053 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00031: val_auc did not improve from 0.83410
# 41/41 [==============================] - 4s 107ms/step - loss: 0.0053 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.2857 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8049 - val_categorical_accuracy: 0.7200
# Epoch 32/200
# 41/41 [==============================] - ETA: 0s - loss: 6.3355e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00032: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 117ms/step - loss: 6.3355e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2549 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8047 - val_categorical_accuracy: 0.7300
# Epoch 33/200
# 41/41 [==============================] - ETA: 0s - loss: 5.8026e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00033: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 123ms/step - loss: 5.8026e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2853 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8017 - val_categorical_accuracy: 0.7300
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 5.5092e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00034: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 122ms/step - loss: 5.4877e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2945 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8056 - val_categorical_accuracy: 0.7200
# Epoch 35/200
# 40/41 [============================>.] - ETA: 0s - loss: 3.6695e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00035: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 121ms/step - loss: 3.6834e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3020 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8057 - val_categorical_accuracy: 0.7200
# Epoch 36/200
# 41/41 [==============================] - ETA: 0s - loss: 3.6377e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00036: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 116ms/step - loss: 3.6377e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3089 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8001 - val_categorical_accuracy: 0.7200
# Epoch 37/200
# 40/41 [============================>.] - ETA: 0s - loss: 3.1386e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00037: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 123ms/step - loss: 3.1386e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3272 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7995 - val_categorical_accuracy: 0.7200
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 3.0784e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000- ETA: 1s - loss: 2.0366e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorica
# Epoch 00038: val_auc did not improve from 0.83410
# 41/41 [==============================] - 4s 109ms/step - loss: 3.0648e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3301 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7980 - val_categorical_accuracy: 0.7200
# Epoch 39/200
# 40/41 [============================>.] - ETA: 0s - loss: 4.8036e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00039: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 116ms/step - loss: 4.8023e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3347 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7983 - val_categorical_accuracy: 0.7200
# Epoch 40/200
# 40/41 [============================>.] - ETA: 0s - loss: 2.8594e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00040: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 117ms/step - loss: 2.8464e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3417 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7981 - val_categorical_accuracy: 0.7200
# Epoch 41/200
# 41/41 [==============================] - ETA: 0s - loss: 4.2686e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00041: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 122ms/step - loss: 4.2686e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3420 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7947 - val_categorical_accuracy: 0.7200
# Epoch 42/200
# 40/41 [============================>.] - ETA: 0s - loss: 3.7515e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00042: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 116ms/step - loss: 3.7355e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3414 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7947 - val_categorical_accuracy: 0.7200
# Epoch 43/200
# 41/41 [==============================] - ETA: 0s - loss: 2.2908e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00043: val_auc did not improve from 0.83410
# 41/41 [==============================] - 5s 120ms/step - loss: 2.2908e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3391 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7948 - val_categorical_accuracy: 0.7200
# Wall time: 4min 46s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 132 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.7450888752937317
# recall: 0.7900000214576721
# precision: 0.7900000214576721
# auc: 0.8340999484062195
# categorical_accuracy: 0.7900000214576721
#
# Wall time: 23.9 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.8727272727272727
# recall: 0.7741935483870968
# f1-score: 0.8205128205128205
# support: 62
#
#
# CN
# precision: 0.6888888888888889
# recall: 0.8157894736842105
# f1-score: 0.746987951807229
# support: 38
#
#
# micro avg
# precision: 0.79
# recall: 0.79
# f1-score: 0.79
# support: 100
#
#
# macro avg
# precision: 0.7808080808080808
# recall: 0.7949915110356536
# f1-score: 0.7837503861600248
# support: 100
#
#
# weighted avg
# precision: 0.8028686868686868
# recall: 0.79
# f1-score: 0.7925733704046957
# support: 100
#
#
# samples avg
# precision: 0.79
# recall: 0.79
# f1-score: 0.79
# support: 100
#
#
# F1
# micro: 0.79
# macro: 0.7837503861600248
#
#
# accuracy_score: 0.79
# sensitivity_score: 0.7741935483870968
# specificity_score: 0.8157894736842105
#
#
# Wall time: 20.9 s
