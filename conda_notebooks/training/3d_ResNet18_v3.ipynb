# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise) + Batch Norm

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201216-010434
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.10,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
#     'batch_norm': False,
    'batch_norm': True,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 104, 128, 104)     0
# _________________________________________________________________
# my_res_net (MyResNet)        (None, 1024)              12032960
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 12,695,746
# Trainable params: 12,683,074
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201216-010434
# checkpoint dir: ../../tmp\checkpoints\20201216-010434
# log dir: ../../tmp\logs\20201216-010434
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 1.5515 - recall: 0.4776 - precision: 0.4776 - auc: 0.4874 - categorical_accuracy: 0.4776
# Epoch 00001: val_auc improved from -inf to 0.45960, saving model to ../../tmp\checkpoints\20201216-010434\cp-0001.ckpt
# 41/41 [==============================] - 7s 163ms/step - loss: 1.5515 - recall: 0.4776 - precision: 0.4776 - auc: 0.4874 - categorical_accuracy: 0.4776 - val_loss: 0.9142 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4596 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.8341 - recall: 0.5875 - precision: 0.5875 - auc: 0.5988 - categorical_accuracy: 0.5875
# Epoch 00002: val_auc improved from 0.45960 to 0.58130, saving model to ../../tmp\checkpoints\20201216-010434\cp-0002.ckpt
# 41/41 [==============================] - 6s 144ms/step - loss: 0.8341 - recall: 0.5871 - precision: 0.5871 - auc: 0.5975 - categorical_accuracy: 0.5871 - val_loss: 0.6588 - val_recall: 0.5600 - val_precision: 0.5600 - val_auc: 0.5813 - val_categorical_accuracy: 0.5600
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7208 - recall: 0.6250 - precision: 0.6250 - auc: 0.6999 - categorical_accuracy: 0.6250
# Epoch 00003: val_auc did not improve from 0.58130
# 41/41 [==============================] - 5s 127ms/step - loss: 0.7207 - recall: 0.6219 - precision: 0.6219 - auc: 0.6986 - categorical_accuracy: 0.6219 - val_loss: 0.9462 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3049 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5091 - recall: 0.7687 - precision: 0.7687 - auc: 0.8255 - categorical_accuracy: 0.7687
# Epoch 00004: val_auc did not improve from 0.58130
# 41/41 [==============================] - 5s 117ms/step - loss: 0.5091 - recall: 0.7687 - precision: 0.7687 - auc: 0.8255 - categorical_accuracy: 0.7687 - val_loss: 1.2766 - val_recall: 0.3600 - val_precision: 0.3600 - val_auc: 0.3003 - val_categorical_accuracy: 0.3600
# Epoch 5/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6129 - recall: 0.7275 - precision: 0.7275 - auc: 0.8078 - categorical_accuracy: 0.7275
# Epoch 00005: val_auc did not improve from 0.58130
# 41/41 [==============================] - 5s 114ms/step - loss: 0.6215 - recall: 0.7264 - precision: 0.7264 - auc: 0.8050 - categorical_accuracy: 0.7264 - val_loss: 1.9084 - val_recall: 0.3700 - val_precision: 0.3700 - val_auc: 0.3214 - val_categorical_accuracy: 0.3700
# Epoch 6/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6770 - recall: 0.7214 - precision: 0.7214 - auc: 0.7980 - categorical_accuracy: 0.7214
# Epoch 00006: val_auc did not improve from 0.58130
# 41/41 [==============================] - 5s 116ms/step - loss: 0.6770 - recall: 0.7214 - precision: 0.7214 - auc: 0.7980 - categorical_accuracy: 0.7214 - val_loss: 0.8310 - val_recall: 0.3900 - val_precision: 0.3900 - val_auc: 0.3518 - val_categorical_accuracy: 0.3900
# Epoch 7/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5376 - recall: 0.7736 - precision: 0.7736 - auc: 0.8516 - categorical_accuracy: 0.7736
# Epoch 00007: val_auc improved from 0.58130 to 0.73020, saving model to ../../tmp\checkpoints\20201216-010434\cp-0007.ckpt
# 41/41 [==============================] - 5s 132ms/step - loss: 0.5376 - recall: 0.7736 - precision: 0.7736 - auc: 0.8516 - categorical_accuracy: 0.7736 - val_loss: 1.3030 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7302 - val_categorical_accuracy: 0.6500
# Epoch 8/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6576 - recall: 0.7800 - precision: 0.7800 - auc: 0.8511 - categorical_accuracy: 0.7800- ETA: 2s - loss: 0.4231 - recall: 0.8176 - precision: 0.8176 - auc: 0.8977 - categor
# Epoch 00008: val_auc did not improve from 0.73020
# 41/41 [==============================] - 5s 127ms/step - loss: 0.6571 - recall: 0.7786 - precision: 0.7786 - auc: 0.8504 - categorical_accuracy: 0.7786 - val_loss: 2.5592 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6500 - val_categorical_accuracy: 0.6200
# Epoch 9/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5153 - recall: 0.7935 - precision: 0.7935 - auc: 0.8643 - categorical_accuracy: 0.7935
# Epoch 00009: val_auc did not improve from 0.73020
# 41/41 [==============================] - 5s 114ms/step - loss: 0.5153 - recall: 0.7935 - precision: 0.7935 - auc: 0.8643 - categorical_accuracy: 0.7935 - val_loss: 0.9196 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4357 - val_categorical_accuracy: 0.3800
# Epoch 10/200
# 41/41 [==============================] - ETA: 0s - loss: 0.4037 - recall: 0.8109 - precision: 0.8109 - auc: 0.8964 - categorical_accuracy: 0.8109
# Epoch 00010: val_auc improved from 0.73020 to 0.74470, saving model to ../../tmp\checkpoints\20201216-010434\cp-0010.ckpt
# 41/41 [==============================] - 6s 142ms/step - loss: 0.4037 - recall: 0.8109 - precision: 0.8109 - auc: 0.8964 - categorical_accuracy: 0.8109 - val_loss: 0.7892 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7447 - val_categorical_accuracy: 0.6600
# Epoch 11/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3022 - recall: 0.8625 - precision: 0.8625 - auc: 0.9414 - categorical_accuracy: 0.8625
# Epoch 00011: val_auc improved from 0.74470 to 0.76030, saving model to ../../tmp\checkpoints\20201216-010434\cp-0011.ckpt
# 41/41 [==============================] - 5s 134ms/step - loss: 0.3035 - recall: 0.8607 - precision: 0.8607 - auc: 0.9407 - categorical_accuracy: 0.8607 - val_loss: 0.6976 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7603 - val_categorical_accuracy: 0.7000
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2911 - recall: 0.8850 - precision: 0.8850 - auc: 0.9482 - categorical_accuracy: 0.8850
# Epoch 00012: val_auc did not improve from 0.76030
# 41/41 [==============================] - 5s 113ms/step - loss: 0.2935 - recall: 0.8831 - precision: 0.8831 - auc: 0.9473 - categorical_accuracy: 0.8831 - val_loss: 0.7508 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7299 - val_categorical_accuracy: 0.6400
# Epoch 13/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1990 - recall: 0.9080 - precision: 0.9080 - auc: 0.9739 - categorical_accuracy: 0.9080
# Epoch 00013: val_auc did not improve from 0.76030
# 41/41 [==============================] - 5s 113ms/step - loss: 0.1990 - recall: 0.9080 - precision: 0.9080 - auc: 0.9739 - categorical_accuracy: 0.9080 - val_loss: 1.2000 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7288 - val_categorical_accuracy: 0.6900
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2941 - recall: 0.8950 - precision: 0.8950 - auc: 0.9530 - categorical_accuracy: 0.8950
# Epoch 00014: val_auc did not improve from 0.76030
# 41/41 [==============================] - 5s 111ms/step - loss: 0.2949 - recall: 0.8955 - precision: 0.8955 - auc: 0.9525 - categorical_accuracy: 0.8955 - val_loss: 1.1830 - val_recall: 0.6000 - val_precision: 0.6000 - val_auc: 0.7153 - val_categorical_accuracy: 0.6000
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2697 - recall: 0.8750 - precision: 0.8750 - auc: 0.9549 - categorical_accuracy: 0.8750- ETA: 2s - loss: 0.2154 - recall: 0.8929 - precision: 0.8929 - auc: 0.9656 - cate
# Epoch 00015: val_auc did not improve from 0.76030
# 41/41 [==============================] - 5s 120ms/step - loss: 0.2748 - recall: 0.8731 - precision: 0.8731 - auc: 0.9535 - categorical_accuracy: 0.8731 - val_loss: 1.0382 - val_recall: 0.5500 - val_precision: 0.5500 - val_auc: 0.5963 - val_categorical_accuracy: 0.5500
# Epoch 16/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2431 - recall: 0.8900 - precision: 0.8900 - auc: 0.9579 - categorical_accuracy: 0.8900
# Epoch 00016: val_auc improved from 0.76030 to 0.78270, saving model to ../../tmp\checkpoints\20201216-010434\cp-0016.ckpt
# 41/41 [==============================] - 6s 142ms/step - loss: 0.2448 - recall: 0.8881 - precision: 0.8881 - auc: 0.9574 - categorical_accuracy: 0.8881 - val_loss: 0.9195 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.7827 - val_categorical_accuracy: 0.7600
# Epoch 17/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1288 - recall: 0.9502 - precision: 0.9502 - auc: 0.9890 - categorical_accuracy: 0.9502
# Epoch 00017: val_auc did not improve from 0.78270
# 41/41 [==============================] - 4s 110ms/step - loss: 0.1288 - recall: 0.9502 - precision: 0.9502 - auc: 0.9890 - categorical_accuracy: 0.9502 - val_loss: 0.8441 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7261 - val_categorical_accuracy: 0.6700
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1000 - recall: 0.9600 - precision: 0.9600 - auc: 0.9928 - categorical_accuracy: 0.9600
# Epoch 00018: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 115ms/step - loss: 0.1018 - recall: 0.9577 - precision: 0.9577 - auc: 0.9925 - categorical_accuracy: 0.9577 - val_loss: 1.1715 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7497 - val_categorical_accuracy: 0.7500
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0874 - recall: 0.9675 - precision: 0.9675 - auc: 0.9934 - categorical_accuracy: 0.9675
# Epoch 00019: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 110ms/step - loss: 0.0894 - recall: 0.9652 - precision: 0.9652 - auc: 0.9932 - categorical_accuracy: 0.9652 - val_loss: 1.2649 - val_recall: 0.7700 - val_precision: 0.7700 - val_auc: 0.7304 - val_categorical_accuracy: 0.7700
# Epoch 20/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0643 - recall: 0.9850 - precision: 0.9850 - auc: 0.9978 - categorical_accuracy: 0.9850
# Epoch 00020: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 110ms/step - loss: 0.0660 - recall: 0.9851 - precision: 0.9851 - auc: 0.9977 - categorical_accuracy: 0.9851 - val_loss: 1.1602 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.7397 - val_categorical_accuracy: 0.7600
# Epoch 21/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0766 - recall: 0.9776 - precision: 0.9776 - auc: 0.9958 - categorical_accuracy: 0.9776
# Epoch 00021: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 114ms/step - loss: 0.0766 - recall: 0.9776 - precision: 0.9776 - auc: 0.9958 - categorical_accuracy: 0.9776 - val_loss: 1.0832 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.6961 - val_categorical_accuracy: 0.6500
# Epoch 22/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0617 - recall: 0.9701 - precision: 0.9701 - auc: 0.9968 - categorical_accuracy: 0.9701
# Epoch 00022: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 114ms/step - loss: 0.0617 - recall: 0.9701 - precision: 0.9701 - auc: 0.9968 - categorical_accuracy: 0.9701 - val_loss: 1.0492 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7539 - val_categorical_accuracy: 0.7100
# Epoch 23/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0495 - recall: 0.9850 - precision: 0.9850 - auc: 0.9974 - categorical_accuracy: 0.9850
# Epoch 00023: val_auc did not improve from 0.78270
# 41/41 [==============================] - 4s 106ms/step - loss: 0.0513 - recall: 0.9826 - precision: 0.9826 - auc: 0.9973 - categorical_accuracy: 0.9826 - val_loss: 0.9057 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7490 - val_categorical_accuracy: 0.7200
# Epoch 24/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0447 - recall: 0.9851 - precision: 0.9851 - auc: 0.9982 - categorical_accuracy: 0.9851
# Epoch 00024: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0447 - recall: 0.9851 - precision: 0.9851 - auc: 0.9982 - categorical_accuracy: 0.9851 - val_loss: 1.0406 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7637 - val_categorical_accuracy: 0.7400
# Epoch 25/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0449 - recall: 0.9801 - precision: 0.9801 - auc: 0.9986 - categorical_accuracy: 0.9801
# Epoch 00025: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 112ms/step - loss: 0.0449 - recall: 0.9801 - precision: 0.9801 - auc: 0.9986 - categorical_accuracy: 0.9801 - val_loss: 0.9697 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7103 - val_categorical_accuracy: 0.6400
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0299 - recall: 0.9925 - precision: 0.9925 - auc: 0.9997 - categorical_accuracy: 0.9925- ETA: 2s - loss: 0.0115 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categ
# Epoch 00026: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0321 - recall: 0.9900 - precision: 0.9900 - auc: 0.9996 - categorical_accuracy: 0.9900 - val_loss: 1.0636 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6687 - val_categorical_accuracy: 0.6200
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0312 - recall: 0.9850 - precision: 0.9850 - auc: 0.9994 - categorical_accuracy: 0.9850
# Epoch 00027: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0330 - recall: 0.9851 - precision: 0.9851 - auc: 0.9993 - categorical_accuracy: 0.9851 - val_loss: 0.9796 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7218 - val_categorical_accuracy: 0.6600
# Epoch 28/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0299 - recall: 0.9875 - precision: 0.9875 - auc: 0.9995 - categorical_accuracy: 0.9875- ETA: 3s - loss: 0.0160 - recall: 0.9923 - precision: 0.9923 - auc: 0.9999 - cat
# Epoch 00028: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 123ms/step - loss: 0.0316 - recall: 0.9876 - precision: 0.9876 - auc: 0.9994 - categorical_accuracy: 0.9876 - val_loss: 1.0276 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7140 - val_categorical_accuracy: 0.6700
# Epoch 29/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0257 - recall: 0.9900 - precision: 0.9900 - auc: 0.9997 - categorical_accuracy: 0.9900
# Epoch 00029: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0275 - recall: 0.9900 - precision: 0.9900 - auc: 0.9996 - categorical_accuracy: 0.9900 - val_loss: 1.0297 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7610 - val_categorical_accuracy: 0.6900
# Epoch 30/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0242 - recall: 0.9900 - precision: 0.9900 - auc: 0.9997 - categorical_accuracy: 0.9900
# Epoch 00030: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0260 - recall: 0.9900 - precision: 0.9900 - auc: 0.9996 - categorical_accuracy: 0.9900 - val_loss: 1.0216 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7653 - val_categorical_accuracy: 0.7000
# Epoch 31/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0237 - recall: 0.9851 - precision: 0.9851 - auc: 0.9997 - categorical_accuracy: 0.9851
# Epoch 00031: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0237 - recall: 0.9851 - precision: 0.9851 - auc: 0.9997 - categorical_accuracy: 0.9851 - val_loss: 0.9687 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7594 - val_categorical_accuracy: 0.7100
# Epoch 32/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0222 - recall: 0.9925 - precision: 0.9925 - auc: 0.9998 - categorical_accuracy: 0.9925- ETA: 1s - loss: 0.0069 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accu
# Epoch 00032: val_auc did not improve from 0.78270
# 41/41 [==============================] - 4s 105ms/step - loss: 0.0241 - recall: 0.9900 - precision: 0.9900 - auc: 0.9997 - categorical_accuracy: 0.9900 - val_loss: 1.0124 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7637 - val_categorical_accuracy: 0.7100
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0237 - recall: 0.9925 - precision: 0.9925 - auc: 0.9997 - categorical_accuracy: 0.9925
# Epoch 00033: val_auc did not improve from 0.78270
# 41/41 [==============================] - 4s 107ms/step - loss: 0.0254 - recall: 0.9925 - precision: 0.9925 - auc: 0.9996 - categorical_accuracy: 0.9925 - val_loss: 1.0581 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7680 - val_categorical_accuracy: 0.7200
# Epoch 34/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0193 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925
# Epoch 00034: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 113ms/step - loss: 0.0193 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925 - val_loss: 1.0249 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7558 - val_categorical_accuracy: 0.7000
# Epoch 35/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0182 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950
# Epoch 00035: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 110ms/step - loss: 0.0182 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950 - val_loss: 1.0472 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7640 - val_categorical_accuracy: 0.7000
# Epoch 36/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0155 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950
# Epoch 00036: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 110ms/step - loss: 0.0171 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950 - val_loss: 1.1008 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7642 - val_categorical_accuracy: 0.7100
# Epoch 37/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0158 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975
# Epoch 00037: val_auc did not improve from 0.78270
# 41/41 [==============================] - 4s 108ms/step - loss: 0.0158 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975 - val_loss: 1.0908 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7548 - val_categorical_accuracy: 0.7000
# Epoch 38/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0153 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950
# Epoch 00038: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 113ms/step - loss: 0.0153 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950 - val_loss: 1.0955 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7555 - val_categorical_accuracy: 0.7000
# Epoch 39/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0158 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00039: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 122ms/step - loss: 0.0158 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.1264 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7554 - val_categorical_accuracy: 0.6900
# Epoch 40/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0153 - recall: 0.9950 - precision: 0.9950 - auc: 0.9998 - categorical_accuracy: 0.9950
# Epoch 00040: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0168 - recall: 0.9950 - precision: 0.9950 - auc: 0.9998 - categorical_accuracy: 0.9950 - val_loss: 1.1400 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7531 - val_categorical_accuracy: 0.7000
# Epoch 41/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0152 - recall: 0.9900 - precision: 0.9900 - auc: 0.9998 - categorical_accuracy: 0.9900
# Epoch 00041: val_auc did not improve from 0.78270
# 41/41 [==============================] - 5s 119ms/step - loss: 0.0168 - recall: 0.9900 - precision: 0.9900 - auc: 0.9998 - categorical_accuracy: 0.9900 - val_loss: 1.1178 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7640 - val_categorical_accuracy: 0.7100
# Wall time: 4min 31s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 133 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.7345976233482361
# recall: 0.7599999904632568
# precision: 0.7599999904632568
# auc: 0.7826999425888062
# categorical_accuracy: 0.7599999904632568
#
# Wall time: 23.6 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.7261904761904762
# recall: 0.9838709677419355
# f1-score: 0.8356164383561643
# support: 62
#
#
# CN
# precision: 0.9375
# recall: 0.39473684210526316
# f1-score: 0.5555555555555556
# support: 38
#
#
# micro avg
# precision: 0.76
# recall: 0.76
# f1-score: 0.76
# support: 100
#
#
# macro avg
# precision: 0.8318452380952381
# recall: 0.6893039049235994
# f1-score: 0.69558599695586
# support: 100
#
#
# weighted avg
# precision: 0.8064880952380952
# recall: 0.76
# f1-score: 0.729193302891933
# support: 100
#
#
# samples avg
# precision: 0.76
# recall: 0.76
# f1-score: 0.76
# support: 100
#
#
# F1
# micro: 0.76
# macro: 0.69558599695586
#
#
# accuracy_score: 0.76
# sensitivity_score: 0.9838709677419355
# specificity_score: 0.39473684210526316
#
#
# Wall time: 21.1 s
