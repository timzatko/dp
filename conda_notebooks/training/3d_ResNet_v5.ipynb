# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise) + Batch Norm + Dropout (0.25)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201215-204801
# Wall time: 4.96 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet50V2'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
    'dropout': 0.25,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
#     'batch_norm': False,
    'batch_norm': True,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\applications\imagenet_utils.py:333: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 104 input channels.
#   str(input_shape[-1]) + ' input channels.')
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 1024)              25979712
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 26,642,498
# Trainable params: 26,593,986
# Non-trainable params: 48,512
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201215-204801
# checkpoint dir: ../../tmp\checkpoints\20201215-204801
# log dir: ../../tmp\logs\20201215-204801
# loading ../../tmp\data-v3\train-ResNet_x.npy, ../../tmp\data-v3\train-ResNet_y.npy...
# loading ../../tmp\data-v3\val-ResNet_x.npy, ../../tmp\data-v3\val-ResNet_y.npy...
# training...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 0.9805 - recall: 0.4627 - precision: 0.4627 - auc: 0.4848 - categorical_accuracy: 0.4627
# Epoch 00001: val_auc improved from -inf to 0.38000, saving model to ../../tmp\checkpoints\20201215-204801\cp-0001.ckpt
# 41/41 [==============================] - 9s 220ms/step - loss: 0.9805 - recall: 0.4627 - precision: 0.4627 - auc: 0.4848 - categorical_accuracy: 0.4627 - val_loss: 0.7241 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.9517 - recall: 0.4200 - precision: 0.4200 - auc: 0.3858 - categorical_accuracy: 0.4200
# Epoch 00002: val_auc improved from 0.38000 to 0.38380, saving model to ../../tmp\checkpoints\20201215-204801\cp-0002.ckpt
# 41/41 [==============================] - 7s 160ms/step - loss: 0.9502 - recall: 0.4204 - precision: 0.4204 - auc: 0.3855 - categorical_accuracy: 0.4204 - val_loss: 0.7108 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3838 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.8545 - recall: 0.5025 - precision: 0.5025 - auc: 0.4880 - categorical_accuracy: 0.5025
# Epoch 00003: val_auc did not improve from 0.38380
# 41/41 [==============================] - 6s 148ms/step - loss: 0.8542 - recall: 0.5025 - precision: 0.5025 - auc: 0.4870 - categorical_accuracy: 0.5025 - val_loss: 0.7011 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3828 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.8148 - recall: 0.5000 - precision: 0.5000 - auc: 0.5177 - categorical_accuracy: 0.5000
# Epoch 00004: val_auc improved from 0.38380 to 0.39860, saving model to ../../tmp\checkpoints\20201215-204801\cp-0004.ckpt
# 41/41 [==============================] - 7s 178ms/step - loss: 0.8141 - recall: 0.5000 - precision: 0.5000 - auc: 0.5170 - categorical_accuracy: 0.5000 - val_loss: 0.6974 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3986 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6468 - recall: 0.6575 - precision: 0.6575 - auc: 0.6970 - categorical_accuracy: 0.6575
# Epoch 00005: val_auc did not improve from 0.39860
# 41/41 [==============================] - 7s 169ms/step - loss: 0.6463 - recall: 0.6567 - precision: 0.6567 - auc: 0.6964 - categorical_accuracy: 0.6567 - val_loss: 0.6946 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3852 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6147 - recall: 0.6575 - precision: 0.6575 - auc: 0.7388 - categorical_accuracy: 0.6575
# Epoch 00006: val_auc improved from 0.39860 to 0.64940, saving model to ../../tmp\checkpoints\20201215-204801\cp-0006.ckpt
# 41/41 [==============================] - 9s 208ms/step - loss: 0.6147 - recall: 0.6542 - precision: 0.6542 - auc: 0.7377 - categorical_accuracy: 0.6542 - val_loss: 0.6917 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.6494 - val_categorical_accuracy: 0.6900
# Epoch 7/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4995 - recall: 0.7575 - precision: 0.7575 - auc: 0.8260 - categorical_accuracy: 0.7575
# Epoch 00007: val_auc did not improve from 0.64940
# 41/41 [==============================] - 6s 147ms/step - loss: 0.4998 - recall: 0.7562 - precision: 0.7562 - auc: 0.8252 - categorical_accuracy: 0.7562 - val_loss: 0.6905 - val_recall: 0.4400 - val_precision: 0.4400 - val_auc: 0.4854 - val_categorical_accuracy: 0.4400
# Epoch 8/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3731 - recall: 0.8259 - precision: 0.8259 - auc: 0.9000 - categorical_accuracy: 0.8259
# Epoch 00008: val_auc did not improve from 0.64940
# 41/41 [==============================] - 6s 157ms/step - loss: 0.3731 - recall: 0.8259 - precision: 0.8259 - auc: 0.9000 - categorical_accuracy: 0.8259 - val_loss: 0.6843 - val_recall: 0.6000 - val_precision: 0.6000 - val_auc: 0.6475 - val_categorical_accuracy: 0.6000
# Epoch 9/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3328 - recall: 0.8650 - precision: 0.8650 - auc: 0.9289 - categorical_accuracy: 0.8650
# Epoch 00009: val_auc improved from 0.64940 to 0.71060, saving model to ../../tmp\checkpoints\20201215-204801\cp-0009.ckpt
# 41/41 [==============================] - 7s 181ms/step - loss: 0.3397 - recall: 0.8632 - precision: 0.8632 - auc: 0.9258 - categorical_accuracy: 0.8632 - val_loss: 0.6888 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.7106 - val_categorical_accuracy: 0.6200
# Epoch 10/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3393 - recall: 0.8625 - precision: 0.8625 - auc: 0.9215 - categorical_accuracy: 0.8625
# Epoch 00010: val_auc improved from 0.71060 to 0.73040, saving model to ../../tmp\checkpoints\20201215-204801\cp-0010.ckpt
# 41/41 [==============================] - 7s 182ms/step - loss: 0.3402 - recall: 0.8607 - precision: 0.8607 - auc: 0.9209 - categorical_accuracy: 0.8607 - val_loss: 0.6774 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7304 - val_categorical_accuracy: 0.6600
# Epoch 11/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2990 - recall: 0.8700 - precision: 0.8700 - auc: 0.9401 - categorical_accuracy: 0.8700- ETA: 2s - loss: 0.2552 - recall: 0.8875 - precision: 0.8875 - auc: 0.9600 - categorical_accuracy: - ETA: 2s - loss: 0.2224 - recall: 0.8867 - precision: 0.8867 - auc: 0.9688 - cat
# Epoch 00011: val_auc did not improve from 0.73040
# 41/41 [==============================] - 5s 132ms/step - loss: 0.3038 - recall: 0.8682 - precision: 0.8682 - auc: 0.9381 - categorical_accuracy: 0.8682 - val_loss: 0.6879 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.7115 - val_categorical_accuracy: 0.6200
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2980 - recall: 0.8825 - precision: 0.8825 - auc: 0.9426 - categorical_accuracy: 0.8825
# Epoch 00012: val_auc did not improve from 0.73040
# 41/41 [==============================] - 6s 145ms/step - loss: 0.3018 - recall: 0.8806 - precision: 0.8806 - auc: 0.9402 - categorical_accuracy: 0.8806 - val_loss: 0.6757 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7132 - val_categorical_accuracy: 0.6600
# Epoch 13/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2077 - recall: 0.9150 - precision: 0.9150 - auc: 0.9706 - categorical_accuracy: 0.9150
# Epoch 00013: val_auc improved from 0.73040 to 0.75210, saving model to ../../tmp\checkpoints\20201215-204801\cp-0013.ckpt
# 41/41 [==============================] - 7s 179ms/step - loss: 0.2205 - recall: 0.9129 - precision: 0.9129 - auc: 0.9664 - categorical_accuracy: 0.9129 - val_loss: 0.6557 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7521 - val_categorical_accuracy: 0.6800
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2032 - recall: 0.9200 - precision: 0.9200 - auc: 0.9694 - categorical_accuracy: 0.9200
# Epoch 00014: val_auc improved from 0.75210 to 0.78290, saving model to ../../tmp\checkpoints\20201215-204801\cp-0014.ckpt
# 41/41 [==============================] - 8s 184ms/step - loss: 0.2143 - recall: 0.9179 - precision: 0.9179 - auc: 0.9652 - categorical_accuracy: 0.9179 - val_loss: 0.6255 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7829 - val_categorical_accuracy: 0.7300
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1832 - recall: 0.9375 - precision: 0.9375 - auc: 0.9766 - categorical_accuracy: 0.9375
# Epoch 00015: val_auc improved from 0.78290 to 0.79670, saving model to ../../tmp\checkpoints\20201215-204801\cp-0015.ckpt
# 41/41 [==============================] - 8s 203ms/step - loss: 0.1896 - recall: 0.9353 - precision: 0.9353 - auc: 0.9734 - categorical_accuracy: 0.9353 - val_loss: 0.6113 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.7967 - val_categorical_accuracy: 0.7600
# Epoch 16/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1574 - recall: 0.9225 - precision: 0.9225 - auc: 0.9830 - categorical_accuracy: 0.9225
# Epoch 00016: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 149ms/step - loss: 0.1727 - recall: 0.9204 - precision: 0.9204 - auc: 0.9788 - categorical_accuracy: 0.9204 - val_loss: 0.6126 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.6875 - val_categorical_accuracy: 0.6300
# Epoch 17/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1425 - recall: 0.9450 - precision: 0.9450 - auc: 0.9878 - categorical_accuracy: 0.9450
# Epoch 00017: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 152ms/step - loss: 0.1452 - recall: 0.9428 - precision: 0.9428 - auc: 0.9870 - categorical_accuracy: 0.9428 - val_loss: 0.5803 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7382 - val_categorical_accuracy: 0.6800
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0984 - recall: 0.9525 - precision: 0.9525 - auc: 0.9928 - categorical_accuracy: 0.9525- ETA: 1s - loss: 0.0766 - recall: 0.9593 - precision: 0.9593 - auc: 0.9972 - categorical_acc
# Epoch 00018: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1101 - recall: 0.9502 - precision: 0.9502 - auc: 0.9887 - categorical_accuracy: 0.9502 - val_loss: 0.7535 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6446 - val_categorical_accuracy: 0.6100
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1104 - recall: 0.9650 - precision: 0.9650 - auc: 0.9904 - categorical_accuracy: 0.9650
# Epoch 00019: val_auc did not improve from 0.79670
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1126 - recall: 0.9627 - precision: 0.9627 - auc: 0.9900 - categorical_accuracy: 0.9627 - val_loss: 0.6942 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7183 - val_categorical_accuracy: 0.6700
# Epoch 20/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0877 - recall: 0.9650 - precision: 0.9650 - auc: 0.9940 - categorical_accuracy: 0.9650
# Epoch 00020: val_auc did not improve from 0.79670
# 41/41 [==============================] - 5s 134ms/step - loss: 0.1060 - recall: 0.9627 - precision: 0.9627 - auc: 0.9901 - categorical_accuracy: 0.9627 - val_loss: 0.7625 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7039 - val_categorical_accuracy: 0.6400
# Epoch 21/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1095 - recall: 0.9650 - precision: 0.9650 - auc: 0.9923 - categorical_accuracy: 0.9650
# Epoch 00021: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 150ms/step - loss: 0.1123 - recall: 0.9627 - precision: 0.9627 - auc: 0.9918 - categorical_accuracy: 0.9627 - val_loss: 0.7221 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7647 - val_categorical_accuracy: 0.7000
# Epoch 22/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0699 - recall: 0.9775 - precision: 0.9775 - auc: 0.9955 - categorical_accuracy: 0.9775
# Epoch 00022: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 145ms/step - loss: 0.0837 - recall: 0.9751 - precision: 0.9751 - auc: 0.9916 - categorical_accuracy: 0.9751 - val_loss: 0.6946 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7836 - val_categorical_accuracy: 0.7200
# Epoch 23/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0859 - recall: 0.9775 - precision: 0.9775 - auc: 0.9940 - categorical_accuracy: 0.9775
# Epoch 00023: val_auc did not improve from 0.79670
# 41/41 [==============================] - 5s 131ms/step - loss: 0.0946 - recall: 0.9751 - precision: 0.9751 - auc: 0.9911 - categorical_accuracy: 0.9751 - val_loss: 0.8085 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7789 - val_categorical_accuracy: 0.6900
# Epoch 24/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0746 - recall: 0.9875 - precision: 0.9875 - auc: 0.9953 - categorical_accuracy: 0.9875- ETA: 3s - loss: 0.0506 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1. - ETA: 2s - loss: 0.0476 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categ
# Epoch 00024: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0765 - recall: 0.9851 - precision: 0.9851 - auc: 0.9952 - categorical_accuracy: 0.9851 - val_loss: 0.8428 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7693 - val_categorical_accuracy: 0.7000
# Epoch 25/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0579 - recall: 0.9850 - precision: 0.9850 - auc: 0.9973 - categorical_accuracy: 0.9850
# Epoch 00025: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0641 - recall: 0.9826 - precision: 0.9826 - auc: 0.9965 - categorical_accuracy: 0.9826 - val_loss: 0.7094 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7648 - val_categorical_accuracy: 0.7000
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0606 - recall: 0.9850 - precision: 0.9850 - auc: 0.9968 - categorical_accuracy: 0.9850- ETA: 1s - loss: 0.0628 - recall: 0.9812 - precision: 0.9812 - auc: 0.9962 - categorical_accuracy
# Epoch 00026: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0621 - recall: 0.9826 - precision: 0.9826 - auc: 0.9967 - categorical_accuracy: 0.9826 - val_loss: 0.6791 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7519 - val_categorical_accuracy: 0.7300
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0566 - recall: 0.9850 - precision: 0.9850 - auc: 0.9969 - categorical_accuracy: 0.9850
# Epoch 00027: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0652 - recall: 0.9826 - precision: 0.9826 - auc: 0.9949 - categorical_accuracy: 0.9826 - val_loss: 0.8255 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7256 - val_categorical_accuracy: 0.6700
# Epoch 28/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0556 - recall: 0.9900 - precision: 0.9900 - auc: 0.9984 - categorical_accuracy: 0.9900
# Epoch 00028: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0579 - recall: 0.9876 - precision: 0.9876 - auc: 0.9983 - categorical_accuracy: 0.9876 - val_loss: 0.7856 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7550 - val_categorical_accuracy: 0.6800
# Epoch 29/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0467 - recall: 0.9825 - precision: 0.9825 - auc: 0.9989 - categorical_accuracy: 0.9825
# Epoch 00029: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0507 - recall: 0.9801 - precision: 0.9801 - auc: 0.9985 - categorical_accuracy: 0.9801 - val_loss: 0.7211 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7706 - val_categorical_accuracy: 0.7000
# Epoch 30/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0490 - recall: 0.9875 - precision: 0.9875 - auc: 0.9974 - categorical_accuracy: 0.9875- ETA: 2s - loss: 0.0215 - recall: 0.9941 - precision: 0.9941 - auc: 0.9999 - categ
# Epoch 00030: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0536 - recall: 0.9851 - precision: 0.9851 - auc: 0.9970 - categorical_accuracy: 0.9851 - val_loss: 0.7633 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7614 - val_categorical_accuracy: 0.7000
# Epoch 31/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0453 - recall: 0.9875 - precision: 0.9875 - auc: 0.9958 - categorical_accuracy: 0.9875
# Epoch 00031: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0540 - recall: 0.9851 - precision: 0.9851 - auc: 0.9940 - categorical_accuracy: 0.9851 - val_loss: 0.8146 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7857 - val_categorical_accuracy: 0.7200
# Epoch 32/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0364 - recall: 0.9925 - precision: 0.9925 - auc: 0.9998 - categorical_accuracy: 0.9925- ETA: 1s - loss: 0.0248 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accur
# Epoch 00032: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0376 - recall: 0.9925 - precision: 0.9925 - auc: 0.9998 - categorical_accuracy: 0.9925 - val_loss: 0.7658 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7815 - val_categorical_accuracy: 0.6800
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0274 - recall: 0.9875 - precision: 0.9875 - auc: 0.9998 - categorical_accuracy: 0.9875
# Epoch 00033: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0288 - recall: 0.9851 - precision: 0.9851 - auc: 0.9997 - categorical_accuracy: 0.9851 - val_loss: 0.8102 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7726 - val_categorical_accuracy: 0.6800
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0249 - recall: 0.9900 - precision: 0.9900 - auc: 0.9996 - categorical_accuracy: 0.9900
# Epoch 00034: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 139ms/step - loss: 0.0261 - recall: 0.9900 - precision: 0.9900 - auc: 0.9996 - categorical_accuracy: 0.9900 - val_loss: 0.8220 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7521 - val_categorical_accuracy: 0.6700
# Epoch 35/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0249 - recall: 0.9925 - precision: 0.9925 - auc: 0.9993 - categorical_accuracy: 0.9925
# Epoch 00035: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0262 - recall: 0.9925 - precision: 0.9925 - auc: 0.9993 - categorical_accuracy: 0.9925 - val_loss: 0.8476 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7646 - val_categorical_accuracy: 0.6800
# Epoch 36/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0181 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925
# Epoch 00036: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0187 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925 - val_loss: 0.8743 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7754 - val_categorical_accuracy: 0.6800
# Epoch 37/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0226 - recall: 0.9875 - precision: 0.9875 - auc: 0.9997 - categorical_accuracy: 0.9875
# Epoch 00037: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0238 - recall: 0.9876 - precision: 0.9876 - auc: 0.9996 - categorical_accuracy: 0.9876 - val_loss: 0.8478 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7693 - val_categorical_accuracy: 0.7100
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0246 - recall: 0.9875 - precision: 0.9875 - auc: 0.9996 - categorical_accuracy: 0.9875
# Epoch 00038: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0262 - recall: 0.9876 - precision: 0.9876 - auc: 0.9996 - categorical_accuracy: 0.9876 - val_loss: 0.8426 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7658 - val_categorical_accuracy: 0.7200
# Epoch 39/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0194 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950- ETA: 2s - loss: 0.0075 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - catego
# Epoch 00039: val_auc did not improve from 0.79670
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0205 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950 - val_loss: 0.8332 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7555 - val_categorical_accuracy: 0.6500
# Epoch 40/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0249 - recall: 0.9875 - precision: 0.9875 - auc: 0.9996 - categorical_accuracy: 0.9875
# Epoch 00040: val_auc did not improve from 0.79670
# 41/41 [==============================] - 7s 164ms/step - loss: 0.0271 - recall: 0.9876 - precision: 0.9876 - auc: 0.9996 - categorical_accuracy: 0.9876 - val_loss: 0.7957 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7639 - val_categorical_accuracy: 0.6800
# Wall time: 5min 41s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 135 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.5532732009887695
# recall: 0.7599999904632568
# precision: 0.7599999904632568
# auc: 0.7966999411582947
# categorical_accuracy: 0.7599999904632568
#
# Wall time: 27.2 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.75
# recall: 0.9193548387096774
# f1-score: 0.826086956521739
# support: 62
#
#
# CN
# precision: 0.7916666666666666
# recall: 0.5
# f1-score: 0.6129032258064516
# support: 38
#
#
# micro avg
# precision: 0.76
# recall: 0.76
# f1-score: 0.76
# support: 100
#
#
# macro avg
# precision: 0.7708333333333333
# recall: 0.7096774193548387
# f1-score: 0.7194950911640954
# support: 100
#
#
# weighted avg
# precision: 0.7658333333333333
# recall: 0.76
# f1-score: 0.7450771388499298
# support: 100
#
#
# samples avg
# precision: 0.76
# recall: 0.76
# f1-score: 0.76
# support: 100
#
#
# F1
# micro: 0.76
# macro: 0.7194950911640954
#
#
# accuracy_score: 0.76
# sensitivity_score: 0.9193548387096774
# specificity_score: 0.5
#
#
# Wall time: 22.4 s
