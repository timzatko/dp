# %% [markdown]
# # 3D CNN

# %% [markdown]
# Basic.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

# RANDOM_SEED = 421949639000
# tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201217-203227
# Wall time: 0 ns

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = '3d_deep'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'dropout': 0.10,
    'dropout': 0.70,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
    'batch_norm': True,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 100,
    'patience': 25,
    'tensorboard_update_freq': 'epoch', 
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_categorical_accuracy', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_categorical_accuracy', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
    'batch_size': 10,
#     'dataset_key': '3d_deep',
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 52, 64, 52, 16)    2016
# _________________________________________________________________
# batch_normalization (BatchNo (None, 52, 64, 52, 16)    64
# _________________________________________________________________
# activation (Activation)      (None, 52, 64, 52, 16)    0
# _________________________________________________________________
# basic_block (BasicBlock)     (None, 52, 64, 52, 16)    13984
# _________________________________________________________________
# basic_block_1 (BasicBlock)   (None, 52, 64, 52, 16)    13984
# _________________________________________________________________
# basic_block_2 (BasicBlock)   (None, 26, 32, 26, 16)    14256
# _________________________________________________________________
# basic_block_3 (BasicBlock)   (None, 26, 32, 26, 32)    42336
# _________________________________________________________________
# basic_block_4 (BasicBlock)   (None, 26, 32, 26, 32)    55616
# _________________________________________________________________
# basic_block_5 (BasicBlock)   (None, 26, 32, 26, 32)    55616
# _________________________________________________________________
# basic_block_6 (BasicBlock)   (None, 13, 16, 13, 32)    56672
# _________________________________________________________________
# basic_block_7 (BasicBlock)   (None, 13, 16, 13, 64)    168640
# _________________________________________________________________
# basic_block_8 (BasicBlock)   (None, 13, 16, 13, 64)    221824
# _________________________________________________________________
# basic_block_9 (BasicBlock)   (None, 13, 16, 13, 64)    221824
# _________________________________________________________________
# basic_block_10 (BasicBlock)  (None, 13, 16, 13, 64)    221824
# _________________________________________________________________
# basic_block_11 (BasicBlock)  (None, 13, 16, 13, 64)    221824
# _________________________________________________________________
# basic_block_12 (BasicBlock)  (None, 7, 8, 7, 64)       225984
# _________________________________________________________________
# basic_block_13 (BasicBlock)  (None, 7, 8, 7, 128)      673152
# _________________________________________________________________
# basic_block_14 (BasicBlock)  (None, 7, 8, 7, 128)      886016
# _________________________________________________________________
# basic_block_15 (BasicBlock)  (None, 7, 8, 7, 128)      886016
# _________________________________________________________________
# basic_block_16 (BasicBlock)  (None, 7, 8, 7, 128)      886016
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 8, 7, 128)      0
# _________________________________________________________________
# global_average_pooling3d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,884,434
# Trainable params: 4,880,114
# Non-trainable params: 4,320
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201217-203227
# checkpoint dir: ../../tmp\checkpoints\20201217-203227
# log dir: ../../tmp\logs\20201217-203227
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer BasicBlock has arguments in `__init__` and therefore must override `get_config`.
# Epoch 1/100
#  2/41 [>.............................] - ETA: 9s - loss: 0.7932 - recall: 0.7500 - precision: 0.7500 - auc: 0.6425 - categorical_accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1671s vs `on_train_batch_end` time: 0.3043s). Check your callbacks.
# 41/41 [==============================] - ETA: 0s - loss: 0.7907 - recall: 0.5174 - precision: 0.5174 - auc: 0.5312 - categorical_accuracy: 0.5174
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.38000, saving model to ../../tmp\checkpoints\20201217-203227\cp-0001.ckpt
# 41/41 [==============================] - 22s 542ms/step - loss: 0.7907 - recall: 0.5174 - precision: 0.5174 - auc: 0.5312 - categorical_accuracy: 0.5174 - val_loss: 0.8389 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 2/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7568 - recall: 0.4751 - precision: 0.4751 - auc: 0.4707 - categorical_accuracy: 0.4751
# Epoch 00002: val_categorical_accuracy did not improve from 0.38000
# 41/41 [==============================] - 20s 498ms/step - loss: 0.7568 - recall: 0.4751 - precision: 0.4751 - auc: 0.4707 - categorical_accuracy: 0.4751 - val_loss: 0.7361 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4250 - val_categorical_accuracy: 0.3800
# Epoch 3/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7317 - recall: 0.5174 - precision: 0.5174 - auc: 0.5115 - categorical_accuracy: 0.5174
# Epoch 00003: val_categorical_accuracy did not improve from 0.38000
# 41/41 [==============================] - 21s 500ms/step - loss: 0.7317 - recall: 0.5174 - precision: 0.5174 - auc: 0.5115 - categorical_accuracy: 0.5174 - val_loss: 0.7049 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 4/100
# 41/41 [==============================] - ETA: 0s - loss: 0.7234 - recall: 0.5100 - precision: 0.5100 - auc: 0.5232 - categorical_accuracy: 0.5100
# Epoch 00004: val_categorical_accuracy did not improve from 0.38000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.7234 - recall: 0.5100 - precision: 0.5100 - auc: 0.5232 - categorical_accuracy: 0.5100 - val_loss: 0.7351 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 5/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6968 - recall: 0.5398 - precision: 0.5398 - auc: 0.5717 - categorical_accuracy: 0.5398
# Epoch 00005: val_categorical_accuracy did not improve from 0.38000
# 41/41 [==============================] - 20s 500ms/step - loss: 0.6968 - recall: 0.5398 - precision: 0.5398 - auc: 0.5717 - categorical_accuracy: 0.5398 - val_loss: 0.8064 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3550 - val_categorical_accuracy: 0.3800
# Epoch 6/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6817 - recall: 0.5871 - precision: 0.5871 - auc: 0.6194 - categorical_accuracy: 0.5871
# Epoch 00006: val_categorical_accuracy did not improve from 0.38000
# 41/41 [==============================] - 21s 500ms/step - loss: 0.6817 - recall: 0.5871 - precision: 0.5871 - auc: 0.6194 - categorical_accuracy: 0.5871 - val_loss: 0.7824 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3193 - val_categorical_accuracy: 0.3800
# Epoch 7/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6388 - recall: 0.6866 - precision: 0.6866 - auc: 0.7056 - categorical_accuracy: 0.6866
# Epoch 00007: val_categorical_accuracy improved from 0.38000 to 0.62000, saving model to ../../tmp\checkpoints\20201217-203227\cp-0007.ckpt
# 41/41 [==============================] - 21s 510ms/step - loss: 0.6388 - recall: 0.6866 - precision: 0.6866 - auc: 0.7056 - categorical_accuracy: 0.6866 - val_loss: 0.6955 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6324 - val_categorical_accuracy: 0.6200
# Epoch 8/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6066 - recall: 0.6965 - precision: 0.6965 - auc: 0.7399 - categorical_accuracy: 0.6965
# Epoch 00008: val_categorical_accuracy did not improve from 0.62000
# 41/41 [==============================] - 21s 505ms/step - loss: 0.6066 - recall: 0.6965 - precision: 0.6965 - auc: 0.7399 - categorical_accuracy: 0.6965 - val_loss: 0.7255 - val_recall: 0.5600 - val_precision: 0.5600 - val_auc: 0.5723 - val_categorical_accuracy: 0.5600
# Epoch 9/100
# 41/41 [==============================] - ETA: 0s - loss: 0.6080 - recall: 0.6940 - precision: 0.6940 - auc: 0.7481 - categorical_accuracy: 0.6940
# Epoch 00009: val_categorical_accuracy did not improve from 0.62000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.6080 - recall: 0.6940 - precision: 0.6940 - auc: 0.7481 - categorical_accuracy: 0.6940 - val_loss: 0.8889 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6297 - val_categorical_accuracy: 0.6200
# Epoch 10/100
# 41/41 [==============================] - ETA: 0s - loss: 0.5373 - recall: 0.7313 - precision: 0.7313 - auc: 0.8085 - categorical_accuracy: 0.7313
# Epoch 00010: val_categorical_accuracy did not improve from 0.62000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.5373 - recall: 0.7313 - precision: 0.7313 - auc: 0.8085 - categorical_accuracy: 0.7313 - val_loss: 0.8297 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3749 - val_categorical_accuracy: 0.3800
# Epoch 11/100
# 41/41 [==============================] - ETA: 0s - loss: 0.4300 - recall: 0.8234 - precision: 0.8234 - auc: 0.8913 - categorical_accuracy: 0.8234
# Epoch 00011: val_categorical_accuracy did not improve from 0.62000
# 41/41 [==============================] - 21s 501ms/step - loss: 0.4300 - recall: 0.8234 - precision: 0.8234 - auc: 0.8913 - categorical_accuracy: 0.8234 - val_loss: 1.0734 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3650 - val_categorical_accuracy: 0.3800
# Epoch 12/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3770 - recall: 0.8308 - precision: 0.8308 - auc: 0.9118 - categorical_accuracy: 0.8308
# Epoch 00012: val_categorical_accuracy did not improve from 0.62000
# 41/41 [==============================] - 21s 502ms/step - loss: 0.3770 - recall: 0.8308 - precision: 0.8308 - auc: 0.9118 - categorical_accuracy: 0.8308 - val_loss: 0.8884 - val_recall: 0.4100 - val_precision: 0.4100 - val_auc: 0.4038 - val_categorical_accuracy: 0.4100
# Epoch 13/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3792 - recall: 0.8358 - precision: 0.8358 - auc: 0.9113 - categorical_accuracy: 0.8358
# Epoch 00013: val_categorical_accuracy improved from 0.62000 to 0.65000, saving model to ../../tmp\checkpoints\20201217-203227\cp-0013.ckpt
# 41/41 [==============================] - 21s 518ms/step - loss: 0.3792 - recall: 0.8358 - precision: 0.8358 - auc: 0.9113 - categorical_accuracy: 0.8358 - val_loss: 1.5087 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.6700 - val_categorical_accuracy: 0.6500
# Epoch 14/100
# 41/41 [==============================] - ETA: 0s - loss: 0.3033 - recall: 0.8831 - precision: 0.8831 - auc: 0.9448 - categorical_accuracy: 0.8831
# Epoch 00014: val_categorical_accuracy did not improve from 0.65000
# 41/41 [==============================] - 21s 508ms/step - loss: 0.3033 - recall: 0.8831 - precision: 0.8831 - auc: 0.9448 - categorical_accuracy: 0.8831 - val_loss: 2.2800 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6682 - val_categorical_accuracy: 0.6200
# Epoch 15/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2416 - recall: 0.9055 - precision: 0.9055 - auc: 0.9630 - categorical_accuracy: 0.9055
# Epoch 00015: val_categorical_accuracy improved from 0.65000 to 0.68000, saving model to ../../tmp\checkpoints\20201217-203227\cp-0015.ckpt
# 41/41 [==============================] - 21s 517ms/step - loss: 0.2416 - recall: 0.9055 - precision: 0.9055 - auc: 0.9630 - categorical_accuracy: 0.9055 - val_loss: 1.4793 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.6907 - val_categorical_accuracy: 0.6800
# Epoch 16/100
# 41/41 [==============================] - ETA: 0s - loss: 0.2115 - recall: 0.9229 - precision: 0.9229 - auc: 0.9723 - categorical_accuracy: 0.9229
# Epoch 00016: val_categorical_accuracy did not improve from 0.68000
# 41/41 [==============================] - 21s 506ms/step - loss: 0.2115 - recall: 0.9229 - precision: 0.9229 - auc: 0.9723 - categorical_accuracy: 0.9229 - val_loss: 1.6872 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7040 - val_categorical_accuracy: 0.6600
# Epoch 17/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1602 - recall: 0.9403 - precision: 0.9403 - auc: 0.9873 - categorical_accuracy: 0.9403
# Epoch 00017: val_categorical_accuracy did not improve from 0.68000
# 41/41 [==============================] - 21s 507ms/step - loss: 0.1602 - recall: 0.9403 - precision: 0.9403 - auc: 0.9873 - categorical_accuracy: 0.9403 - val_loss: 1.5059 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7227 - val_categorical_accuracy: 0.6800
# Epoch 18/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1643 - recall: 0.9378 - precision: 0.9378 - auc: 0.9796 - categorical_accuracy: 0.9378
# Epoch 00018: val_categorical_accuracy improved from 0.68000 to 0.71000, saving model to ../../tmp\checkpoints\20201217-203227\cp-0018.ckpt
# 41/41 [==============================] - 21s 512ms/step - loss: 0.1643 - recall: 0.9378 - precision: 0.9378 - auc: 0.9796 - categorical_accuracy: 0.9378 - val_loss: 1.9681 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7593 - val_categorical_accuracy: 0.7100
# Epoch 19/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1494 - recall: 0.9478 - precision: 0.9478 - auc: 0.9861 - categorical_accuracy: 0.9478
# Epoch 00019: val_categorical_accuracy did not improve from 0.71000
# 41/41 [==============================] - 21s 500ms/step - loss: 0.1494 - recall: 0.9478 - precision: 0.9478 - auc: 0.9861 - categorical_accuracy: 0.9478 - val_loss: 1.0974 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7330 - val_categorical_accuracy: 0.6900
# Epoch 20/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1055 - recall: 0.9801 - precision: 0.9801 - auc: 0.9944 - categorical_accuracy: 0.9801
# Epoch 00020: val_categorical_accuracy improved from 0.71000 to 0.74000, saving model to ../../tmp\checkpoints\20201217-203227\cp-0020.ckpt
# 41/41 [==============================] - 21s 515ms/step - loss: 0.1055 - recall: 0.9801 - precision: 0.9801 - auc: 0.9944 - categorical_accuracy: 0.9801 - val_loss: 1.0941 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7721 - val_categorical_accuracy: 0.7400
# Epoch 21/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0756 - recall: 0.9776 - precision: 0.9776 - auc: 0.9969 - categorical_accuracy: 0.9776
# Epoch 00021: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 501ms/step - loss: 0.0756 - recall: 0.9776 - precision: 0.9776 - auc: 0.9969 - categorical_accuracy: 0.9776 - val_loss: 1.1815 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7632 - val_categorical_accuracy: 0.7100
# Epoch 22/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0667 - recall: 0.9751 - precision: 0.9751 - auc: 0.9979 - categorical_accuracy: 0.9751
# Epoch 00022: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 500ms/step - loss: 0.0667 - recall: 0.9751 - precision: 0.9751 - auc: 0.9979 - categorical_accuracy: 0.9751 - val_loss: 1.7381 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7557 - val_categorical_accuracy: 0.7300
# Epoch 23/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0769 - recall: 0.9751 - precision: 0.9751 - auc: 0.9969 - categorical_accuracy: 0.9751
# Epoch 00023: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0769 - recall: 0.9751 - precision: 0.9751 - auc: 0.9969 - categorical_accuracy: 0.9751 - val_loss: 1.6190 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7653 - val_categorical_accuracy: 0.7200
# Epoch 24/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0999 - recall: 0.9701 - precision: 0.9701 - auc: 0.9944 - categorical_accuracy: 0.9701
# Epoch 00024: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 500ms/step - loss: 0.0999 - recall: 0.9701 - precision: 0.9701 - auc: 0.9944 - categorical_accuracy: 0.9701 - val_loss: 1.5718 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7253 - val_categorical_accuracy: 0.6700
# Epoch 25/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0805 - recall: 0.9677 - precision: 0.9677 - auc: 0.9950 - categorical_accuracy: 0.9677
# Epoch 00025: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 498ms/step - loss: 0.0805 - recall: 0.9677 - precision: 0.9677 - auc: 0.9950 - categorical_accuracy: 0.9677 - val_loss: 1.1311 - val_recall: 0.5700 - val_precision: 0.5700 - val_auc: 0.6417 - val_categorical_accuracy: 0.5700
# Epoch 26/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0452 - recall: 0.9876 - precision: 0.9876 - auc: 0.9995 - categorical_accuracy: 0.9876
# Epoch 00026: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 501ms/step - loss: 0.0452 - recall: 0.9876 - precision: 0.9876 - auc: 0.9995 - categorical_accuracy: 0.9876 - val_loss: 1.3110 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7501 - val_categorical_accuracy: 0.6600
# Epoch 27/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0443 - recall: 0.9876 - precision: 0.9876 - auc: 0.9994 - categorical_accuracy: 0.9876
# Epoch 00027: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 498ms/step - loss: 0.0443 - recall: 0.9876 - precision: 0.9876 - auc: 0.9994 - categorical_accuracy: 0.9876 - val_loss: 1.2947 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6881 - val_categorical_accuracy: 0.6400
# Epoch 28/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0338 - recall: 0.9876 - precision: 0.9876 - auc: 0.9996 - categorical_accuracy: 0.9876
# Epoch 00028: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0338 - recall: 0.9876 - precision: 0.9876 - auc: 0.9996 - categorical_accuracy: 0.9876 - val_loss: 1.1893 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6921 - val_categorical_accuracy: 0.6400
# Epoch 29/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0219 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975
# Epoch 00029: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 501ms/step - loss: 0.0219 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975 - val_loss: 1.1377 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7765 - val_categorical_accuracy: 0.6800
# Epoch 30/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0432 - recall: 0.9851 - precision: 0.9851 - auc: 0.9992 - categorical_accuracy: 0.9851
# Epoch 00030: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 500ms/step - loss: 0.0432 - recall: 0.9851 - precision: 0.9851 - auc: 0.9992 - categorical_accuracy: 0.9851 - val_loss: 1.4324 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7410 - val_categorical_accuracy: 0.7000
# Epoch 31/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0362 - recall: 0.9950 - precision: 0.9950 - auc: 0.9994 - categorical_accuracy: 0.9950
# Epoch 00031: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 498ms/step - loss: 0.0362 - recall: 0.9950 - precision: 0.9950 - auc: 0.9994 - categorical_accuracy: 0.9950 - val_loss: 1.3447 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7608 - val_categorical_accuracy: 0.6900
# Epoch 32/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0218 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925
# Epoch 00032: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 502ms/step - loss: 0.0218 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925 - val_loss: 1.2893 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7841 - val_categorical_accuracy: 0.7300
# Epoch 33/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0217 - recall: 0.9950 - precision: 0.9950 - auc: 0.9998 - categorical_accuracy: 0.9950
# Epoch 00033: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 500ms/step - loss: 0.0217 - recall: 0.9950 - precision: 0.9950 - auc: 0.9998 - categorical_accuracy: 0.9950 - val_loss: 1.4019 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7747 - val_categorical_accuracy: 0.7200
# Epoch 34/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0181 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950
# Epoch 00034: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 501ms/step - loss: 0.0181 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950 - val_loss: 1.3312 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7742 - val_categorical_accuracy: 0.7100
# Epoch 35/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0088 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00035: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0088 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2689 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7809 - val_categorical_accuracy: 0.7100
# Epoch 36/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0112 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00036: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0112 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2888 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7718 - val_categorical_accuracy: 0.6800
# Epoch 37/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0058 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00037: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0058 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3608 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7748 - val_categorical_accuracy: 0.7200
# Epoch 38/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0141 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950
# Epoch 00038: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0141 - recall: 0.9950 - precision: 0.9950 - auc: 0.9999 - categorical_accuracy: 0.9950 - val_loss: 1.4339 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7790 - val_categorical_accuracy: 0.7200
# Epoch 39/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0080 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00039: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0080 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4256 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7601 - val_categorical_accuracy: 0.6800
# Epoch 40/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0092 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00040: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0092 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.3558 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7407 - val_categorical_accuracy: 0.6600
# Epoch 41/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0049 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00041: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 499ms/step - loss: 0.0049 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3639 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7301 - val_categorical_accuracy: 0.6800
# Epoch 42/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0102 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00042: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 20s 500ms/step - loss: 0.0102 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.2882 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7463 - val_categorical_accuracy: 0.6900
# Epoch 43/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0070 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00043: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 503ms/step - loss: 0.0070 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2953 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7609 - val_categorical_accuracy: 0.7100
# Epoch 44/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0084 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00044: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 507ms/step - loss: 0.0084 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.3023 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7588 - val_categorical_accuracy: 0.6800
# Epoch 45/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0085 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00045: val_categorical_accuracy did not improve from 0.74000
# 41/41 [==============================] - 21s 507ms/step - loss: 0.0085 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.3173 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7773 - val_categorical_accuracy: 0.7300
# Wall time: 17min 6s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 138 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.9428677558898926
# recall: 0.7400000095367432
# precision: 0.7400000095367432
# auc: 0.772100031375885
# categorical_accuracy: 0.7400000095367432
#
# Wall time: 24.7 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.78125
# recall: 0.8064516129032258
# f1-score: 0.7936507936507936
# support: 62
#
#
# CN
# precision: 0.6666666666666666
# recall: 0.631578947368421
# f1-score: 0.6486486486486486
# support: 38
#
#
# micro avg
# precision: 0.74
# recall: 0.74
# f1-score: 0.74
# support: 100
#
#
# macro avg
# precision: 0.7239583333333333
# recall: 0.7190152801358234
# f1-score: 0.7211497211497211
# support: 100
#
#
# weighted avg
# precision: 0.7377083333333333
# recall: 0.74
# f1-score: 0.7385499785499785
# support: 100
#
#
# samples avg
# precision: 0.74
# recall: 0.74
# f1-score: 0.74
# support: 100
#
#
# F1
# micro: 0.74
# macro: 0.7211497211497211
#
#
# accuracy_score: 0.74
# sensitivity_score: 0.8064516129032258
# specificity_score: 0.631578947368421
#
#
# Wall time: 23.3 s
