# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201216-142654
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.10,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 104, 128, 104)     0
# _________________________________________________________________
# my_res_net (MyResNet)        (None, 1024)              12032960
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 12,689,602
# Trainable params: 12,680,002
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201216-142654
# checkpoint dir: ../../tmp\checkpoints\20201216-142654
# log dir: ../../tmp\logs\20201216-142654
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 0.8017 - recall: 0.4900 - precision: 0.4900 - auc: 0.4874 - categorical_accuracy: 0.4900
# Epoch 00001: val_auc improved from -inf to 0.39140, saving model to ../../tmp\checkpoints\20201216-142654\cp-0001.ckpt
# 41/41 [==============================] - 6s 153ms/step - loss: 0.8017 - recall: 0.4900 - precision: 0.4900 - auc: 0.4874 - categorical_accuracy: 0.4900 - val_loss: 0.7586 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3914 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 41/41 [==============================] - ETA: 0s - loss: 0.7178 - recall: 0.5423 - precision: 0.5423 - auc: 0.5485 - categorical_accuracy: 0.5423
# Epoch 00002: val_auc did not improve from 0.39140
# 41/41 [==============================] - 4s 107ms/step - loss: 0.7178 - recall: 0.5423 - precision: 0.5423 - auc: 0.5485 - categorical_accuracy: 0.5423 - val_loss: 0.7161 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3072 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6855 - recall: 0.6075 - precision: 0.6075 - auc: 0.6284 - categorical_accuracy: 0.6075- ETA: 1s - loss: 0.6576 - recall: 0.6048 - precision: 0.6048 - auc: 0.6463 - categorical
# Epoch 00003: val_auc did not improve from 0.39140
# 41/41 [==============================] - 5s 122ms/step - loss: 0.6853 - recall: 0.6070 - precision: 0.6070 - auc: 0.6275 - categorical_accuracy: 0.6070 - val_loss: 0.7478 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.2802 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6550 - recall: 0.6617 - precision: 0.6617 - auc: 0.7054 - categorical_accuracy: 0.6617
# Epoch 00004: val_auc improved from 0.39140 to 0.66150, saving model to ../../tmp\checkpoints\20201216-142654\cp-0004.ckpt
# 41/41 [==============================] - 5s 130ms/step - loss: 0.6550 - recall: 0.6617 - precision: 0.6617 - auc: 0.7054 - categorical_accuracy: 0.6617 - val_loss: 0.6882 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6615 - val_categorical_accuracy: 0.6100
# Epoch 5/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6165 - recall: 0.6965 - precision: 0.6965 - auc: 0.7335 - categorical_accuracy: 0.6965
# Epoch 00005: val_auc did not improve from 0.66150
# 41/41 [==============================] - 5s 113ms/step - loss: 0.6165 - recall: 0.6965 - precision: 0.6965 - auc: 0.7335 - categorical_accuracy: 0.6965 - val_loss: 0.7857 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4589 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5568 - recall: 0.7325 - precision: 0.7325 - auc: 0.7982 - categorical_accuracy: 0.7325
# Epoch 00006: val_auc improved from 0.66150 to 0.70770, saving model to ../../tmp\checkpoints\20201216-142654\cp-0006.ckpt
# 41/41 [==============================] - 6s 135ms/step - loss: 0.5581 - recall: 0.7313 - precision: 0.7313 - auc: 0.7961 - categorical_accuracy: 0.7313 - val_loss: 0.7605 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7077 - val_categorical_accuracy: 0.6500
# Epoch 7/200
# 41/41 [==============================] - ETA: 0s - loss: 0.4990 - recall: 0.7587 - precision: 0.7587 - auc: 0.8373 - categorical_accuracy: 0.7587
# Epoch 00007: val_auc did not improve from 0.70770
# 41/41 [==============================] - 4s 109ms/step - loss: 0.4990 - recall: 0.7587 - precision: 0.7587 - auc: 0.8373 - categorical_accuracy: 0.7587 - val_loss: 0.8740 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4077 - val_categorical_accuracy: 0.3800
# Epoch 8/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4632 - recall: 0.7900 - precision: 0.7900 - auc: 0.8606 - categorical_accuracy: 0.7900
# Epoch 00008: val_auc did not improve from 0.70770
# 41/41 [==============================] - 5s 115ms/step - loss: 0.4648 - recall: 0.7886 - precision: 0.7886 - auc: 0.8587 - categorical_accuracy: 0.7886 - val_loss: 0.7175 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6933 - val_categorical_accuracy: 0.6200
# Epoch 9/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4196 - recall: 0.7975 - precision: 0.7975 - auc: 0.8888 - categorical_accuracy: 0.7975
# Epoch 00009: val_auc did not improve from 0.70770
# 41/41 [==============================] - 5s 117ms/step - loss: 0.4215 - recall: 0.7960 - precision: 0.7960 - auc: 0.8872 - categorical_accuracy: 0.7960 - val_loss: 0.8656 - val_recall: 0.5100 - val_precision: 0.5100 - val_auc: 0.5965 - val_categorical_accuracy: 0.5100
# Epoch 10/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3564 - recall: 0.8425 - precision: 0.8425 - auc: 0.9139 - categorical_accuracy: 0.8425
# Epoch 00010: val_auc did not improve from 0.70770
# 41/41 [==============================] - 5s 125ms/step - loss: 0.3563 - recall: 0.8433 - precision: 0.8433 - auc: 0.9138 - categorical_accuracy: 0.8433 - val_loss: 1.6185 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4128 - val_categorical_accuracy: 0.3800
# Epoch 11/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3060 - recall: 0.8650 - precision: 0.8650 - auc: 0.9398 - categorical_accuracy: 0.8650
# Epoch 00011: val_auc did not improve from 0.70770
# 41/41 [==============================] - 5s 121ms/step - loss: 0.3093 - recall: 0.8632 - precision: 0.8632 - auc: 0.9380 - categorical_accuracy: 0.8632 - val_loss: 0.7786 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.6881 - val_categorical_accuracy: 0.6600
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2616 - recall: 0.8925 - precision: 0.8925 - auc: 0.9605 - categorical_accuracy: 0.8925
# Epoch 00012: val_auc improved from 0.70770 to 0.79600, saving model to ../../tmp\checkpoints\20201216-142654\cp-0012.ckpt
# 41/41 [==============================] - 5s 129ms/step - loss: 0.2656 - recall: 0.8905 - precision: 0.8905 - auc: 0.9583 - categorical_accuracy: 0.8905 - val_loss: 0.5847 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7960 - val_categorical_accuracy: 0.7200
# Epoch 13/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2025 - recall: 0.9225 - precision: 0.9225 - auc: 0.9749 - categorical_accuracy: 0.9225
# Epoch 00013: val_auc did not improve from 0.79600
# 41/41 [==============================] - 5s 111ms/step - loss: 0.2020 - recall: 0.9229 - precision: 0.9229 - auc: 0.9750 - categorical_accuracy: 0.9229 - val_loss: 1.0046 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7488 - val_categorical_accuracy: 0.6600
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1726 - recall: 0.9400 - precision: 0.9400 - auc: 0.9790 - categorical_accuracy: 0.9400
# Epoch 00014: val_auc did not improve from 0.79600
# 41/41 [==============================] - 4s 107ms/step - loss: 0.1741 - recall: 0.9378 - precision: 0.9378 - auc: 0.9787 - categorical_accuracy: 0.9378 - val_loss: 1.3039 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7038 - val_categorical_accuracy: 0.6600
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1953 - recall: 0.9300 - precision: 0.9300 - auc: 0.9748 - categorical_accuracy: 0.9300- ETA: 3s - loss: 0.2070 - recall: 0.9100 - precision: 0.9100 - auc: 0.9694 - c
# Epoch 00015: val_auc did not improve from 0.79600
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1983 - recall: 0.9279 - precision: 0.9279 - auc: 0.9739 - categorical_accuracy: 0.9279 - val_loss: 0.7926 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7919 - val_categorical_accuracy: 0.7100
# Epoch 16/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1077 - recall: 0.9625 - precision: 0.9625 - auc: 0.9930 - categorical_accuracy: 0.9625
# Epoch 00016: val_auc did not improve from 0.79600
# 41/41 [==============================] - 5s 122ms/step - loss: 0.1077 - recall: 0.9627 - precision: 0.9627 - auc: 0.9930 - categorical_accuracy: 0.9627 - val_loss: 0.8914 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7924 - val_categorical_accuracy: 0.7200
# Epoch 17/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0987 - recall: 0.9602 - precision: 0.9602 - auc: 0.9955 - categorical_accuracy: 0.9602
# Epoch 00017: val_auc did not improve from 0.79600
# 41/41 [==============================] - 5s 115ms/step - loss: 0.0987 - recall: 0.9602 - precision: 0.9602 - auc: 0.9955 - categorical_accuracy: 0.9602 - val_loss: 1.0138 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7426 - val_categorical_accuracy: 0.6500
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0810 - recall: 0.9675 - precision: 0.9675 - auc: 0.9957 - categorical_accuracy: 0.9675- ETA: 1s - loss: 0.0732 - recall: 0.9696 - precision: 0.9696 - auc: 0.9957 - categorical_a
# Epoch 00018: val_auc improved from 0.79600 to 0.80270, saving model to ../../tmp\checkpoints\20201216-142654\cp-0018.ckpt
# 41/41 [==============================] - 5s 128ms/step - loss: 0.0807 - recall: 0.9677 - precision: 0.9677 - auc: 0.9957 - categorical_accuracy: 0.9677 - val_loss: 0.6870 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8027 - val_categorical_accuracy: 0.7300
# Epoch 19/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0456 - recall: 0.9925 - precision: 0.9925 - auc: 0.9982 - categorical_accuracy: 0.9925
# Epoch 00019: val_auc improved from 0.80270 to 0.81700, saving model to ../../tmp\checkpoints\20201216-142654\cp-0019.ckpt
# 41/41 [==============================] - 5s 134ms/step - loss: 0.0456 - recall: 0.9925 - precision: 0.9925 - auc: 0.9982 - categorical_accuracy: 0.9925 - val_loss: 0.8481 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8170 - val_categorical_accuracy: 0.7200
# Epoch 20/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0134 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00020: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 125ms/step - loss: 0.0134 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 0.9217 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8141 - val_categorical_accuracy: 0.7400
# Epoch 21/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0041 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00021: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 124ms/step - loss: 0.0041 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.9738 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8160 - val_categorical_accuracy: 0.7500
# Epoch 22/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0042 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00022: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 122ms/step - loss: 0.0042 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0864 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8166 - val_categorical_accuracy: 0.7300
# Epoch 23/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0071 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00023: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0071 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.2091 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.7993 - val_categorical_accuracy: 0.7600
# Epoch 24/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0015 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00024: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0015 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1684 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.8064 - val_categorical_accuracy: 0.7600
# Epoch 25/200
# 41/41 [==============================] - ETA: 0s - loss: 8.8932e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00025: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 114ms/step - loss: 8.8932e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1695 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8079 - val_categorical_accuracy: 0.7500
# Epoch 26/200
# 41/41 [==============================] - ETA: 0s - loss: 8.7184e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00026: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 117ms/step - loss: 8.7184e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1949 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7985 - val_categorical_accuracy: 0.7400
# Epoch 27/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0012 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00027: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0012 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2015 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8014 - val_categorical_accuracy: 0.7500
# Epoch 28/200
# 41/41 [==============================] - ETA: 0s - loss: 7.2293e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00028: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 128ms/step - loss: 7.2293e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2070 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8060 - val_categorical_accuracy: 0.7400
# Epoch 29/200
# 41/41 [==============================] - ETA: 0s - loss: 5.0361e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000- ETA: 3s - loss: 3.1075e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1
# Epoch 00029: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 114ms/step - loss: 5.0361e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2242 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8119 - val_categorical_accuracy: 0.7400
# Epoch 30/200
# 41/41 [==============================] - ETA: 0s - loss: 6.4823e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00030: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 117ms/step - loss: 6.4823e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2448 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8005 - val_categorical_accuracy: 0.7400
# Epoch 31/200
# 41/41 [==============================] - ETA: 0s - loss: 4.5527e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00031: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 114ms/step - loss: 4.5527e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2622 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8029 - val_categorical_accuracy: 0.7500
# Epoch 32/200
# 41/41 [==============================] - ETA: 0s - loss: 4.3186e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000- ETA: 2s - loss: 2.5528e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1. - ETA: 1s - loss: 2.7106e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accu
# Epoch 00032: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 120ms/step - loss: 4.3186e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2771 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8036 - val_categorical_accuracy: 0.7500
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 4.2742e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00033: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 117ms/step - loss: 4.4186e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2925 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8001 - val_categorical_accuracy: 0.7500
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0017 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00034: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 112ms/step - loss: 0.0017 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5931 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7823 - val_categorical_accuracy: 0.7200
# Epoch 35/200
# 41/41 [==============================] - ETA: 0s - loss: 4.5711e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00035: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 121ms/step - loss: 4.5711e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5595 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7886 - val_categorical_accuracy: 0.7400
# Epoch 36/200
# 40/41 [============================>.] - ETA: 0s - loss: 6.7409e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00036: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 119ms/step - loss: 6.7123e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5345 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7888 - val_categorical_accuracy: 0.7400
# Epoch 37/200
# 41/41 [==============================] - ETA: 0s - loss: 3.1578e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00037: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 116ms/step - loss: 3.1578e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5243 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7766 - val_categorical_accuracy: 0.7500
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 3.3700e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000- ETA: 1s - loss: 3.2241e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy
# Epoch 00038: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 112ms/step - loss: 3.3926e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5153 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7769 - val_categorical_accuracy: 0.7400
# Epoch 39/200
# 40/41 [============================>.] - ETA: 0s - loss: 9.3612e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00039: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 116ms/step - loss: 9.3223e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5650 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7868 - val_categorical_accuracy: 0.7400
# Epoch 40/200
# 41/41 [==============================] - ETA: 0s - loss: 4.6459e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00040: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 113ms/step - loss: 4.6459e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5248 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7845 - val_categorical_accuracy: 0.7400
# Epoch 41/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0013 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00041: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0013 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4696 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7821 - val_categorical_accuracy: 0.7400
# Epoch 42/200
# 41/41 [==============================] - ETA: 0s - loss: 1.9337e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00042: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 110ms/step - loss: 1.9337e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4043 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7717 - val_categorical_accuracy: 0.7300
# Epoch 43/200
# 40/41 [============================>.] - ETA: 0s - loss: 1.6032e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00043: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 112ms/step - loss: 1.6036e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4108 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7721 - val_categorical_accuracy: 0.7300
# Epoch 44/200
# 41/41 [==============================] - ETA: 0s - loss: 2.1526e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000- ETA: 4s - loss: 1.5998e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.
# Epoch 00044: val_auc did not improve from 0.81700
# 41/41 [==============================] - 5s 119ms/step - loss: 2.1526e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4214 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7732 - val_categorical_accuracy: 0.7300
# Wall time: 4min 52s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 142 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.7678996324539185
# recall: 0.7200000286102295
# precision: 0.7200000286102295
# auc: 0.8169999718666077
# categorical_accuracy: 0.7200000286102295
#
# Wall time: 25 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.765625
# recall: 0.7903225806451613
# f1-score: 0.7777777777777778
# support: 62
#
#
# CN
# precision: 0.6388888888888888
# recall: 0.6052631578947368
# f1-score: 0.6216216216216216
# support: 38
#
#
# micro avg
# precision: 0.72
# recall: 0.72
# f1-score: 0.72
# support: 100
#
#
# macro avg
# precision: 0.7022569444444444
# recall: 0.6977928692699491
# f1-score: 0.6996996996996997
# support: 100
#
#
# weighted avg
# precision: 0.7174652777777777
# recall: 0.72
# f1-score: 0.7184384384384385
# support: 100
#
#
# samples avg
# precision: 0.72
# recall: 0.72
# f1-score: 0.72
# support: 100
#
#
# F1
# micro: 0.72
# macro: 0.6996996996996997
#
#
# accuracy_score: 0.72
# sensitivity_score: 0.7903225806451613
# specificity_score: 0.6052631578947368
#
#
# Wall time: 22.5 s
