# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise) + Dropout (0.6)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

# RANDOM_SEED = 300785674475887
# tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %%
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#     # Restrict TensorFlow to only allocate 1GB * 2 of memory on the first GPU
#     try:
#         tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 2)])
#         logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#     except RuntimeError as e:
#         # Virtual devices must be set before GPUs have been initialized
#         print(e)

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201218-135809
# Wall time: 3.01 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = '3DResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0001,
#     'l2_beta': None,
    'dropout': 0.6,
    'blocks': (2, 2, 2),
    'filters': (64, 128, 256),
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 10,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 30,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 12,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# my_res_net (MyResNet)        (None, 256)               8323712
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 8,356,866
# Trainable params: 8,352,386
# Non-trainable params: 4,480
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201217-233514', 'cp-0037.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201218-135809
# checkpoint dir: ../../tmp\checkpoints\20201218-135809
# log dir: ../../tmp\logs\20201218-135809
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
#  2/34 [>.............................] - ETA: 6s - loss: 0.9393 - recall: 0.6667 - precision: 0.6667 - auc: 0.6441 - categorical_accuracy: 0.6667WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1432s vs `on_train_batch_end` time: 0.2435s). Check your callbacks.
# 34/34 [==============================] - ETA: 0s - loss: 1.0169 - recall: 0.5348 - precision: 0.5348 - auc: 0.5453 - categorical_accuracy: 0.5348
# Epoch 00001: val_auc improved from -inf to 0.40740, saving model to ../../tmp\checkpoints\20201218-135809\cp-0001.ckpt
# 34/34 [==============================] - 16s 472ms/step - loss: 1.0169 - recall: 0.5348 - precision: 0.5348 - auc: 0.5453 - categorical_accuracy: 0.5348 - val_loss: 0.7578 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4074 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 34/34 [==============================] - ETA: 0s - loss: 0.8167 - recall: 0.4975 - precision: 0.4975 - auc: 0.5172 - categorical_accuracy: 0.4975
# Epoch 00002: val_auc did not improve from 0.40740
# 34/34 [==============================] - 14s 425ms/step - loss: 0.8167 - recall: 0.4975 - precision: 0.4975 - auc: 0.5172 - categorical_accuracy: 0.4975 - val_loss: 0.7178 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 34/34 [==============================] - ETA: 0s - loss: 0.7900 - recall: 0.4303 - precision: 0.4303 - auc: 0.4306 - categorical_accuracy: 0.4303
# Epoch 00003: val_auc improved from 0.40740 to 0.41270, saving model to ../../tmp\checkpoints\20201218-135809\cp-0003.ckpt
# 34/34 [==============================] - 15s 442ms/step - loss: 0.7900 - recall: 0.4303 - precision: 0.4303 - auc: 0.4306 - categorical_accuracy: 0.4303 - val_loss: 0.7039 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4127 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 34/34 [==============================] - ETA: 0s - loss: 0.7274 - recall: 0.4900 - precision: 0.4900 - auc: 0.5282 - categorical_accuracy: 0.4900
# Epoch 00004: val_auc did not improve from 0.41270
# 34/34 [==============================] - 14s 424ms/step - loss: 0.7274 - recall: 0.4900 - precision: 0.4900 - auc: 0.5282 - categorical_accuracy: 0.4900 - val_loss: 0.7021 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4050 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 34/34 [==============================] - ETA: 0s - loss: 0.7286 - recall: 0.4950 - precision: 0.4950 - auc: 0.5063 - categorical_accuracy: 0.4950
# Epoch 00005: val_auc did not improve from 0.41270
# 34/34 [==============================] - 14s 425ms/step - loss: 0.7286 - recall: 0.4950 - precision: 0.4950 - auc: 0.5063 - categorical_accuracy: 0.4950 - val_loss: 0.7288 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3924 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 34/34 [==============================] - ETA: 0s - loss: 0.7254 - recall: 0.4950 - precision: 0.4950 - auc: 0.4950 - categorical_accuracy: 0.4950
# Epoch 00006: val_auc did not improve from 0.41270
# 34/34 [==============================] - 15s 428ms/step - loss: 0.7254 - recall: 0.4950 - precision: 0.4950 - auc: 0.4950 - categorical_accuracy: 0.4950 - val_loss: 0.7200 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4070 - val_categorical_accuracy: 0.3800
# Epoch 7/200
# 34/34 [==============================] - ETA: 0s - loss: 0.7060 - recall: 0.5124 - precision: 0.5124 - auc: 0.5301 - categorical_accuracy: 0.5124
# Epoch 00007: val_auc did not improve from 0.41270
# 34/34 [==============================] - 14s 422ms/step - loss: 0.7060 - recall: 0.5124 - precision: 0.5124 - auc: 0.5301 - categorical_accuracy: 0.5124 - val_loss: 0.7071 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3956 - val_categorical_accuracy: 0.3800
# Epoch 8/200
# 34/34 [==============================] - ETA: 0s - loss: 0.7137 - recall: 0.4925 - precision: 0.4925 - auc: 0.5014 - categorical_accuracy: 0.4925
# Epoch 00008: val_auc improved from 0.41270 to 0.43050, saving model to ../../tmp\checkpoints\20201218-135809\cp-0008.ckpt
# 34/34 [==============================] - 15s 438ms/step - loss: 0.7137 - recall: 0.4925 - precision: 0.4925 - auc: 0.5014 - categorical_accuracy: 0.4925 - val_loss: 0.6985 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4305 - val_categorical_accuracy: 0.3800
# Epoch 9/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6991 - recall: 0.5348 - precision: 0.5348 - auc: 0.5491 - categorical_accuracy: 0.5348
# Epoch 00009: val_auc did not improve from 0.43050
# 34/34 [==============================] - 14s 424ms/step - loss: 0.6991 - recall: 0.5348 - precision: 0.5348 - auc: 0.5491 - categorical_accuracy: 0.5348 - val_loss: 0.6922 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4163 - val_categorical_accuracy: 0.3800
# Epoch 10/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6839 - recall: 0.5597 - precision: 0.5597 - auc: 0.5659 - categorical_accuracy: 0.5597
# Epoch 00010: val_auc improved from 0.43050 to 0.57935, saving model to ../../tmp\checkpoints\20201218-135809\cp-0010.ckpt
# 34/34 [==============================] - 15s 438ms/step - loss: 0.6839 - recall: 0.5597 - precision: 0.5597 - auc: 0.5659 - categorical_accuracy: 0.5597 - val_loss: 0.6907 - val_recall: 0.5800 - val_precision: 0.5800 - val_auc: 0.5793 - val_categorical_accuracy: 0.5800
# Epoch 11/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6942 - recall: 0.5547 - precision: 0.5547 - auc: 0.5843 - categorical_accuracy: 0.5547
# Epoch 00011: val_auc improved from 0.57935 to 0.68030, saving model to ../../tmp\checkpoints\20201218-135809\cp-0011.ckpt
# 34/34 [==============================] - 15s 439ms/step - loss: 0.6942 - recall: 0.5547 - precision: 0.5547 - auc: 0.5843 - categorical_accuracy: 0.5547 - val_loss: 0.6910 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6803 - val_categorical_accuracy: 0.6200
# Epoch 12/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6923 - recall: 0.5597 - precision: 0.5597 - auc: 0.5658 - categorical_accuracy: 0.5597
# Epoch 00012: val_auc did not improve from 0.68030
# 34/34 [==============================] - 14s 422ms/step - loss: 0.6923 - recall: 0.5597 - precision: 0.5597 - auc: 0.5658 - categorical_accuracy: 0.5597 - val_loss: 0.6901 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4490 - val_categorical_accuracy: 0.3800
# Epoch 13/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6881 - recall: 0.5572 - precision: 0.5572 - auc: 0.5851 - categorical_accuracy: 0.5572
# Epoch 00013: val_auc did not improve from 0.68030
# 34/34 [==============================] - 14s 422ms/step - loss: 0.6881 - recall: 0.5572 - precision: 0.5572 - auc: 0.5851 - categorical_accuracy: 0.5572 - val_loss: 0.6941 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.5627 - val_categorical_accuracy: 0.6300
# Epoch 14/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6644 - recall: 0.5572 - precision: 0.5572 - auc: 0.6163 - categorical_accuracy: 0.5572
# Epoch 00014: val_auc did not improve from 0.68030
# 34/34 [==============================] - 14s 420ms/step - loss: 0.6644 - recall: 0.5572 - precision: 0.5572 - auc: 0.6163 - categorical_accuracy: 0.5572 - val_loss: 0.6877 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4611 - val_categorical_accuracy: 0.3800
# Epoch 15/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6555 - recall: 0.5746 - precision: 0.5746 - auc: 0.6412 - categorical_accuracy: 0.5746
# Epoch 00015: val_auc did not improve from 0.68030
# 34/34 [==============================] - 14s 422ms/step - loss: 0.6555 - recall: 0.5746 - precision: 0.5746 - auc: 0.6412 - categorical_accuracy: 0.5746 - val_loss: 0.6796 - val_recall: 0.4400 - val_precision: 0.4400 - val_auc: 0.4722 - val_categorical_accuracy: 0.4400
# Epoch 16/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6395 - recall: 0.6119 - precision: 0.6119 - auc: 0.6671 - categorical_accuracy: 0.6119
# Epoch 00016: val_auc improved from 0.68030 to 0.69220, saving model to ../../tmp\checkpoints\20201218-135809\cp-0016.ckpt
# 34/34 [==============================] - 15s 436ms/step - loss: 0.6395 - recall: 0.6119 - precision: 0.6119 - auc: 0.6671 - categorical_accuracy: 0.6119 - val_loss: 0.6713 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.6922 - val_categorical_accuracy: 0.6700
# Epoch 17/200
# 34/34 [==============================] - ETA: 0s - loss: 0.6018 - recall: 0.6592 - precision: 0.6592 - auc: 0.7379 - categorical_accuracy: 0.6592
# Epoch 00017: val_auc improved from 0.69220 to 0.76960, saving model to ../../tmp\checkpoints\20201218-135809\cp-0017.ckpt
# 34/34 [==============================] - 15s 438ms/step - loss: 0.6018 - recall: 0.6592 - precision: 0.6592 - auc: 0.7379 - categorical_accuracy: 0.6592 - val_loss: 0.6624 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7696 - val_categorical_accuracy: 0.7400
# Epoch 18/200
# 34/34 [==============================] - ETA: 0s - loss: 0.5871 - recall: 0.7139 - precision: 0.7139 - auc: 0.7623 - categorical_accuracy: 0.7139
# Epoch 00018: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.5871 - recall: 0.7139 - precision: 0.7139 - auc: 0.7623 - categorical_accuracy: 0.7139 - val_loss: 0.6613 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7554 - val_categorical_accuracy: 0.7300
# Epoch 19/200
# 34/34 [==============================] - ETA: 0s - loss: 0.5923 - recall: 0.6791 - precision: 0.6791 - auc: 0.7478 - categorical_accuracy: 0.6791
# Epoch 00019: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.5923 - recall: 0.6791 - precision: 0.6791 - auc: 0.7478 - categorical_accuracy: 0.6791 - val_loss: 0.8266 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6436 - val_categorical_accuracy: 0.6100
# Epoch 20/200
# 34/34 [==============================] - ETA: 0s - loss: 0.5536 - recall: 0.6891 - precision: 0.6891 - auc: 0.7765 - categorical_accuracy: 0.6891
# Epoch 00020: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 421ms/step - loss: 0.5536 - recall: 0.6891 - precision: 0.6891 - auc: 0.7765 - categorical_accuracy: 0.6891 - val_loss: 0.7476 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4895 - val_categorical_accuracy: 0.3800
# Epoch 21/200
# 34/34 [==============================] - ETA: 0s - loss: 0.5596 - recall: 0.7065 - precision: 0.7065 - auc: 0.7867 - categorical_accuracy: 0.7065
# Epoch 00021: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.5596 - recall: 0.7065 - precision: 0.7065 - auc: 0.7867 - categorical_accuracy: 0.7065 - val_loss: 0.6182 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7663 - val_categorical_accuracy: 0.7100
# Epoch 22/200
# 34/34 [==============================] - ETA: 0s - loss: 0.5171 - recall: 0.7388 - precision: 0.7388 - auc: 0.8301 - categorical_accuracy: 0.7388
# Epoch 00022: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.5171 - recall: 0.7388 - precision: 0.7388 - auc: 0.8301 - categorical_accuracy: 0.7388 - val_loss: 0.6226 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6296 - val_categorical_accuracy: 0.6200
# Epoch 23/200
# 34/34 [==============================] - ETA: 0s - loss: 0.4954 - recall: 0.7711 - precision: 0.7711 - auc: 0.8496 - categorical_accuracy: 0.7711
# Epoch 00023: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.4954 - recall: 0.7711 - precision: 0.7711 - auc: 0.8496 - categorical_accuracy: 0.7711 - val_loss: 0.6052 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7604 - val_categorical_accuracy: 0.7000
# Epoch 24/200
# 34/34 [==============================] - ETA: 0s - loss: 0.4722 - recall: 0.7811 - precision: 0.7811 - auc: 0.8641 - categorical_accuracy: 0.7811
# Epoch 00024: val_auc did not improve from 0.76960
# 34/34 [==============================] - 15s 427ms/step - loss: 0.4722 - recall: 0.7811 - precision: 0.7811 - auc: 0.8641 - categorical_accuracy: 0.7811 - val_loss: 0.6292 - val_recall: 0.5700 - val_precision: 0.5700 - val_auc: 0.6468 - val_categorical_accuracy: 0.5700
# Epoch 25/200
# 34/34 [==============================] - ETA: 0s - loss: 0.4729 - recall: 0.7861 - precision: 0.7861 - auc: 0.8615 - categorical_accuracy: 0.7861
# Epoch 00025: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.4729 - recall: 0.7861 - precision: 0.7861 - auc: 0.8615 - categorical_accuracy: 0.7861 - val_loss: 1.0343 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7213 - val_categorical_accuracy: 0.6500
# Epoch 26/200
# 34/34 [==============================] - ETA: 0s - loss: 0.4561 - recall: 0.7786 - precision: 0.7786 - auc: 0.8731 - categorical_accuracy: 0.7786
# Epoch 00026: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 426ms/step - loss: 0.4561 - recall: 0.7786 - precision: 0.7786 - auc: 0.8731 - categorical_accuracy: 0.7786 - val_loss: 0.7429 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7475 - val_categorical_accuracy: 0.7100
# Epoch 27/200
# 34/34 [==============================] - ETA: 0s - loss: 0.4427 - recall: 0.7910 - precision: 0.7910 - auc: 0.8771 - categorical_accuracy: 0.7910
# Epoch 00027: val_auc did not improve from 0.76960
# 34/34 [==============================] - 15s 427ms/step - loss: 0.4427 - recall: 0.7910 - precision: 0.7910 - auc: 0.8771 - categorical_accuracy: 0.7910 - val_loss: 0.7670 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.5185 - val_categorical_accuracy: 0.5000
# Epoch 28/200
# 34/34 [==============================] - ETA: 0s - loss: 0.4015 - recall: 0.8408 - precision: 0.8408 - auc: 0.9042 - categorical_accuracy: 0.8408
# Epoch 00028: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.4015 - recall: 0.8408 - precision: 0.8408 - auc: 0.9042 - categorical_accuracy: 0.8408 - val_loss: 0.6345 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.7310 - val_categorical_accuracy: 0.6300
# Epoch 29/200
# 34/34 [==============================] - ETA: 0s - loss: 0.3727 - recall: 0.8557 - precision: 0.8557 - auc: 0.9222 - categorical_accuracy: 0.8557
# Epoch 00029: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.3727 - recall: 0.8557 - precision: 0.8557 - auc: 0.9222 - categorical_accuracy: 0.8557 - val_loss: 0.6777 - val_recall: 0.5800 - val_precision: 0.5800 - val_auc: 0.6834 - val_categorical_accuracy: 0.5800
# Epoch 30/200
# 34/34 [==============================] - ETA: 0s - loss: 0.3665 - recall: 0.8657 - precision: 0.8657 - auc: 0.9271 - categorical_accuracy: 0.8657
# Epoch 00030: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.3665 - recall: 0.8657 - precision: 0.8657 - auc: 0.9271 - categorical_accuracy: 0.8657 - val_loss: 0.7132 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7233 - val_categorical_accuracy: 0.6600
# Epoch 31/200
# 34/34 [==============================] - ETA: 0s - loss: 0.3391 - recall: 0.8706 - precision: 0.8706 - auc: 0.9430 - categorical_accuracy: 0.8706
# Epoch 00031: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.3391 - recall: 0.8706 - precision: 0.8706 - auc: 0.9430 - categorical_accuracy: 0.8706 - val_loss: 0.7797 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7618 - val_categorical_accuracy: 0.7500
# Epoch 32/200
# 34/34 [==============================] - ETA: 0s - loss: 0.3395 - recall: 0.8856 - precision: 0.8856 - auc: 0.9413 - categorical_accuracy: 0.8856
# Epoch 00032: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.3395 - recall: 0.8856 - precision: 0.8856 - auc: 0.9413 - categorical_accuracy: 0.8856 - val_loss: 0.7109 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7499 - val_categorical_accuracy: 0.7100
# Epoch 33/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2959 - recall: 0.9055 - precision: 0.9055 - auc: 0.9599 - categorical_accuracy: 0.9055
# Epoch 00033: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.2959 - recall: 0.9055 - precision: 0.9055 - auc: 0.9599 - categorical_accuracy: 0.9055 - val_loss: 0.7534 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7625 - val_categorical_accuracy: 0.7300
# Epoch 34/200
# 34/34 [==============================] - ETA: 0s - loss: 0.3122 - recall: 0.8806 - precision: 0.8806 - auc: 0.9498 - categorical_accuracy: 0.8806
# Epoch 00034: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 421ms/step - loss: 0.3122 - recall: 0.8806 - precision: 0.8806 - auc: 0.9498 - categorical_accuracy: 0.8806 - val_loss: 0.7575 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7291 - val_categorical_accuracy: 0.6800
# Epoch 35/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2885 - recall: 0.9030 - precision: 0.9030 - auc: 0.9654 - categorical_accuracy: 0.9030
# Epoch 00035: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.2885 - recall: 0.9030 - precision: 0.9030 - auc: 0.9654 - categorical_accuracy: 0.9030 - val_loss: 0.7477 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7359 - val_categorical_accuracy: 0.6800
# Epoch 36/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2883 - recall: 0.9005 - precision: 0.9005 - auc: 0.9590 - categorical_accuracy: 0.9005
# Epoch 00036: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.2883 - recall: 0.9005 - precision: 0.9005 - auc: 0.9590 - categorical_accuracy: 0.9005 - val_loss: 0.7157 - val_recall: 0.5600 - val_precision: 0.5600 - val_auc: 0.6960 - val_categorical_accuracy: 0.5600
# Epoch 37/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2895 - recall: 0.9005 - precision: 0.9005 - auc: 0.9583 - categorical_accuracy: 0.9005
# Epoch 00037: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.2895 - recall: 0.9005 - precision: 0.9005 - auc: 0.9583 - categorical_accuracy: 0.9005 - val_loss: 0.7368 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7370 - val_categorical_accuracy: 0.6900
# Epoch 38/200
# 34/34 [==============================] - ETA: 0s - loss: 0.3003 - recall: 0.9129 - precision: 0.9129 - auc: 0.9573 - categorical_accuracy: 0.9129
# Epoch 00038: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.3003 - recall: 0.9129 - precision: 0.9129 - auc: 0.9573 - categorical_accuracy: 0.9129 - val_loss: 0.7328 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7535 - val_categorical_accuracy: 0.7100
# Epoch 39/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2658 - recall: 0.9030 - precision: 0.9030 - auc: 0.9658 - categorical_accuracy: 0.9030
# Epoch 00039: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.2658 - recall: 0.9030 - precision: 0.9030 - auc: 0.9658 - categorical_accuracy: 0.9030 - val_loss: 0.7134 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7493 - val_categorical_accuracy: 0.6900
# Epoch 40/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2855 - recall: 0.9030 - precision: 0.9030 - auc: 0.9599 - categorical_accuracy: 0.9030
# Epoch 00040: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.2855 - recall: 0.9030 - precision: 0.9030 - auc: 0.9599 - categorical_accuracy: 0.9030 - val_loss: 0.6956 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7389 - val_categorical_accuracy: 0.6500
# Epoch 41/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2857 - recall: 0.8930 - precision: 0.8930 - auc: 0.9581 - categorical_accuracy: 0.8930
# Epoch 00041: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.2857 - recall: 0.8930 - precision: 0.8930 - auc: 0.9581 - categorical_accuracy: 0.8930 - val_loss: 0.6936 - val_recall: 0.5700 - val_precision: 0.5700 - val_auc: 0.7075 - val_categorical_accuracy: 0.5700
# Epoch 42/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2693 - recall: 0.9154 - precision: 0.9154 - auc: 0.9687 - categorical_accuracy: 0.9154
# Epoch 00042: val_auc did not improve from 0.76960
# 34/34 [==============================] - 15s 428ms/step - loss: 0.2693 - recall: 0.9154 - precision: 0.9154 - auc: 0.9687 - categorical_accuracy: 0.9154 - val_loss: 0.7044 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7341 - val_categorical_accuracy: 0.6500
# Epoch 43/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2647 - recall: 0.9254 - precision: 0.9254 - auc: 0.9683 - categorical_accuracy: 0.9254
# Epoch 00043: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.2647 - recall: 0.9254 - precision: 0.9254 - auc: 0.9683 - categorical_accuracy: 0.9254 - val_loss: 0.7046 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7435 - val_categorical_accuracy: 0.6400
# Epoch 44/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2971 - recall: 0.9080 - precision: 0.9080 - auc: 0.9584 - categorical_accuracy: 0.9080
# Epoch 00044: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.2971 - recall: 0.9080 - precision: 0.9080 - auc: 0.9584 - categorical_accuracy: 0.9080 - val_loss: 0.7117 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.7120 - val_categorical_accuracy: 0.6100
# Epoch 45/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2618 - recall: 0.9129 - precision: 0.9129 - auc: 0.9734 - categorical_accuracy: 0.9129
# Epoch 00045: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 422ms/step - loss: 0.2618 - recall: 0.9129 - precision: 0.9129 - auc: 0.9734 - categorical_accuracy: 0.9129 - val_loss: 0.7211 - val_recall: 0.5400 - val_precision: 0.5400 - val_auc: 0.6946 - val_categorical_accuracy: 0.5400
# Epoch 46/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2398 - recall: 0.9204 - precision: 0.9204 - auc: 0.9762 - categorical_accuracy: 0.9204
# Epoch 00046: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 424ms/step - loss: 0.2398 - recall: 0.9204 - precision: 0.9204 - auc: 0.9762 - categorical_accuracy: 0.9204 - val_loss: 0.7218 - val_recall: 0.5900 - val_precision: 0.5900 - val_auc: 0.7074 - val_categorical_accuracy: 0.5900
# Epoch 47/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2764 - recall: 0.9154 - precision: 0.9154 - auc: 0.9626 - categorical_accuracy: 0.9154
# Epoch 00047: val_auc did not improve from 0.76960
# 34/34 [==============================] - 14s 423ms/step - loss: 0.2764 - recall: 0.9154 - precision: 0.9154 - auc: 0.9626 - categorical_accuracy: 0.9154 - val_loss: 0.7200 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.7259 - val_categorical_accuracy: 0.6300
# Wall time: 12min 58s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 141 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.6528438329696655
# recall: 0.7400000095367432
# precision: 0.7400000095367432
# auc: 0.7696000337600708
# categorical_accuracy: 0.7400000095367432
#
# Wall time: 24.4 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.7368421052631579
# recall: 0.9032258064516129
# f1-score: 0.8115942028985507
# support: 62
#
#
# CN
# precision: 0.75
# recall: 0.47368421052631576
# f1-score: 0.5806451612903226
# support: 38
#
#
# micro avg
# precision: 0.74
# recall: 0.74
# f1-score: 0.74
# support: 100
#
#
# macro avg
# precision: 0.743421052631579
# recall: 0.6884550084889643
# f1-score: 0.6961196820944366
# support: 100
#
#
# weighted avg
# precision: 0.7418421052631579
# recall: 0.74
# f1-score: 0.723833567087424
# support: 100
#
#
# samples avg
# precision: 0.74
# recall: 0.74
# f1-score: 0.74
# support: 100
#
#
# F1
# micro: 0.74
# macro: 0.6961196820944366
#
#
# accuracy_score: 0.74
# sensitivity_score: 0.9032258064516129
# specificity_score: 0.47368421052631576
#
#
# Wall time: 23.1 s
