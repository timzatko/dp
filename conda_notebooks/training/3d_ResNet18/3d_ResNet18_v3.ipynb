# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, shear, blur, noise) + Batch Norm

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
# import tensorflow as tf

# RANDOM_SEED = 792379571013149
# tf.random.set_seed(RANDOM_SEED)

# print(tf.version.VERSION)
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20210312-104448
# Wall time: 0 ns

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = '3DResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.10,
#     'dropout': None,
    'batch_norm': True,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00005,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0., 0.),
        'shear': (0.2, 0.5), # probability, degrees
        'blur': (0.2, 0.85),
        'noise': (0.2, 0.00020)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# my_res_net (MyResNet)        (None, 512)               33437056
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 33,601,538
# Trainable params: 33,591,938
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20210312-104448
# checkpoint dir: ../../tmp\checkpoints\20210312-104448
# log dir: ../../tmp\logs\20210312-104448
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
#  2/41 [>.............................] - ETA: 7s - loss: 0.7593 - recall: 0.3000 - precision: 0.3000 - auc: 0.2538 - categorical_accuracy: 0.3000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1480s vs `on_train_batch_end` time: 0.2271s). Check your callbacks.
# 41/41 [==============================] - ETA: 0s - loss: 0.7330 - recall: 0.5000 - precision: 0.5000 - auc: 0.5073 - categorical_accuracy: 0.5000
# Epoch 00001: val_auc improved from -inf to 0.35800, saving model to ../../tmp\checkpoints\20210312-104448\cp-0001.ckpt
# 41/41 [==============================] - 20s 479ms/step - loss: 0.7330 - recall: 0.5000 - precision: 0.5000 - auc: 0.5073 - categorical_accuracy: 0.5000 - val_loss: 0.8170 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3580 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6656 - recall: 0.5920 - precision: 0.5920 - auc: 0.6425 - categorical_accuracy: 0.5920
# Epoch 00002: val_auc improved from 0.35800 to 0.38240, saving model to ../../tmp\checkpoints\20210312-104448\cp-0002.ckpt
# 41/41 [==============================] - 18s 448ms/step - loss: 0.6656 - recall: 0.5920 - precision: 0.5920 - auc: 0.6425 - categorical_accuracy: 0.5920 - val_loss: 0.8284 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3824 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5698 - recall: 0.7313 - precision: 0.7313 - auc: 0.7845 - categorical_accuracy: 0.7313
# Epoch 00003: val_auc improved from 0.38240 to 0.41420, saving model to ../../tmp\checkpoints\20210312-104448\cp-0003.ckpt
# 41/41 [==============================] - 19s 453ms/step - loss: 0.5698 - recall: 0.7313 - precision: 0.7313 - auc: 0.7845 - categorical_accuracy: 0.7313 - val_loss: 0.9715 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4142 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5075 - recall: 0.7836 - precision: 0.7836 - auc: 0.8387 - categorical_accuracy: 0.7836
# Epoch 00004: val_auc did not improve from 0.41420
# 41/41 [==============================] - 17s 409ms/step - loss: 0.5075 - recall: 0.7836 - precision: 0.7836 - auc: 0.8387 - categorical_accuracy: 0.7836 - val_loss: 1.0302 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3665 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3273 - recall: 0.8731 - precision: 0.8731 - auc: 0.9388 - categorical_accuracy: 0.8731
# Epoch 00005: val_auc did not improve from 0.41420
# 41/41 [==============================] - 17s 408ms/step - loss: 0.3273 - recall: 0.8731 - precision: 0.8731 - auc: 0.9388 - categorical_accuracy: 0.8731 - val_loss: 0.8393 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3340 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3634 - recall: 0.8632 - precision: 0.8632 - auc: 0.9235 - categorical_accuracy: 0.8632
# Epoch 00006: val_auc improved from 0.41420 to 0.68370, saving model to ../../tmp\checkpoints\20210312-104448\cp-0006.ckpt
# 41/41 [==============================] - 19s 453ms/step - loss: 0.3634 - recall: 0.8632 - precision: 0.8632 - auc: 0.9235 - categorical_accuracy: 0.8632 - val_loss: 0.8104 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6837 - val_categorical_accuracy: 0.6200
# Epoch 7/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3528 - recall: 0.8682 - precision: 0.8682 - auc: 0.9196 - categorical_accuracy: 0.8682
# Epoch 00007: val_auc improved from 0.68370 to 0.69730, saving model to ../../tmp\checkpoints\20210312-104448\cp-0007.ckpt
# 41/41 [==============================] - 18s 450ms/step - loss: 0.3528 - recall: 0.8682 - precision: 0.8682 - auc: 0.9196 - categorical_accuracy: 0.8682 - val_loss: 0.6864 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6973 - val_categorical_accuracy: 0.6100
# Epoch 8/200
# 41/41 [==============================] - ETA: 0s - loss: 0.2160 - recall: 0.9154 - precision: 0.9154 - auc: 0.9722 - categorical_accuracy: 0.9154
# Epoch 00008: val_auc did not improve from 0.69730
# 41/41 [==============================] - 17s 410ms/step - loss: 0.2160 - recall: 0.9154 - precision: 0.9154 - auc: 0.9722 - categorical_accuracy: 0.9154 - val_loss: 0.8482 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4319 - val_categorical_accuracy: 0.3800
# Epoch 9/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1611 - recall: 0.9478 - precision: 0.9478 - auc: 0.9845 - categorical_accuracy: 0.9478
# Epoch 00009: val_auc did not improve from 0.69730
# 41/41 [==============================] - 17s 410ms/step - loss: 0.1611 - recall: 0.9478 - precision: 0.9478 - auc: 0.9845 - categorical_accuracy: 0.9478 - val_loss: 0.8260 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3757 - val_categorical_accuracy: 0.3800
# Epoch 10/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1369 - recall: 0.9478 - precision: 0.9478 - auc: 0.9887 - categorical_accuracy: 0.9478
# Epoch 00010: val_auc did not improve from 0.69730
# 41/41 [==============================] - 17s 410ms/step - loss: 0.1369 - recall: 0.9478 - precision: 0.9478 - auc: 0.9887 - categorical_accuracy: 0.9478 - val_loss: 1.3284 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3612 - val_categorical_accuracy: 0.3800
# Epoch 11/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1092 - recall: 0.9577 - precision: 0.9577 - auc: 0.9936 - categorical_accuracy: 0.9577
# Epoch 00011: val_auc did not improve from 0.69730
# 41/41 [==============================] - 17s 409ms/step - loss: 0.1092 - recall: 0.9577 - precision: 0.9577 - auc: 0.9936 - categorical_accuracy: 0.9577 - val_loss: 0.7153 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.5180 - val_categorical_accuracy: 0.5000
# Epoch 12/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1224 - recall: 0.9577 - precision: 0.9577 - auc: 0.9906 - categorical_accuracy: 0.9577
# Epoch 00012: val_auc did not improve from 0.69730
# 41/41 [==============================] - 17s 412ms/step - loss: 0.1224 - recall: 0.9577 - precision: 0.9577 - auc: 0.9906 - categorical_accuracy: 0.9577 - val_loss: 0.8450 - val_recall: 0.4300 - val_precision: 0.4300 - val_auc: 0.4625 - val_categorical_accuracy: 0.4300
# Epoch 13/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0829 - recall: 0.9701 - precision: 0.9701 - auc: 0.9968 - categorical_accuracy: 0.9701
# Epoch 00013: val_auc improved from 0.69730 to 0.74990, saving model to ../../tmp\checkpoints\20210312-104448\cp-0013.ckpt
# 41/41 [==============================] - 19s 453ms/step - loss: 0.0829 - recall: 0.9701 - precision: 0.9701 - auc: 0.9968 - categorical_accuracy: 0.9701 - val_loss: 0.5851 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7499 - val_categorical_accuracy: 0.7100
# Epoch 14/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0632 - recall: 0.9876 - precision: 0.9876 - auc: 0.9974 - categorical_accuracy: 0.9876
# Epoch 00014: val_auc improved from 0.74990 to 0.79640, saving model to ../../tmp\checkpoints\20210312-104448\cp-0014.ckpt
# 41/41 [==============================] - 19s 453ms/step - loss: 0.0632 - recall: 0.9876 - precision: 0.9876 - auc: 0.9974 - categorical_accuracy: 0.9876 - val_loss: 0.5366 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7964 - val_categorical_accuracy: 0.7000
# Epoch 15/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0495 - recall: 0.9851 - precision: 0.9851 - auc: 0.9982 - categorical_accuracy: 0.9851
# Epoch 00015: val_auc improved from 0.79640 to 0.81830, saving model to ../../tmp\checkpoints\20210312-104448\cp-0015.ckpt
# 41/41 [==============================] - 18s 450ms/step - loss: 0.0495 - recall: 0.9851 - precision: 0.9851 - auc: 0.9982 - categorical_accuracy: 0.9851 - val_loss: 0.6341 - val_recall: 0.7800 - val_precision: 0.7800 - val_auc: 0.8183 - val_categorical_accuracy: 0.7800
# Epoch 16/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0435 - recall: 0.9900 - precision: 0.9900 - auc: 0.9985 - categorical_accuracy: 0.9900
# Epoch 00016: val_auc did not improve from 0.81830
# 41/41 [==============================] - 17s 408ms/step - loss: 0.0435 - recall: 0.9900 - precision: 0.9900 - auc: 0.9985 - categorical_accuracy: 0.9900 - val_loss: 0.6922 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7736 - val_categorical_accuracy: 0.7000
# Epoch 17/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0434 - recall: 0.9876 - precision: 0.9876 - auc: 0.9993 - categorical_accuracy: 0.9876
# Epoch 00017: val_auc improved from 0.81830 to 0.82785, saving model to ../../tmp\checkpoints\20210312-104448\cp-0017.ckpt
# 41/41 [==============================] - 19s 452ms/step - loss: 0.0434 - recall: 0.9876 - precision: 0.9876 - auc: 0.9993 - categorical_accuracy: 0.9876 - val_loss: 0.5767 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.8279 - val_categorical_accuracy: 0.7600
# Epoch 18/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0512 - recall: 0.9851 - precision: 0.9851 - auc: 0.9975 - categorical_accuracy: 0.9851
# Epoch 00018: val_auc improved from 0.82785 to 0.83740, saving model to ../../tmp\checkpoints\20210312-104448\cp-0018.ckpt
# 41/41 [==============================] - 18s 447ms/step - loss: 0.0512 - recall: 0.9851 - precision: 0.9851 - auc: 0.9975 - categorical_accuracy: 0.9851 - val_loss: 0.5996 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.8374 - val_categorical_accuracy: 0.7600
# Epoch 19/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0289 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950
# Epoch 00019: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 409ms/step - loss: 0.0289 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950 - val_loss: 0.6408 - val_recall: 0.7800 - val_precision: 0.7800 - val_auc: 0.8374 - val_categorical_accuracy: 0.7800
# Epoch 20/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0164 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00020: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 409ms/step - loss: 0.0164 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.7557 - val_recall: 0.7700 - val_precision: 0.7700 - val_auc: 0.8234 - val_categorical_accuracy: 0.7700
# Epoch 21/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0214 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925
# Epoch 00021: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 412ms/step - loss: 0.0214 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925 - val_loss: 0.7245 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8271 - val_categorical_accuracy: 0.7300
# Epoch 22/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0331 - recall: 0.9851 - precision: 0.9851 - auc: 0.9995 - categorical_accuracy: 0.9851
# Epoch 00022: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 409ms/step - loss: 0.0331 - recall: 0.9851 - precision: 0.9851 - auc: 0.9995 - categorical_accuracy: 0.9851 - val_loss: 0.9535 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.8203 - val_categorical_accuracy: 0.7600
# Epoch 23/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0161 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00023: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 407ms/step - loss: 0.0161 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3339 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7927 - val_categorical_accuracy: 0.7200
# Epoch 24/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0163 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00024: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 411ms/step - loss: 0.0163 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8950 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8239 - val_categorical_accuracy: 0.7400
# Epoch 25/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0082 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00025: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 410ms/step - loss: 0.0082 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8735 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8257 - val_categorical_accuracy: 0.7400
# Epoch 26/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0100 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00026: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 410ms/step - loss: 0.0100 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 0.9671 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8243 - val_categorical_accuracy: 0.7500
# Epoch 27/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0153 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975
# Epoch 00027: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 407ms/step - loss: 0.0153 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975 - val_loss: 0.7801 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7913 - val_categorical_accuracy: 0.6800
# Epoch 28/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0177 - recall: 0.9975 - precision: 0.9975 - auc: 0.9993 - categorical_accuracy: 0.9975
# Epoch 00028: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 410ms/step - loss: 0.0177 - recall: 0.9975 - precision: 0.9975 - auc: 0.9993 - categorical_accuracy: 0.9975 - val_loss: 0.7968 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8139 - val_categorical_accuracy: 0.7400
# Epoch 29/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0112 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00029: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 410ms/step - loss: 0.0112 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 0.8406 - val_recall: 0.7600 - val_precision: 0.7600 - val_auc: 0.8350 - val_categorical_accuracy: 0.7600
# Epoch 30/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0083 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00030: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 408ms/step - loss: 0.0083 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.7876 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8271 - val_categorical_accuracy: 0.7100
# Epoch 31/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0098 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00031: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 407ms/step - loss: 0.0098 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.7768 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8092 - val_categorical_accuracy: 0.7300
# Epoch 32/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0048 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00032: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 407ms/step - loss: 0.0048 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8051 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8234 - val_categorical_accuracy: 0.7300
# Epoch 33/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0034 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00033: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 410ms/step - loss: 0.0034 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8348 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8237 - val_categorical_accuracy: 0.7400
# Epoch 34/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0037 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00034: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 408ms/step - loss: 0.0037 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8481 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8216 - val_categorical_accuracy: 0.7400
# Epoch 35/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0046 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00035: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 407ms/step - loss: 0.0046 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8550 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8204 - val_categorical_accuracy: 0.7500
# Epoch 36/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0030 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00036: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 409ms/step - loss: 0.0030 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.9025 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8229 - val_categorical_accuracy: 0.7400
# Epoch 37/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0052 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00037: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 408ms/step - loss: 0.0052 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 0.8555 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8257 - val_categorical_accuracy: 0.7500
# Epoch 38/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0026 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00038: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 412ms/step - loss: 0.0026 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8832 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8214 - val_categorical_accuracy: 0.7500
# Epoch 39/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0038 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00039: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 410ms/step - loss: 0.0038 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.9017 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8222 - val_categorical_accuracy: 0.7300
# Epoch 40/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0032 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00040: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 412ms/step - loss: 0.0032 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.8997 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.8181 - val_categorical_accuracy: 0.7400
# Epoch 41/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0035 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00041: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 409ms/step - loss: 0.0035 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.9317 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8132 - val_categorical_accuracy: 0.7300
# Epoch 42/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0022 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00042: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 407ms/step - loss: 0.0022 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.9379 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8127 - val_categorical_accuracy: 0.7300
# Epoch 43/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0031 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00043: val_auc did not improve from 0.83740
# 41/41 [==============================] - 17s 411ms/step - loss: 0.0031 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.9531 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8142 - val_categorical_accuracy: 0.7300
# Wall time: 14min

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 158 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.5543928742408752
# recall: 0.7599999904632568
# precision: 0.7599999904632568
# auc: 0.8374000191688538
# categorical_accuracy: 0.7599999904632568
#
# Wall time: 27.8 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.796875
# recall: 0.8225806451612904
# f1-score: 0.8095238095238094
# support: 62
#
#
# CN
# precision: 0.6944444444444444
# recall: 0.6578947368421053
# f1-score: 0.6756756756756757
# support: 38
#
#
# micro avg
# precision: 0.76
# recall: 0.76
# f1-score: 0.76
# support: 100
#
#
# macro avg
# precision: 0.7456597222222222
# recall: 0.7402376910016979
# f1-score: 0.7425997425997426
# support: 100
#
#
# weighted avg
# precision: 0.7579513888888889
# recall: 0.76
# f1-score: 0.7586615186615185
# support: 100
#
#
# samples avg
# precision: 0.76
# recall: 0.76
# f1-score: 0.76
# support: 100
#
#
# F1
# micro: 0.76
# macro: 0.7425997425997426
#
#
# accuracy_score: 0.76
# sensitivity_score: 0.8225806451612904
# specificity_score: 0.6578947368421053
#
#
# Wall time: 26 s
