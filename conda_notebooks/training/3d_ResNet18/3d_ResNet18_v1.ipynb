# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
# import tensorflow as tf

# RANDOM_SEED = 792379571013149
# tf.random.set_seed(RANDOM_SEED)

# print(tf.version.VERSION)
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201229-152016
# Wall time: 4 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = '3DResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.10,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
#     'augmentations': {
#         'invert': (0.5, None),
#         'rotate': (0.2, 5), # probability, degrees
#         'zoom': (0., 0.),
#         'shear': (0.2, 0.5), # probability, degrees
#         'blur': (0.2, 0.85),
#         'noise': (0.2, 0.00020)
#     },
    'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# my_res_net (MyResNet)        (None, 512)               33421440
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 33,585,922
# Trainable params: 33,584,130
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201229-142940', 'cp-0001.ckpt')
# Out:
# loading checkpoint from ../../tmp\checkpoints\20201229-142940\cp-0001.ckpt...

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201229-152016
# checkpoint dir: ../../tmp\checkpoints\20201229-152016
# log dir: ../../tmp\logs\20201229-152016
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
#  2/41 [>.............................] - ETA: 5s - loss: 0.6314 - recall: 0.4500 - precision: 0.4500 - auc: 0.4250 - categorical_accuracy: 0.4500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1060s vs `on_train_batch_end` time: 0.1800s). Check your callbacks.
# 41/41 [==============================] - ETA: 0s - loss: 0.7077 - recall: 0.5348 - precision: 0.5348 - auc: 0.5098 - categorical_accuracy: 0.5348
# Epoch 00001: val_auc improved from -inf to 0.38000, saving model to ../../tmp\checkpoints\20201229-152016\cp-0001.ckpt
# 41/41 [==============================] - 15s 378ms/step - loss: 0.7077 - recall: 0.5348 - precision: 0.5348 - auc: 0.5098 - categorical_accuracy: 0.5348 - val_loss: 0.8021 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 41/41 [==============================] - ETA: 0s - loss: 0.7007 - recall: 0.5323 - precision: 0.5323 - auc: 0.5309 - categorical_accuracy: 0.5323
# Epoch 00002: val_auc improved from 0.38000 to 0.39140, saving model to ../../tmp\checkpoints\20201229-152016\cp-0002.ckpt
# 41/41 [==============================] - 15s 358ms/step - loss: 0.7007 - recall: 0.5323 - precision: 0.5323 - auc: 0.5309 - categorical_accuracy: 0.5323 - val_loss: 0.7858 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3914 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6963 - recall: 0.5473 - precision: 0.5473 - auc: 0.5450 - categorical_accuracy: 0.5473
# Epoch 00003: val_auc improved from 0.39140 to 0.42800, saving model to ../../tmp\checkpoints\20201229-152016\cp-0003.ckpt
# 41/41 [==============================] - 15s 355ms/step - loss: 0.6963 - recall: 0.5473 - precision: 0.5473 - auc: 0.5450 - categorical_accuracy: 0.5473 - val_loss: 0.7826 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4280 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6862 - recall: 0.5771 - precision: 0.5771 - auc: 0.5898 - categorical_accuracy: 0.5771
# Epoch 00004: val_auc did not improve from 0.42800
# 41/41 [==============================] - 13s 316ms/step - loss: 0.6862 - recall: 0.5771 - precision: 0.5771 - auc: 0.5898 - categorical_accuracy: 0.5771 - val_loss: 0.7939 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4206 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6728 - recall: 0.6095 - precision: 0.6095 - auc: 0.6272 - categorical_accuracy: 0.6095
# Epoch 00005: val_auc did not improve from 0.42800
# 41/41 [==============================] - 13s 316ms/step - loss: 0.6728 - recall: 0.6095 - precision: 0.6095 - auc: 0.6272 - categorical_accuracy: 0.6095 - val_loss: 0.7953 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3994 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6549 - recall: 0.6194 - precision: 0.6194 - auc: 0.6624 - categorical_accuracy: 0.6194
# Epoch 00006: val_auc improved from 0.42800 to 0.43960, saving model to ../../tmp\checkpoints\20201229-152016\cp-0006.ckpt
# 41/41 [==============================] - 15s 356ms/step - loss: 0.6549 - recall: 0.6194 - precision: 0.6194 - auc: 0.6624 - categorical_accuracy: 0.6194 - val_loss: 0.7756 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4396 - val_categorical_accuracy: 0.3800
# Epoch 7/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6501 - recall: 0.6194 - precision: 0.6194 - auc: 0.6752 - categorical_accuracy: 0.6194
# Epoch 00007: val_auc did not improve from 0.43960
# 41/41 [==============================] - 13s 318ms/step - loss: 0.6501 - recall: 0.6194 - precision: 0.6194 - auc: 0.6752 - categorical_accuracy: 0.6194 - val_loss: 0.8182 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3909 - val_categorical_accuracy: 0.3800
# Epoch 8/200
# 41/41 [==============================] - ETA: 0s - loss: 0.6213 - recall: 0.6517 - precision: 0.6517 - auc: 0.7122 - categorical_accuracy: 0.6517
# Epoch 00008: val_auc did not improve from 0.43960
# 41/41 [==============================] - 17s 420ms/step - loss: 0.6213 - recall: 0.6517 - precision: 0.6517 - auc: 0.7122 - categorical_accuracy: 0.6517 - val_loss: 0.8295 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3738 - val_categorical_accuracy: 0.3800
# Epoch 9/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5820 - recall: 0.6741 - precision: 0.6741 - auc: 0.7598 - categorical_accuracy: 0.6741
# Epoch 00009: val_auc did not improve from 0.43960
# 41/41 [==============================] - 104s 3s/step - loss: 0.5820 - recall: 0.6741 - precision: 0.6741 - auc: 0.7598 - categorical_accuracy: 0.6741 - val_loss: 0.8364 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4222 - val_categorical_accuracy: 0.3800
# Epoch 10/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5636 - recall: 0.7214 - precision: 0.7214 - auc: 0.7785 - categorical_accuracy: 0.7214
# Epoch 00010: val_auc did not improve from 0.43960
# 41/41 [==============================] - 13s 315ms/step - loss: 0.5636 - recall: 0.7214 - precision: 0.7214 - auc: 0.7785 - categorical_accuracy: 0.7214 - val_loss: 0.8034 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4284 - val_categorical_accuracy: 0.3800
# Epoch 11/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5171 - recall: 0.7612 - precision: 0.7612 - auc: 0.8260 - categorical_accuracy: 0.7612
# Epoch 00011: val_auc improved from 0.43960 to 0.49460, saving model to ../../tmp\checkpoints\20201229-152016\cp-0011.ckpt
# 41/41 [==============================] - 14s 353ms/step - loss: 0.5171 - recall: 0.7612 - precision: 0.7612 - auc: 0.8260 - categorical_accuracy: 0.7612 - val_loss: 0.8403 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4946 - val_categorical_accuracy: 0.3800
# Epoch 12/200
# 41/41 [==============================] - ETA: 0s - loss: 0.4382 - recall: 0.8284 - precision: 0.8284 - auc: 0.8834 - categorical_accuracy: 0.8284
# Epoch 00012: val_auc did not improve from 0.49460
# 41/41 [==============================] - 13s 312ms/step - loss: 0.4382 - recall: 0.8284 - precision: 0.8284 - auc: 0.8834 - categorical_accuracy: 0.8284 - val_loss: 0.9556 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4536 - val_categorical_accuracy: 0.3800
# Epoch 13/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3582 - recall: 0.8607 - precision: 0.8607 - auc: 0.9202 - categorical_accuracy: 0.8607
# Epoch 00013: val_auc did not improve from 0.49460
# 41/41 [==============================] - 13s 312ms/step - loss: 0.3582 - recall: 0.8607 - precision: 0.8607 - auc: 0.9202 - categorical_accuracy: 0.8607 - val_loss: 0.8846 - val_recall: 0.3900 - val_precision: 0.3900 - val_auc: 0.4827 - val_categorical_accuracy: 0.3900
# Epoch 14/200
# 41/41 [==============================] - ETA: 0s - loss: 0.4037 - recall: 0.8209 - precision: 0.8209 - auc: 0.8937 - categorical_accuracy: 0.8209
# Epoch 00014: val_auc improved from 0.49460 to 0.72420, saving model to ../../tmp\checkpoints\20201229-152016\cp-0014.ckpt
# 41/41 [==============================] - 14s 350ms/step - loss: 0.4037 - recall: 0.8209 - precision: 0.8209 - auc: 0.8937 - categorical_accuracy: 0.8209 - val_loss: 1.4289 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7242 - val_categorical_accuracy: 0.6400
# Epoch 15/200
# 41/41 [==============================] - ETA: 0s - loss: 0.2911 - recall: 0.8930 - precision: 0.8930 - auc: 0.9472 - categorical_accuracy: 0.8930
# Epoch 00015: val_auc did not improve from 0.72420
# 41/41 [==============================] - 13s 314ms/step - loss: 0.2911 - recall: 0.8930 - precision: 0.8930 - auc: 0.9472 - categorical_accuracy: 0.8930 - val_loss: 0.6900 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6862 - val_categorical_accuracy: 0.6200
# Epoch 16/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1668 - recall: 0.9478 - precision: 0.9478 - auc: 0.9822 - categorical_accuracy: 0.9478
# Epoch 00016: val_auc did not improve from 0.72420
# 41/41 [==============================] - 13s 313ms/step - loss: 0.1668 - recall: 0.9478 - precision: 0.9478 - auc: 0.9822 - categorical_accuracy: 0.9478 - val_loss: 1.2923 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.5167 - val_categorical_accuracy: 0.3800
# Epoch 17/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1177 - recall: 0.9652 - precision: 0.9652 - auc: 0.9918 - categorical_accuracy: 0.9652
# Epoch 00017: val_auc did not improve from 0.72420
# 41/41 [==============================] - 13s 315ms/step - loss: 0.1177 - recall: 0.9652 - precision: 0.9652 - auc: 0.9918 - categorical_accuracy: 0.9652 - val_loss: 1.0076 - val_recall: 0.6000 - val_precision: 0.6000 - val_auc: 0.6122 - val_categorical_accuracy: 0.6000
# Epoch 18/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1014 - recall: 0.9726 - precision: 0.9726 - auc: 0.9928 - categorical_accuracy: 0.9726
# Epoch 00018: val_auc did not improve from 0.72420
# 41/41 [==============================] - 13s 315ms/step - loss: 0.1014 - recall: 0.9726 - precision: 0.9726 - auc: 0.9928 - categorical_accuracy: 0.9726 - val_loss: 1.6194 - val_recall: 0.3900 - val_precision: 0.3900 - val_auc: 0.5031 - val_categorical_accuracy: 0.3900
# Epoch 19/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0727 - recall: 0.9776 - precision: 0.9776 - auc: 0.9962 - categorical_accuracy: 0.9776
# Epoch 00019: val_auc did not improve from 0.72420
# 41/41 [==============================] - 13s 314ms/step - loss: 0.0727 - recall: 0.9776 - precision: 0.9776 - auc: 0.9962 - categorical_accuracy: 0.9776 - val_loss: 1.5419 - val_recall: 0.4300 - val_precision: 0.4300 - val_auc: 0.5221 - val_categorical_accuracy: 0.4300
# Epoch 20/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0523 - recall: 0.9801 - precision: 0.9801 - auc: 0.9977 - categorical_accuracy: 0.9801
# Epoch 00020: val_auc improved from 0.72420 to 0.78360, saving model to ../../tmp\checkpoints\20201229-152016\cp-0020.ckpt
# 41/41 [==============================] - 14s 353ms/step - loss: 0.0523 - recall: 0.9801 - precision: 0.9801 - auc: 0.9977 - categorical_accuracy: 0.9801 - val_loss: 1.2392 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7836 - val_categorical_accuracy: 0.7100
# Epoch 21/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0798 - recall: 0.9726 - precision: 0.9726 - auc: 0.9961 - categorical_accuracy: 0.9726
# Epoch 00021: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 0.0798 - recall: 0.9726 - precision: 0.9726 - auc: 0.9961 - categorical_accuracy: 0.9726 - val_loss: 1.0163 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7327 - val_categorical_accuracy: 0.6600
# Epoch 22/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0264 - recall: 0.9950 - precision: 0.9950 - auc: 0.9997 - categorical_accuracy: 0.9950
# Epoch 00022: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 0.0264 - recall: 0.9950 - precision: 0.9950 - auc: 0.9997 - categorical_accuracy: 0.9950 - val_loss: 1.9958 - val_recall: 0.4100 - val_precision: 0.4100 - val_auc: 0.4963 - val_categorical_accuracy: 0.4100
# Epoch 23/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0080 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00023: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 0.0080 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4517 - val_recall: 0.5900 - val_precision: 0.5900 - val_auc: 0.6112 - val_categorical_accuracy: 0.5900
# Epoch 24/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0028 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00024: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 0.0028 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2712 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7036 - val_categorical_accuracy: 0.7000
# Epoch 25/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0012 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00025: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 315ms/step - loss: 0.0012 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3360 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7332 - val_categorical_accuracy: 0.7100
# Epoch 26/200
# 41/41 [==============================] - ETA: 0s - loss: 8.6290e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00026: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 8.6290e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3568 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7520 - val_categorical_accuracy: 0.7200
# Epoch 27/200
# 41/41 [==============================] - ETA: 0s - loss: 6.7943e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00027: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 315ms/step - loss: 6.7943e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3957 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7657 - val_categorical_accuracy: 0.7300
# Epoch 28/200
# 41/41 [==============================] - ETA: 0s - loss: 5.5789e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00028: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 5.5789e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4326 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7678 - val_categorical_accuracy: 0.7500
# Epoch 29/200
# 41/41 [==============================] - ETA: 0s - loss: 4.6656e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00029: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 315ms/step - loss: 4.6656e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4675 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7686 - val_categorical_accuracy: 0.7500
# Epoch 30/200
# 41/41 [==============================] - ETA: 0s - loss: 3.9913e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00030: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 315ms/step - loss: 3.9913e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.4965 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7690 - val_categorical_accuracy: 0.7400
# Epoch 31/200
# 41/41 [==============================] - ETA: 0s - loss: 3.4722e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00031: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 315ms/step - loss: 3.4722e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5218 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7693 - val_categorical_accuracy: 0.7400
# Epoch 32/200
# 41/41 [==============================] - ETA: 0s - loss: 3.0609e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00032: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 320ms/step - loss: 3.0609e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5445 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7698 - val_categorical_accuracy: 0.7400
# Epoch 33/200
# 41/41 [==============================] - ETA: 0s - loss: 2.7280e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00033: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 2.7280e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5649 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7695 - val_categorical_accuracy: 0.7400
# Epoch 34/200
# 41/41 [==============================] - ETA: 0s - loss: 2.4505e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00034: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 2.4505e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.5837 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7727 - val_categorical_accuracy: 0.7400
# Epoch 35/200
# 41/41 [==============================] - ETA: 0s - loss: 2.2169e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00035: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 313ms/step - loss: 2.2169e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6016 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7724 - val_categorical_accuracy: 0.7400
# Epoch 36/200
# 41/41 [==============================] - ETA: 0s - loss: 2.0121e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00036: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 2.0121e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6189 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7724 - val_categorical_accuracy: 0.7400
# Epoch 37/200
# 41/41 [==============================] - ETA: 0s - loss: 1.8306e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00037: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 1.8306e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6357 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7725 - val_categorical_accuracy: 0.7400
# Epoch 38/200
# 41/41 [==============================] - ETA: 0s - loss: 1.6713e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00038: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 313ms/step - loss: 1.6713e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6521 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7725 - val_categorical_accuracy: 0.7400
# Epoch 39/200
# 41/41 [==============================] - ETA: 0s - loss: 1.5312e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00039: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 1.5312e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6676 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7725 - val_categorical_accuracy: 0.7400
# Epoch 40/200
# 41/41 [==============================] - ETA: 0s - loss: 1.4085e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00040: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 313ms/step - loss: 1.4085e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6825 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7728 - val_categorical_accuracy: 0.7400
# Epoch 41/200
# 41/41 [==============================] - ETA: 0s - loss: 1.3013e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00041: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 1.3013e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.6968 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7730 - val_categorical_accuracy: 0.7400
# Epoch 42/200
# 41/41 [==============================] - ETA: 0s - loss: 1.2071e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00042: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 1.2071e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.7103 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7728 - val_categorical_accuracy: 0.7400
# Epoch 43/200
# 41/41 [==============================] - ETA: 0s - loss: 1.1242e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00043: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 1.1242e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.7231 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7744 - val_categorical_accuracy: 0.7400
# Epoch 44/200
# 41/41 [==============================] - ETA: 0s - loss: 1.0514e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00044: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 314ms/step - loss: 1.0514e-04 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.7352 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7760 - val_categorical_accuracy: 0.7400
# Epoch 45/200
# 41/41 [==============================] - ETA: 0s - loss: 9.8731e-05 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00045: val_auc did not improve from 0.78360
# 41/41 [==============================] - 13s 315ms/step - loss: 9.8731e-05 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.7465 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7760 - val_categorical_accuracy: 0.7400
# Wall time: 12min 37s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 160 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 1.0886684656143188
# recall: 0.7099999785423279
# precision: 0.7099999785423279
# auc: 0.7835999131202698
# categorical_accuracy: 0.7099999785423279
#
# Wall time: 23.9 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.7538461538461538
# recall: 0.7903225806451613
# f1-score: 0.7716535433070866
# support: 62
#
#
# CN
# precision: 0.6285714285714286
# recall: 0.5789473684210527
# f1-score: 0.6027397260273972
# support: 38
#
#
# micro avg
# precision: 0.71
# recall: 0.71
# f1-score: 0.7100000000000001
# support: 100
#
#
# macro avg
# precision: 0.6912087912087912
# recall: 0.684634974533107
# f1-score: 0.6871966346672419
# support: 100
#
#
# weighted avg
# precision: 0.7062417582417582
# recall: 0.71
# f1-score: 0.7074662927408046
# support: 100
#
#
# samples avg
# precision: 0.71
# recall: 0.71
# f1-score: 0.71
# support: 100
#
#
# F1
# micro: 0.7100000000000001
# macro: 0.6871966346672419
#
#
# accuracy_score: 0.71
# sensitivity_score: 0.7903225806451613
# specificity_score: 0.5789473684210527
#
#
# Wall time: 22 s
