# %% [markdown]
# # 3D CNN

# %% [markdown]
# Basic + Batch Norm + Augmentations (invert, rotate, zoom, blur, noise) + Dropout (0.25) + l2

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
# import tensorflow as tf

# RANDOM_SEED = 792379571013149
# tf.random.set_seed(RANDOM_SEED)

# print(tf.version.VERSION)
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weightss (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201229-225712
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = '3d_cnn'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.05,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
    'batch_norm': True,
    'is_complex': True, # a complex layer from the paper, max batch_size is 3
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
#     'augmentations': False,
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.20),
        'shear': (0, 0), # probability, degrees
        'blur': (0.2, 0.85),
        'noise': (0.2, 0.00020)
    },
    'batch_size': 6,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 104, 128, 104, 32) 896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 104, 128, 104, 32) 128
# _________________________________________________________________
# activation (Activation)      (None, 104, 128, 104, 32) 0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 104, 128, 104, 32) 27680
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 104, 128, 104, 32) 128
# _________________________________________________________________
# activation_1 (Activation)    (None, 104, 128, 104, 32) 0
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 52, 64, 52, 32)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 52, 64, 52, 64)    55360
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 52, 64, 52, 64)    256
# _________________________________________________________________
# activation_2 (Activation)    (None, 52, 64, 52, 64)    0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 52, 64, 52, 64)    110656
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 52, 64, 52, 64)    256
# _________________________________________________________________
# activation_3 (Activation)    (None, 52, 64, 52, 64)    0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 17, 21, 17, 64)    0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 17, 21, 17, 128)   221312
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 17, 21, 17, 128)   512
# _________________________________________________________________
# activation_4 (Activation)    (None, 17, 21, 17, 128)   0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 17, 21, 17, 128)   442496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 17, 21, 17, 128)   512
# _________________________________________________________________
# activation_5 (Activation)    (None, 17, 21, 17, 128)   0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 4, 5, 4, 128)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 10240)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               5243392
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 6,235,426
# Trainable params: 6,234,530
# Non-trainable params: 896
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201229-225712
# checkpoint dir: ../../tmp\checkpoints\20201229-225712
# log dir: ../../tmp\logs\20201229-225712
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# Epoch 1/200
#  2/67 [..............................] - ETA: 28s - loss: 7.3225 - recall: 0.3333 - precision: 0.3333 - auc: 0.5000 - categorical_accuracy: 0.3333               WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2870s vs `on_train_batch_end` time: 0.5960s). Check your callbacks.
# 67/67 [==============================] - ETA: 0s - loss: 1.8050 - recall: 0.5323 - precision: 0.5323 - auc: 0.5455 - categorical_accuracy: 0.5323
# Epoch 00001: val_auc improved from -inf to 0.38520, saving model to ../../tmp\checkpoints\20201229-225712\cp-0001.ckpt
# 67/67 [==============================] - 65s 963ms/step - loss: 1.8050 - recall: 0.5323 - precision: 0.5323 - auc: 0.5455 - categorical_accuracy: 0.5323 - val_loss: 0.8582 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3852 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 67/67 [==============================] - ETA: 0s - loss: 0.9972 - recall: 0.5498 - precision: 0.5498 - auc: 0.5605 - categorical_accuracy: 0.5498
# Epoch 00002: val_auc did not improve from 0.38520
# 67/67 [==============================] - 64s 950ms/step - loss: 0.9972 - recall: 0.5498 - precision: 0.5498 - auc: 0.5605 - categorical_accuracy: 0.5498 - val_loss: 1.1316 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 67/67 [==============================] - ETA: 0s - loss: 0.9937 - recall: 0.5000 - precision: 0.5000 - auc: 0.4909 - categorical_accuracy: 0.5000
# Epoch 00003: val_auc did not improve from 0.38520
# 67/67 [==============================] - 63s 946ms/step - loss: 0.9937 - recall: 0.5000 - precision: 0.5000 - auc: 0.4909 - categorical_accuracy: 0.5000 - val_loss: 0.8058 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3838 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 67/67 [==============================] - ETA: 0s - loss: 0.8411 - recall: 0.4776 - precision: 0.4776 - auc: 0.4919 - categorical_accuracy: 0.4776
# Epoch 00004: val_auc did not improve from 0.38520
# 67/67 [==============================] - 63s 946ms/step - loss: 0.8411 - recall: 0.4776 - precision: 0.4776 - auc: 0.4919 - categorical_accuracy: 0.4776 - val_loss: 0.6940 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 67/67 [==============================] - ETA: 0s - loss: 0.7777 - recall: 0.4975 - precision: 0.4975 - auc: 0.4974 - categorical_accuracy: 0.4975
# Epoch 00005: val_auc improved from 0.38520 to 0.66120, saving model to ../../tmp\checkpoints\20201229-225712\cp-0005.ckpt
# 67/67 [==============================] - 64s 962ms/step - loss: 0.7777 - recall: 0.4975 - precision: 0.4975 - auc: 0.4974 - categorical_accuracy: 0.4975 - val_loss: 0.7510 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6612 - val_categorical_accuracy: 0.6200
# Epoch 6/200
# 67/67 [==============================] - ETA: 0s - loss: 0.7622 - recall: 0.5249 - precision: 0.5249 - auc: 0.5022 - categorical_accuracy: 0.5249
# Epoch 00006: val_auc did not improve from 0.66120
# 67/67 [==============================] - 64s 952ms/step - loss: 0.7622 - recall: 0.5249 - precision: 0.5249 - auc: 0.5022 - categorical_accuracy: 0.5249 - val_loss: 0.6959 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4396 - val_categorical_accuracy: 0.3800
# Epoch 7/200
# 67/67 [==============================] - ETA: 0s - loss: 0.7212 - recall: 0.5522 - precision: 0.5522 - auc: 0.5462 - categorical_accuracy: 0.5522
# Epoch 00007: val_auc improved from 0.66120 to 0.68360, saving model to ../../tmp\checkpoints\20201229-225712\cp-0007.ckpt
# 67/67 [==============================] - 64s 948ms/step - loss: 0.7212 - recall: 0.5522 - precision: 0.5522 - auc: 0.5462 - categorical_accuracy: 0.5522 - val_loss: 0.6965 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6836 - val_categorical_accuracy: 0.6200
# Epoch 8/200
# 67/67 [==============================] - ETA: 0s - loss: 0.7147 - recall: 0.5622 - precision: 0.5622 - auc: 0.5580 - categorical_accuracy: 0.5622
# Epoch 00008: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 951ms/step - loss: 0.7147 - recall: 0.5622 - precision: 0.5622 - auc: 0.5580 - categorical_accuracy: 0.5622 - val_loss: 0.6948 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4259 - val_categorical_accuracy: 0.3800
# Epoch 9/200
# 67/67 [==============================] - ETA: 0s - loss: 0.7108 - recall: 0.5498 - precision: 0.5498 - auc: 0.5658 - categorical_accuracy: 0.5498
# Epoch 00009: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 944ms/step - loss: 0.7108 - recall: 0.5498 - precision: 0.5498 - auc: 0.5658 - categorical_accuracy: 0.5498 - val_loss: 0.7056 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3580 - val_categorical_accuracy: 0.3800
# Epoch 10/200
# 67/67 [==============================] - ETA: 0s - loss: 0.7035 - recall: 0.5746 - precision: 0.5746 - auc: 0.5723 - categorical_accuracy: 0.5746
# Epoch 00010: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 944ms/step - loss: 0.7035 - recall: 0.5746 - precision: 0.5746 - auc: 0.5723 - categorical_accuracy: 0.5746 - val_loss: 0.6865 - val_recall: 0.5600 - val_precision: 0.5600 - val_auc: 0.6124 - val_categorical_accuracy: 0.5600
# Epoch 11/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6884 - recall: 0.5920 - precision: 0.5920 - auc: 0.5967 - categorical_accuracy: 0.5920
# Epoch 00011: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 956ms/step - loss: 0.6884 - recall: 0.5920 - precision: 0.5920 - auc: 0.5967 - categorical_accuracy: 0.5920 - val_loss: 0.6893 - val_recall: 0.5100 - val_precision: 0.5100 - val_auc: 0.5447 - val_categorical_accuracy: 0.5100
# Epoch 12/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6743 - recall: 0.6169 - precision: 0.6169 - auc: 0.6232 - categorical_accuracy: 0.6169
# Epoch 00012: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 955ms/step - loss: 0.6743 - recall: 0.6169 - precision: 0.6169 - auc: 0.6232 - categorical_accuracy: 0.6169 - val_loss: 0.6935 - val_recall: 0.4900 - val_precision: 0.4900 - val_auc: 0.4591 - val_categorical_accuracy: 0.4900
# Epoch 13/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6735 - recall: 0.5970 - precision: 0.5970 - auc: 0.6197 - categorical_accuracy: 0.5970
# Epoch 00013: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 945ms/step - loss: 0.6735 - recall: 0.5970 - precision: 0.5970 - auc: 0.6197 - categorical_accuracy: 0.5970 - val_loss: 0.6850 - val_recall: 0.5200 - val_precision: 0.5200 - val_auc: 0.5186 - val_categorical_accuracy: 0.5200
# Epoch 14/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6677 - recall: 0.5796 - precision: 0.5796 - auc: 0.6263 - categorical_accuracy: 0.5796
# Epoch 00014: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 948ms/step - loss: 0.6677 - recall: 0.5796 - precision: 0.5796 - auc: 0.6263 - categorical_accuracy: 0.5796 - val_loss: 0.6784 - val_recall: 0.5700 - val_precision: 0.5700 - val_auc: 0.6071 - val_categorical_accuracy: 0.5700
# Epoch 15/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6575 - recall: 0.5920 - precision: 0.5920 - auc: 0.6381 - categorical_accuracy: 0.5920
# Epoch 00015: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 950ms/step - loss: 0.6575 - recall: 0.5920 - precision: 0.5920 - auc: 0.6381 - categorical_accuracy: 0.5920 - val_loss: 0.6798 - val_recall: 0.5600 - val_precision: 0.5600 - val_auc: 0.6092 - val_categorical_accuracy: 0.5600
# Epoch 16/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6441 - recall: 0.6045 - precision: 0.6045 - auc: 0.6705 - categorical_accuracy: 0.6045
# Epoch 00016: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 944ms/step - loss: 0.6441 - recall: 0.6045 - precision: 0.6045 - auc: 0.6705 - categorical_accuracy: 0.6045 - val_loss: 0.6878 - val_recall: 0.5700 - val_precision: 0.5700 - val_auc: 0.5166 - val_categorical_accuracy: 0.5700
# Epoch 17/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6566 - recall: 0.6020 - precision: 0.6020 - auc: 0.6370 - categorical_accuracy: 0.6020
# Epoch 00017: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 946ms/step - loss: 0.6566 - recall: 0.6020 - precision: 0.6020 - auc: 0.6370 - categorical_accuracy: 0.6020 - val_loss: 0.6825 - val_recall: 0.5400 - val_precision: 0.5400 - val_auc: 0.5285 - val_categorical_accuracy: 0.5400
# Epoch 18/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6377 - recall: 0.6318 - precision: 0.6318 - auc: 0.6853 - categorical_accuracy: 0.6318
# Epoch 00018: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 942ms/step - loss: 0.6377 - recall: 0.6318 - precision: 0.6318 - auc: 0.6853 - categorical_accuracy: 0.6318 - val_loss: 0.6935 - val_recall: 0.5300 - val_precision: 0.5300 - val_auc: 0.4869 - val_categorical_accuracy: 0.5300
# Epoch 19/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6385 - recall: 0.6169 - precision: 0.6169 - auc: 0.6734 - categorical_accuracy: 0.6169
# Epoch 00019: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 950ms/step - loss: 0.6385 - recall: 0.6169 - precision: 0.6169 - auc: 0.6734 - categorical_accuracy: 0.6169 - val_loss: 0.6868 - val_recall: 0.5400 - val_precision: 0.5400 - val_auc: 0.5033 - val_categorical_accuracy: 0.5400
# Epoch 20/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6378 - recall: 0.6318 - precision: 0.6318 - auc: 0.6776 - categorical_accuracy: 0.6318
# Epoch 00020: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 946ms/step - loss: 0.6378 - recall: 0.6318 - precision: 0.6318 - auc: 0.6776 - categorical_accuracy: 0.6318 - val_loss: 0.6964 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.4755 - val_categorical_accuracy: 0.5000
# Epoch 21/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6221 - recall: 0.6493 - precision: 0.6493 - auc: 0.7113 - categorical_accuracy: 0.6493
# Epoch 00021: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 947ms/step - loss: 0.6221 - recall: 0.6493 - precision: 0.6493 - auc: 0.7113 - categorical_accuracy: 0.6493 - val_loss: 0.6887 - val_recall: 0.5500 - val_precision: 0.5500 - val_auc: 0.5265 - val_categorical_accuracy: 0.5500
# Epoch 22/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6201 - recall: 0.6368 - precision: 0.6368 - auc: 0.7006 - categorical_accuracy: 0.6368
# Epoch 00022: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 945ms/step - loss: 0.6201 - recall: 0.6368 - precision: 0.6368 - auc: 0.7006 - categorical_accuracy: 0.6368 - val_loss: 0.7008 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.4750 - val_categorical_accuracy: 0.5000
# Epoch 23/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6158 - recall: 0.6791 - precision: 0.6791 - auc: 0.7192 - categorical_accuracy: 0.6791
# Epoch 00023: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 949ms/step - loss: 0.6158 - recall: 0.6791 - precision: 0.6791 - auc: 0.7192 - categorical_accuracy: 0.6791 - val_loss: 0.6979 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.4880 - val_categorical_accuracy: 0.5000
# Epoch 24/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6061 - recall: 0.6567 - precision: 0.6567 - auc: 0.7408 - categorical_accuracy: 0.6567
# Epoch 00024: val_auc did not improve from 0.68360
# 67/67 [==============================] - 65s 969ms/step - loss: 0.6061 - recall: 0.6567 - precision: 0.6567 - auc: 0.7408 - categorical_accuracy: 0.6567 - val_loss: 0.6970 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.4905 - val_categorical_accuracy: 0.5000
# Epoch 25/200
# 67/67 [==============================] - ETA: 0s - loss: 0.6087 - recall: 0.6667 - precision: 0.6667 - auc: 0.7373 - categorical_accuracy: 0.6667
# Epoch 00025: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 941ms/step - loss: 0.6087 - recall: 0.6667 - precision: 0.6667 - auc: 0.7373 - categorical_accuracy: 0.6667 - val_loss: 0.7036 - val_recall: 0.5200 - val_precision: 0.5200 - val_auc: 0.4880 - val_categorical_accuracy: 0.5200
# Epoch 26/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5951 - recall: 0.6915 - precision: 0.6915 - auc: 0.7611 - categorical_accuracy: 0.6915
# Epoch 00026: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 956ms/step - loss: 0.5951 - recall: 0.6915 - precision: 0.6915 - auc: 0.7611 - categorical_accuracy: 0.6915 - val_loss: 0.6988 - val_recall: 0.5300 - val_precision: 0.5300 - val_auc: 0.5388 - val_categorical_accuracy: 0.5300
# Epoch 27/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5801 - recall: 0.7090 - precision: 0.7090 - auc: 0.7861 - categorical_accuracy: 0.7090
# Epoch 00027: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 952ms/step - loss: 0.5801 - recall: 0.7090 - precision: 0.7090 - auc: 0.7861 - categorical_accuracy: 0.7090 - val_loss: 0.7049 - val_recall: 0.5600 - val_precision: 0.5600 - val_auc: 0.5117 - val_categorical_accuracy: 0.5600
# Epoch 28/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5877 - recall: 0.6816 - precision: 0.6816 - auc: 0.7631 - categorical_accuracy: 0.6816
# Epoch 00028: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 947ms/step - loss: 0.5877 - recall: 0.6816 - precision: 0.6816 - auc: 0.7631 - categorical_accuracy: 0.6816 - val_loss: 0.7045 - val_recall: 0.5500 - val_precision: 0.5500 - val_auc: 0.5053 - val_categorical_accuracy: 0.5500
# Epoch 29/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5908 - recall: 0.6617 - precision: 0.6617 - auc: 0.7536 - categorical_accuracy: 0.6617
# Epoch 00029: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 945ms/step - loss: 0.5908 - recall: 0.6617 - precision: 0.6617 - auc: 0.7536 - categorical_accuracy: 0.6617 - val_loss: 0.7037 - val_recall: 0.5200 - val_precision: 0.5200 - val_auc: 0.5056 - val_categorical_accuracy: 0.5200
# Epoch 30/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5722 - recall: 0.6816 - precision: 0.6816 - auc: 0.7913 - categorical_accuracy: 0.6816
# Epoch 00030: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 955ms/step - loss: 0.5722 - recall: 0.6816 - precision: 0.6816 - auc: 0.7913 - categorical_accuracy: 0.6816 - val_loss: 0.7045 - val_recall: 0.5300 - val_precision: 0.5300 - val_auc: 0.5128 - val_categorical_accuracy: 0.5300
# Epoch 31/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5718 - recall: 0.6990 - precision: 0.6990 - auc: 0.7856 - categorical_accuracy: 0.6990
# Epoch 00031: val_auc did not improve from 0.68360
# 67/67 [==============================] - 64s 950ms/step - loss: 0.5718 - recall: 0.6990 - precision: 0.6990 - auc: 0.7856 - categorical_accuracy: 0.6990 - val_loss: 0.6933 - val_recall: 0.5800 - val_precision: 0.5800 - val_auc: 0.5434 - val_categorical_accuracy: 0.5800
# Epoch 32/200
# 67/67 [==============================] - ETA: 0s - loss: 0.5586 - recall: 0.7015 - precision: 0.7015 - auc: 0.8019 - categorical_accuracy: 0.7015
# Epoch 00032: val_auc did not improve from 0.68360
# 67/67 [==============================] - 63s 944ms/step - loss: 0.5586 - recall: 0.7015 - precision: 0.7015 - auc: 0.8019 - categorical_accuracy: 0.7015 - val_loss: 0.6897 - val_recall: 0.5900 - val_precision: 0.5900 - val_auc: 0.5557 - val_categorical_accuracy: 0.5900
# Wall time: 35min 31s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 156 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Desktop\dp\src\model\evaluation\show_simple_metrics.py in show_simple_metrics(model, test_seq)
#       1 def show_simple_metrics(model, test_seq):
# ----> 2     baseline_results = model.evaluate(test_seq, verbose=0)
#       3     for name, value in zip(model.metrics_names, baseline_results):
#       4         print(f'{name}: {value}')
#       5     print()
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378               callbacks.on_test_batch_begin(step)
# -> 1379               tmp_logs = test_function(iterator)
#    1380               if data_handler.should_sync:
#    1381                 context.async_wait()
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted:  OOM when allocating tensor with shape[12,32,104,128,104] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node sequential/conv3d_1/Conv3D (defined at ../..\src\model\evaluation\show_simple_metrics.py:2) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[assert_less_equal_2/Assert/AssertGuard/pivot_f/_69/_107]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted:  OOM when allocating tensor with shape[12,32,104,128,104] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node sequential/conv3d_1/Conv3D (defined at ../..\src\model\evaluation\show_simple_metrics.py:2) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_test_function_457312]
#
# Function call stack:
# test_function -> test_function

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Desktop\dp\src\model\evaluation\show_metrics.py in show_metrics(model, test_seq, class_names)
#      13         x, y, *_ = batch
#      14
# ---> 15         pred = model.predict(x)
#      16
#      17         y_true = np.concatenate([y_true, y])
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     844               *args, **kwds)
#     845       # If we did not create any variables the trace we have is good enough.
# --> 846       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     847
#     848     def fn_with_cond(*inner_args, **inner_kwds):
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[12,32,104,128,104] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node sequential/conv3d_1/Conv3D (defined at ../..\src\model\evaluation\show_metrics.py:15) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_predict_function_457541]
#
# Function call stack:
# predict_function
