# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise) + Batch Norm + Dropout (0.5)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201215-204816
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet50V2'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
    'dropout': 0.50,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
#     'batch_norm': False,
    'batch_norm': True,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\applications\imagenet_utils.py:333: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 104 input channels.
#   str(input_shape[-1]) + ' input channels.')
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 1024)              25979712
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 26,642,498
# Trainable params: 26,593,986
# Non-trainable params: 48,512
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201215-204816
# checkpoint dir: ../../tmp\checkpoints\20201215-204816
# log dir: ../../tmp\logs\20201215-204816
# loading ../../tmp\data-v3\train-ResNet_x.npy, ../../tmp\data-v3\train-ResNet_y.npy...
# loading ../../tmp\data-v3\val-ResNet_x.npy, ../../tmp\data-v3\val-ResNet_y.npy...
# training...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 1.0459 - recall: 0.4851 - precision: 0.4851 - auc: 0.4686 - categorical_accuracy: 0.4851- ETA: 3s - loss: 0.9194 - recall: 0.4769 - precision: 0.4769 - auc: 0.4689 -
# Epoch 00001: val_auc improved from -inf to 0.38000, saving model to ../../tmp\checkpoints\20201215-204816\cp-0001.ckpt
# 41/41 [==============================] - 10s 248ms/step - loss: 1.0459 - recall: 0.4851 - precision: 0.4851 - auc: 0.4686 - categorical_accuracy: 0.4851 - val_loss: 0.7291 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.8257 - recall: 0.5075 - precision: 0.5075 - auc: 0.5095 - categorical_accuracy: 0.5075- ETA: 4s - loss: 0.8592 - recall: 0.4917 - precision: 0.4917 - auc: 0.5096 - c
# Epoch 00002: val_auc did not improve from 0.38000
# 41/41 [==============================] - 6s 135ms/step - loss: 0.8244 - recall: 0.5075 - precision: 0.5075 - auc: 0.5093 - categorical_accuracy: 0.5075 - val_loss: 0.7077 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.8149 - recall: 0.5200 - precision: 0.5200 - auc: 0.5288 - categorical_accuracy: 0.5200
# Epoch 00003: val_auc did not improve from 0.38000
# 41/41 [==============================] - 6s 155ms/step - loss: 0.8140 - recall: 0.5199 - precision: 0.5199 - auc: 0.5282 - categorical_accuracy: 0.5199 - val_loss: 0.7004 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6828 - recall: 0.5950 - precision: 0.5950 - auc: 0.6568 - categorical_accuracy: 0.5950
# Epoch 00004: val_auc did not improve from 0.38000
# 41/41 [==============================] - 6s 158ms/step - loss: 0.6830 - recall: 0.5920 - precision: 0.5920 - auc: 0.6552 - categorical_accuracy: 0.5920 - val_loss: 0.6961 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5535 - recall: 0.7025 - precision: 0.7025 - auc: 0.7740 - categorical_accuracy: 0.7025- ETA: 0s - loss: 0.5622 - recall: 0.6972 - precision: 0.6972 - auc: 0.7606 - categorical_accuracy: 0.
# Epoch 00005: val_auc improved from 0.38000 to 0.42960, saving model to ../../tmp\checkpoints\20201215-204816\cp-0005.ckpt
# 41/41 [==============================] - 8s 191ms/step - loss: 0.5556 - recall: 0.7015 - precision: 0.7015 - auc: 0.7723 - categorical_accuracy: 0.7015 - val_loss: 0.6922 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4296 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5127 - recall: 0.7550 - precision: 0.7550 - auc: 0.8345 - categorical_accuracy: 0.7550- ETA: 3s - loss: 0.5376 - recall: 0.7545 - precision: 0.7545 - auc: 0.8055 -
# Epoch 00006: val_auc improved from 0.42960 to 0.70000, saving model to ../../tmp\checkpoints\20201215-204816\cp-0006.ckpt
# 41/41 [==============================] - 8s 190ms/step - loss: 0.5147 - recall: 0.7537 - precision: 0.7537 - auc: 0.8327 - categorical_accuracy: 0.7537 - val_loss: 0.6907 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.7000 - val_categorical_accuracy: 0.6200
# Epoch 7/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4506 - recall: 0.7975 - precision: 0.7975 - auc: 0.8621 - categorical_accuracy: 0.7975
# Epoch 00007: val_auc improved from 0.70000 to 0.70820, saving model to ../../tmp\checkpoints\20201215-204816\cp-0007.ckpt
# 41/41 [==============================] - 7s 173ms/step - loss: 0.4517 - recall: 0.7960 - precision: 0.7960 - auc: 0.8610 - categorical_accuracy: 0.7960 - val_loss: 0.6921 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.7082 - val_categorical_accuracy: 0.6200
# Epoch 8/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3548 - recall: 0.8557 - precision: 0.8557 - auc: 0.9167 - categorical_accuracy: 0.8557
# Epoch 00008: val_auc improved from 0.70820 to 0.71020, saving model to ../../tmp\checkpoints\20201215-204816\cp-0008.ckpt
# 41/41 [==============================] - 7s 181ms/step - loss: 0.3548 - recall: 0.8557 - precision: 0.8557 - auc: 0.9167 - categorical_accuracy: 0.8557 - val_loss: 0.6931 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.7102 - val_categorical_accuracy: 0.6200
# Epoch 9/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4340 - recall: 0.7975 - precision: 0.7975 - auc: 0.8763 - categorical_accuracy: 0.7975- ETA: 2s - loss: 0.4032 - recall: 0.8059 - precision: 0.8059 - auc: 0.8879 - categ
# Epoch 00009: val_auc did not improve from 0.71020
# 41/41 [==============================] - 5s 132ms/step - loss: 0.4396 - recall: 0.7960 - precision: 0.7960 - auc: 0.8735 - categorical_accuracy: 0.7960 - val_loss: 0.6846 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6957 - val_categorical_accuracy: 0.6200
# Epoch 10/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3772 - recall: 0.8400 - precision: 0.8400 - auc: 0.9084 - categorical_accuracy: 0.8400
# Epoch 00010: val_auc did not improve from 0.71020
# 41/41 [==============================] - 6s 139ms/step - loss: 0.3779 - recall: 0.8383 - precision: 0.8383 - auc: 0.9079 - categorical_accuracy: 0.8383 - val_loss: 0.6979 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6798 - val_categorical_accuracy: 0.6200
# Epoch 11/200
# 41/41 [==============================] - ETA: 0s - loss: 0.2338 - recall: 0.8831 - precision: 0.8831 - auc: 0.9595 - categorical_accuracy: 0.8831
# Epoch 00011: val_auc improved from 0.71020 to 0.76460, saving model to ../../tmp\checkpoints\20201215-204816\cp-0011.ckpt
# 41/41 [==============================] - 8s 191ms/step - loss: 0.2338 - recall: 0.8831 - precision: 0.8831 - auc: 0.9595 - categorical_accuracy: 0.8831 - val_loss: 0.6456 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7646 - val_categorical_accuracy: 0.7100
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2493 - recall: 0.8750 - precision: 0.8750 - auc: 0.9553 - categorical_accuracy: 0.8750- ETA: 0s - loss: 0.2586 - recall: 0.8719 - precision: 0.8719 - auc: 0.9507 - categorical_accuracy:
# Epoch 00012: val_auc did not improve from 0.76460
# 41/41 [==============================] - 5s 125ms/step - loss: 0.2539 - recall: 0.8731 - precision: 0.8731 - auc: 0.9537 - categorical_accuracy: 0.8731 - val_loss: 0.6863 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7113 - val_categorical_accuracy: 0.6500
# Epoch 13/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2093 - recall: 0.9275 - precision: 0.9275 - auc: 0.9689 - categorical_accuracy: 0.9275- ETA: 4s - loss: 0.2242 - recall: 0.9000 - precision: 0.9000 - auc: 0.961
# Epoch 00013: val_auc did not improve from 0.76460
# 41/41 [==============================] - 6s 140ms/step - loss: 0.2297 - recall: 0.9254 - precision: 0.9254 - auc: 0.9648 - categorical_accuracy: 0.9254 - val_loss: 0.6671 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7626 - val_categorical_accuracy: 0.6600
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2251 - recall: 0.9125 - precision: 0.9125 - auc: 0.9649 - categorical_accuracy: 0.9125
# Epoch 00014: val_auc improved from 0.76460 to 0.81160, saving model to ../../tmp\checkpoints\20201215-204816\cp-0014.ckpt
# 41/41 [==============================] - 8s 205ms/step - loss: 0.2321 - recall: 0.9104 - precision: 0.9104 - auc: 0.9619 - categorical_accuracy: 0.9104 - val_loss: 0.6120 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8116 - val_categorical_accuracy: 0.7300
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1733 - recall: 0.9250 - precision: 0.9250 - auc: 0.9807 - categorical_accuracy: 0.9250
# Epoch 00015: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 150ms/step - loss: 0.1747 - recall: 0.9229 - precision: 0.9229 - auc: 0.9803 - categorical_accuracy: 0.9229 - val_loss: 0.5682 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7314 - val_categorical_accuracy: 0.6600
# Epoch 16/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1916 - recall: 0.9125 - precision: 0.9125 - auc: 0.9755 - categorical_accuracy: 0.9125
# Epoch 00016: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 147ms/step - loss: 0.1953 - recall: 0.9104 - precision: 0.9104 - auc: 0.9745 - categorical_accuracy: 0.9104 - val_loss: 0.6126 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7649 - val_categorical_accuracy: 0.6800
# Epoch 17/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1789 - recall: 0.9400 - precision: 0.9400 - auc: 0.9768 - categorical_accuracy: 0.9400
# Epoch 00017: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 145ms/step - loss: 0.1815 - recall: 0.9378 - precision: 0.9378 - auc: 0.9761 - categorical_accuracy: 0.9378 - val_loss: 0.7689 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7782 - val_categorical_accuracy: 0.7300
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1616 - recall: 0.9250 - precision: 0.9250 - auc: 0.9798 - categorical_accuracy: 0.9250
# Epoch 00018: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 137ms/step - loss: 0.1627 - recall: 0.9229 - precision: 0.9229 - auc: 0.9795 - categorical_accuracy: 0.9229 - val_loss: 1.0002 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7584 - val_categorical_accuracy: 0.7500
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1252 - recall: 0.9575 - precision: 0.9575 - auc: 0.9876 - categorical_accuracy: 0.9575
# Epoch 00019: val_auc did not improve from 0.81160
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1340 - recall: 0.9552 - precision: 0.9552 - auc: 0.9851 - categorical_accuracy: 0.9552 - val_loss: 0.6627 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7584 - val_categorical_accuracy: 0.6500
# Epoch 20/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0960 - recall: 0.9625 - precision: 0.9625 - auc: 0.9950 - categorical_accuracy: 0.9625- ETA: 4s - loss: 0.0859 - recall: 0.9667 - precision: 0.9667 - auc:
# Epoch 00020: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 139ms/step - loss: 0.1135 - recall: 0.9602 - precision: 0.9602 - auc: 0.9909 - categorical_accuracy: 0.9602 - val_loss: 0.8312 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7308 - val_categorical_accuracy: 0.6700
# Epoch 21/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1198 - recall: 0.9575 - precision: 0.9575 - auc: 0.9903 - categorical_accuracy: 0.9575
# Epoch 00021: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 145ms/step - loss: 0.1208 - recall: 0.9577 - precision: 0.9577 - auc: 0.9902 - categorical_accuracy: 0.9577 - val_loss: 0.8188 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7702 - val_categorical_accuracy: 0.7200
# Epoch 22/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1249 - recall: 0.9525 - precision: 0.9525 - auc: 0.9867 - categorical_accuracy: 0.9525
# Epoch 00022: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 144ms/step - loss: 0.1270 - recall: 0.9502 - precision: 0.9502 - auc: 0.9863 - categorical_accuracy: 0.9502 - val_loss: 0.8978 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7744 - val_categorical_accuracy: 0.6900
# Epoch 23/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0935 - recall: 0.9677 - precision: 0.9677 - auc: 0.9919 - categorical_accuracy: 0.9677
# Epoch 00023: val_auc did not improve from 0.81160
# 41/41 [==============================] - 5s 133ms/step - loss: 0.0935 - recall: 0.9677 - precision: 0.9677 - auc: 0.9919 - categorical_accuracy: 0.9677 - val_loss: 0.8496 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7674 - val_categorical_accuracy: 0.6500
# Epoch 24/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1103 - recall: 0.9701 - precision: 0.9701 - auc: 0.9887 - categorical_accuracy: 0.9701
# Epoch 00024: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 141ms/step - loss: 0.1103 - recall: 0.9701 - precision: 0.9701 - auc: 0.9887 - categorical_accuracy: 0.9701 - val_loss: 0.8263 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7652 - val_categorical_accuracy: 0.6700
# Epoch 25/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0996 - recall: 0.9650 - precision: 0.9650 - auc: 0.9919 - categorical_accuracy: 0.9650
# Epoch 00025: val_auc did not improve from 0.81160
# 41/41 [==============================] - 5s 134ms/step - loss: 0.1021 - recall: 0.9627 - precision: 0.9627 - auc: 0.9916 - categorical_accuracy: 0.9627 - val_loss: 0.7186 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7803 - val_categorical_accuracy: 0.6900
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0867 - recall: 0.9775 - precision: 0.9775 - auc: 0.9945 - categorical_accuracy: 0.9775
# Epoch 00026: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0933 - recall: 0.9751 - precision: 0.9751 - auc: 0.9932 - categorical_accuracy: 0.9751 - val_loss: 0.8305 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7355 - val_categorical_accuracy: 0.6400
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0771 - recall: 0.9725 - precision: 0.9725 - auc: 0.9962 - categorical_accuracy: 0.9725- ETA: 3s - loss: 0.0401 - recall: 0.9882 - precision: 0.9882 - auc: 0.9997 - categ
# Epoch 00027: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0909 - recall: 0.9701 - precision: 0.9701 - auc: 0.9923 - categorical_accuracy: 0.9701 - val_loss: 0.8799 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7399 - val_categorical_accuracy: 0.6400
# Epoch 28/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0606 - recall: 0.9800 - precision: 0.9800 - auc: 0.9990 - categorical_accuracy: 0.9800
# Epoch 00028: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0668 - recall: 0.9776 - precision: 0.9776 - auc: 0.9976 - categorical_accuracy: 0.9776 - val_loss: 0.8433 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.7362 - val_categorical_accuracy: 0.6200
# Epoch 29/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0707 - recall: 0.9800 - precision: 0.9800 - auc: 0.9971 - categorical_accuracy: 0.9800
# Epoch 00029: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 144ms/step - loss: 0.0731 - recall: 0.9776 - precision: 0.9776 - auc: 0.9969 - categorical_accuracy: 0.9776 - val_loss: 0.8633 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7563 - val_categorical_accuracy: 0.6500
# Epoch 30/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0457 - recall: 0.9875 - precision: 0.9875 - auc: 0.9994 - categorical_accuracy: 0.9875
# Epoch 00030: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0623 - recall: 0.9851 - precision: 0.9851 - auc: 0.9956 - categorical_accuracy: 0.9851 - val_loss: 0.9138 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7637 - val_categorical_accuracy: 0.6800
# Epoch 31/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0418 - recall: 0.9900 - precision: 0.9900 - auc: 0.9993 - categorical_accuracy: 0.9900
# Epoch 00031: val_auc did not improve from 0.81160
# 41/41 [==============================] - 5s 131ms/step - loss: 0.0457 - recall: 0.9876 - precision: 0.9876 - auc: 0.9990 - categorical_accuracy: 0.9876 - val_loss: 0.8782 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7567 - val_categorical_accuracy: 0.6600
# Epoch 32/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0514 - recall: 0.9775 - precision: 0.9775 - auc: 0.9988 - categorical_accuracy: 0.9775
# Epoch 00032: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 141ms/step - loss: 0.0556 - recall: 0.9751 - precision: 0.9751 - auc: 0.9984 - categorical_accuracy: 0.9751 - val_loss: 0.9175 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.7516 - val_categorical_accuracy: 0.6500
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0419 - recall: 0.9850 - precision: 0.9850 - auc: 0.9993 - categorical_accuracy: 0.9850
# Epoch 00033: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0434 - recall: 0.9851 - precision: 0.9851 - auc: 0.9993 - categorical_accuracy: 0.9851 - val_loss: 0.9770 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7773 - val_categorical_accuracy: 0.7000
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0428 - recall: 0.9825 - precision: 0.9825 - auc: 0.9993 - categorical_accuracy: 0.9825
# Epoch 00034: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 141ms/step - loss: 0.0615 - recall: 0.9801 - precision: 0.9801 - auc: 0.9958 - categorical_accuracy: 0.9801 - val_loss: 0.8865 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7824 - val_categorical_accuracy: 0.6900
# Epoch 35/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0563 - recall: 0.9800 - precision: 0.9800 - auc: 0.9986 - categorical_accuracy: 0.9800
# Epoch 00035: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 141ms/step - loss: 0.0577 - recall: 0.9776 - precision: 0.9776 - auc: 0.9985 - categorical_accuracy: 0.9776 - val_loss: 0.7774 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7802 - val_categorical_accuracy: 0.6700
# Epoch 36/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0377 - recall: 0.9900 - precision: 0.9900 - auc: 0.9995 - categorical_accuracy: 0.9900
# Epoch 00036: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0394 - recall: 0.9876 - precision: 0.9876 - auc: 0.9995 - categorical_accuracy: 0.9876 - val_loss: 0.8620 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7624 - val_categorical_accuracy: 0.6900
# Epoch 37/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0341 - recall: 0.9950 - precision: 0.9950 - auc: 0.9993 - categorical_accuracy: 0.9950- ETA: 4s - loss: 0.0151 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000
# Epoch 00037: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0419 - recall: 0.9925 - precision: 0.9925 - auc: 0.9981 - categorical_accuracy: 0.9925 - val_loss: 0.8297 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7400 - val_categorical_accuracy: 0.6400
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0336 - recall: 0.9875 - precision: 0.9875 - auc: 0.9995 - categorical_accuracy: 0.9875
# Epoch 00038: val_auc did not improve from 0.81160
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0367 - recall: 0.9851 - precision: 0.9851 - auc: 0.9993 - categorical_accuracy: 0.9851 - val_loss: 0.7470 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7608 - val_categorical_accuracy: 0.6800
# Epoch 39/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0338 - recall: 0.9925 - precision: 0.9925 - auc: 0.9997 - categorical_accuracy: 0.9925- ETA: 1s - loss: 0.0135 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accurac
# Epoch 00039: val_auc did not improve from 0.81160
# 41/41 [==============================] - 5s 132ms/step - loss: 0.0416 - recall: 0.9900 - precision: 0.9900 - auc: 0.9985 - categorical_accuracy: 0.9900 - val_loss: 0.7929 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7664 - val_categorical_accuracy: 0.7000
# Wall time: 5min 33s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 170 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.5382878184318542
# recall: 0.7300000190734863
# precision: 0.7300000190734863
# auc: 0.8115999698638916
# categorical_accuracy: 0.7300000190734863
#
# Wall time: 25.5 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.7011494252873564
# recall: 0.9838709677419355
# f1-score: 0.8187919463087249
# support: 62
#
#
# CN
# precision: 0.9230769230769231
# recall: 0.3157894736842105
# f1-score: 0.47058823529411764
# support: 38
#
#
# micro avg
# precision: 0.73
# recall: 0.73
# f1-score: 0.7299999999999999
# support: 100
#
#
# macro avg
# precision: 0.8121131741821397
# recall: 0.6498302207130731
# f1-score: 0.6446900908014213
# support: 100
#
#
# weighted avg
# precision: 0.7854818744473917
# recall: 0.73
# f1-score: 0.6864745361231741
# support: 100
#
#
# samples avg
# precision: 0.73
# recall: 0.73
# f1-score: 0.73
# support: 100
#
#
# F1
# micro: 0.7299999999999999
# macro: 0.6446900908014213
#
#
# accuracy_score: 0.73
# sensitivity_score: 0.9838709677419355
# specificity_score: 0.3157894736842105
#
#
# Wall time: 22.4 s
