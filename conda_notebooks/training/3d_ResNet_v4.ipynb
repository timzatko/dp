# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise) + Dropout (0.25)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201216-160204
# Wall time: 4 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet50V2'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
    'dropout': 0.25,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\applications\imagenet_utils.py:333: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 104 input channels.
#   str(input_shape[-1]) + ' input channels.')
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 1024)              25979712
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 26,636,354
# Trainable params: 26,590,914
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201216-160204
# checkpoint dir: ../../tmp\checkpoints\20201216-160204
# log dir: ../../tmp\logs\20201216-160204
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 0.7475 - recall: 0.3806 - precision: 0.3806 - auc: 0.3517 - categorical_accuracy: 0.3806
# Epoch 00001: val_auc improved from -inf to 0.38000, saving model to ../../tmp\checkpoints\20201216-160204\cp-0001.ckpt
# 41/41 [==============================] - 8s 198ms/step - loss: 0.7475 - recall: 0.3806 - precision: 0.3806 - auc: 0.3517 - categorical_accuracy: 0.3806 - val_loss: 0.7171 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7078 - recall: 0.4125 - precision: 0.4125 - auc: 0.3939 - categorical_accuracy: 0.4125
# Epoch 00002: val_auc improved from 0.38000 to 0.39910, saving model to ../../tmp\checkpoints\20201216-160204\cp-0002.ckpt
# 41/41 [==============================] - 6s 153ms/step - loss: 0.7071 - recall: 0.4129 - precision: 0.4129 - auc: 0.3946 - categorical_accuracy: 0.4129 - val_loss: 0.6965 - val_recall: 0.3900 - val_precision: 0.3900 - val_auc: 0.3991 - val_categorical_accuracy: 0.3900
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6937 - recall: 0.4725 - precision: 0.4725 - auc: 0.4953 - categorical_accuracy: 0.4725
# Epoch 00003: val_auc improved from 0.39910 to 0.62000, saving model to ../../tmp\checkpoints\20201216-160204\cp-0003.ckpt
# 41/41 [==============================] - 6s 158ms/step - loss: 0.6933 - recall: 0.4701 - precision: 0.4701 - auc: 0.4931 - categorical_accuracy: 0.4701 - val_loss: 0.7052 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6200 - val_categorical_accuracy: 0.6200
# Epoch 4/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7112 - recall: 0.4825 - precision: 0.4825 - auc: 0.4882 - categorical_accuracy: 0.4825
# Epoch 00004: val_auc did not improve from 0.62000
# 41/41 [==============================] - 5s 113ms/step - loss: 0.7111 - recall: 0.4801 - precision: 0.4801 - auc: 0.4848 - categorical_accuracy: 0.4801 - val_loss: 0.6973 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3724 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7048 - recall: 0.3900 - precision: 0.3900 - auc: 0.3782 - categorical_accuracy: 0.3900
# Epoch 00005: val_auc did not improve from 0.62000
# 41/41 [==============================] - 5s 120ms/step - loss: 0.7044 - recall: 0.3881 - precision: 0.3881 - auc: 0.3766 - categorical_accuracy: 0.3881 - val_loss: 0.6931 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6988 - recall: 0.4925 - precision: 0.4925 - auc: 0.4788 - categorical_accuracy: 0.4925
# Epoch 00006: val_auc improved from 0.62000 to 0.62825, saving model to ../../tmp\checkpoints\20201216-160204\cp-0006.ckpt
# 41/41 [==============================] - 6s 157ms/step - loss: 0.6985 - recall: 0.4900 - precision: 0.4900 - auc: 0.4751 - categorical_accuracy: 0.4900 - val_loss: 0.6925 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6283 - val_categorical_accuracy: 0.6100
# Epoch 7/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7011 - recall: 0.4875 - precision: 0.4875 - auc: 0.4563 - categorical_accuracy: 0.4875- ETA: 1s - loss: 0.6896 - recall: 0.4731 - precision: 0.4731 - auc: 0.4305 - categorical_ac
# Epoch 00007: val_auc improved from 0.62825 to 0.63440, saving model to ../../tmp\checkpoints\20201216-160204\cp-0007.ckpt
# 41/41 [==============================] - 6s 156ms/step - loss: 0.7007 - recall: 0.4851 - precision: 0.4851 - auc: 0.4534 - categorical_accuracy: 0.4851 - val_loss: 0.6926 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6344 - val_categorical_accuracy: 0.6200
# Epoch 8/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6823 - recall: 0.5600 - precision: 0.5600 - auc: 0.5735 - categorical_accuracy: 0.5600
# Epoch 00008: val_auc improved from 0.63440 to 0.65290, saving model to ../../tmp\checkpoints\20201216-160204\cp-0008.ckpt
# 41/41 [==============================] - 6s 144ms/step - loss: 0.6818 - recall: 0.5597 - precision: 0.5597 - auc: 0.5729 - categorical_accuracy: 0.5597 - val_loss: 0.7003 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.6529 - val_categorical_accuracy: 0.6300
# Epoch 9/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7141 - recall: 0.4875 - precision: 0.4875 - auc: 0.5317 - categorical_accuracy: 0.4875
# Epoch 00009: val_auc did not improve from 0.65290
# 41/41 [==============================] - 5s 121ms/step - loss: 0.7134 - recall: 0.4876 - precision: 0.4876 - auc: 0.5310 - categorical_accuracy: 0.4876 - val_loss: 0.6930 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 10/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7014 - recall: 0.4425 - precision: 0.4425 - auc: 0.4140 - categorical_accuracy: 0.4425
# Epoch 00010: val_auc did not improve from 0.65290
# 41/41 [==============================] - 5s 126ms/step - loss: 0.7009 - recall: 0.4403 - precision: 0.4403 - auc: 0.4111 - categorical_accuracy: 0.4403 - val_loss: 0.6953 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3676 - val_categorical_accuracy: 0.3800
# Epoch 11/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6990 - recall: 0.4550 - precision: 0.4550 - auc: 0.4427 - categorical_accuracy: 0.4550
# Epoch 00011: val_auc did not improve from 0.65290
# 41/41 [==============================] - 5s 127ms/step - loss: 0.6984 - recall: 0.4552 - precision: 0.4552 - auc: 0.4425 - categorical_accuracy: 0.4552 - val_loss: 0.6920 - val_recall: 0.4300 - val_precision: 0.4300 - val_auc: 0.4345 - val_categorical_accuracy: 0.4300
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6958 - recall: 0.5175 - precision: 0.5175 - auc: 0.5664 - categorical_accuracy: 0.5175
# Epoch 00012: val_auc did not improve from 0.65290
# 41/41 [==============================] - 5s 116ms/step - loss: 0.6950 - recall: 0.5174 - precision: 0.5174 - auc: 0.5671 - categorical_accuracy: 0.5174 - val_loss: 0.7086 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3738 - val_categorical_accuracy: 0.3800
# Epoch 13/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6896 - recall: 0.5550 - precision: 0.5550 - auc: 0.5751 - categorical_accuracy: 0.5550
# Epoch 00013: val_auc did not improve from 0.65290
# 41/41 [==============================] - 5s 111ms/step - loss: 0.6890 - recall: 0.5547 - precision: 0.5547 - auc: 0.5751 - categorical_accuracy: 0.5547 - val_loss: 0.6980 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3824 - val_categorical_accuracy: 0.3800
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6921 - recall: 0.5550 - precision: 0.5550 - auc: 0.5245 - categorical_accuracy: 0.5550
# Epoch 00014: val_auc did not improve from 0.65290
# 41/41 [==============================] - 5s 115ms/step - loss: 0.6917 - recall: 0.5547 - precision: 0.5547 - auc: 0.5229 - categorical_accuracy: 0.5547 - val_loss: 0.6819 - val_recall: 0.4200 - val_precision: 0.4200 - val_auc: 0.4805 - val_categorical_accuracy: 0.4200
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6893 - recall: 0.5625 - precision: 0.5625 - auc: 0.5296 - categorical_accuracy: 0.5625
# Epoch 00015: val_auc improved from 0.65290 to 0.66575, saving model to ../../tmp\checkpoints\20201216-160204\cp-0015.ckpt
# 41/41 [==============================] - 7s 164ms/step - loss: 0.6889 - recall: 0.5622 - precision: 0.5622 - auc: 0.5282 - categorical_accuracy: 0.5622 - val_loss: 0.6747 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.6658 - val_categorical_accuracy: 0.6700
# Epoch 16/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6822 - recall: 0.5850 - precision: 0.5850 - auc: 0.5902 - categorical_accuracy: 0.5850
# Epoch 00016: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 128ms/step - loss: 0.6814 - recall: 0.5846 - precision: 0.5846 - auc: 0.5913 - categorical_accuracy: 0.5846 - val_loss: 0.6967 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6058 - val_categorical_accuracy: 0.6100
# Epoch 17/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6635 - recall: 0.6075 - precision: 0.6075 - auc: 0.6480 - categorical_accuracy: 0.6075- ETA: 1s - loss: 0.6563 - recall: 0.6037 - precision: 0.6037 - auc: 0.6344 - categorical_acc
# Epoch 00017: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 124ms/step - loss: 0.6629 - recall: 0.6070 - precision: 0.6070 - auc: 0.6478 - categorical_accuracy: 0.6070 - val_loss: 0.6600 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.5807 - val_categorical_accuracy: 0.6200
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6674 - recall: 0.6150 - precision: 0.6150 - auc: 0.6511 - categorical_accuracy: 0.6150
# Epoch 00018: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 116ms/step - loss: 0.6664 - recall: 0.6169 - precision: 0.6169 - auc: 0.6519 - categorical_accuracy: 0.6169 - val_loss: 0.6670 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.5508 - val_categorical_accuracy: 0.6100
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6637 - recall: 0.6025 - precision: 0.6025 - auc: 0.6337 - categorical_accuracy: 0.6025
# Epoch 00019: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 115ms/step - loss: 0.6625 - recall: 0.6045 - precision: 0.6045 - auc: 0.6352 - categorical_accuracy: 0.6045 - val_loss: 0.6914 - val_recall: 0.5400 - val_precision: 0.5400 - val_auc: 0.4921 - val_categorical_accuracy: 0.5400
# Epoch 20/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6405 - recall: 0.6475 - precision: 0.6475 - auc: 0.6927 - categorical_accuracy: 0.6475
# Epoch 00020: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 115ms/step - loss: 0.6392 - recall: 0.6493 - precision: 0.6493 - auc: 0.6945 - categorical_accuracy: 0.6493 - val_loss: 0.7035 - val_recall: 0.5100 - val_precision: 0.5100 - val_auc: 0.4745 - val_categorical_accuracy: 0.5100
# Epoch 21/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6469 - recall: 0.6100 - precision: 0.6100 - auc: 0.6761 - categorical_accuracy: 0.6100
# Epoch 00021: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 128ms/step - loss: 0.6460 - recall: 0.6095 - precision: 0.6095 - auc: 0.6766 - categorical_accuracy: 0.6095 - val_loss: 0.6910 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6472 - val_categorical_accuracy: 0.6400
# Epoch 22/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6443 - recall: 0.6375 - precision: 0.6375 - auc: 0.6914 - categorical_accuracy: 0.6375
# Epoch 00022: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 117ms/step - loss: 0.6433 - recall: 0.6393 - precision: 0.6393 - auc: 0.6925 - categorical_accuracy: 0.6393 - val_loss: 0.7076 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.5821 - val_categorical_accuracy: 0.6400
# Epoch 23/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6062 - recall: 0.7025 - precision: 0.7025 - auc: 0.7626 - categorical_accuracy: 0.7025
# Epoch 00023: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 117ms/step - loss: 0.6049 - recall: 0.7040 - precision: 0.7040 - auc: 0.7643 - categorical_accuracy: 0.7040 - val_loss: 0.7127 - val_recall: 0.6300 - val_precision: 0.6300 - val_auc: 0.6614 - val_categorical_accuracy: 0.6300
# Epoch 24/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5916 - recall: 0.7275 - precision: 0.7275 - auc: 0.7783 - categorical_accuracy: 0.7275- ETA: 2s - loss: 0.5516 - recall: 0.7937 - precision: 0.7937 - auc: 0.8314 - cate
# Epoch 00024: val_auc did not improve from 0.66575
# 41/41 [==============================] - 5s 123ms/step - loss: 0.5915 - recall: 0.7264 - precision: 0.7264 - auc: 0.7778 - categorical_accuracy: 0.7264 - val_loss: 0.6842 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.6465 - val_categorical_accuracy: 0.6500
# Epoch 25/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5828 - recall: 0.7225 - precision: 0.7225 - auc: 0.7933 - categorical_accuracy: 0.7225
# Epoch 00025: val_auc improved from 0.66575 to 0.69730, saving model to ../../tmp\checkpoints\20201216-160204\cp-0025.ckpt
# 41/41 [==============================] - 6s 153ms/step - loss: 0.5823 - recall: 0.7214 - precision: 0.7214 - auc: 0.7933 - categorical_accuracy: 0.7214 - val_loss: 0.6591 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6973 - val_categorical_accuracy: 0.6400
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5285 - recall: 0.7400 - precision: 0.7400 - auc: 0.8367 - categorical_accuracy: 0.7400
# Epoch 00026: val_auc improved from 0.69730 to 0.72705, saving model to ../../tmp\checkpoints\20201216-160204\cp-0026.ckpt
# 41/41 [==============================] - 7s 165ms/step - loss: 0.5272 - recall: 0.7413 - precision: 0.7413 - auc: 0.8380 - categorical_accuracy: 0.7413 - val_loss: 0.6526 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7271 - val_categorical_accuracy: 0.6700
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5263 - recall: 0.7425 - precision: 0.7425 - auc: 0.8196 - categorical_accuracy: 0.7425
# Epoch 00027: val_auc did not improve from 0.72705
# 41/41 [==============================] - 5s 122ms/step - loss: 0.5273 - recall: 0.7413 - precision: 0.7413 - auc: 0.8172 - categorical_accuracy: 0.7413 - val_loss: 0.6840 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.6752 - val_categorical_accuracy: 0.6800
# Epoch 28/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5060 - recall: 0.8025 - precision: 0.8025 - auc: 0.8551 - categorical_accuracy: 0.8025
# Epoch 00028: val_auc did not improve from 0.72705
# 41/41 [==============================] - 5s 127ms/step - loss: 0.5054 - recall: 0.8035 - precision: 0.8035 - auc: 0.8555 - categorical_accuracy: 0.8035 - val_loss: 0.6820 - val_recall: 0.6800 - val_precision: 0.6800 - val_auc: 0.7166 - val_categorical_accuracy: 0.6800
# Epoch 29/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4565 - recall: 0.8350 - precision: 0.8350 - auc: 0.8863 - categorical_accuracy: 0.8350
# Epoch 00029: val_auc did not improve from 0.72705
# 41/41 [==============================] - 5s 122ms/step - loss: 0.4559 - recall: 0.8358 - precision: 0.8358 - auc: 0.8866 - categorical_accuracy: 0.8358 - val_loss: 0.7209 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7142 - val_categorical_accuracy: 0.6700
# Epoch 30/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4516 - recall: 0.8550 - precision: 0.8550 - auc: 0.8871 - categorical_accuracy: 0.8550
# Epoch 00030: val_auc did not improve from 0.72705
# 41/41 [==============================] - 5s 116ms/step - loss: 0.4511 - recall: 0.8557 - precision: 0.8557 - auc: 0.8875 - categorical_accuracy: 0.8557 - val_loss: 0.6759 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7235 - val_categorical_accuracy: 0.7000
# Epoch 31/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4028 - recall: 0.8900 - precision: 0.8900 - auc: 0.9234 - categorical_accuracy: 0.8900
# Epoch 00031: val_auc did not improve from 0.72705
# 41/41 [==============================] - 5s 112ms/step - loss: 0.4018 - recall: 0.8905 - precision: 0.8905 - auc: 0.9238 - categorical_accuracy: 0.8905 - val_loss: 0.6552 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7173 - val_categorical_accuracy: 0.7300
# Epoch 32/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4054 - recall: 0.8975 - precision: 0.8975 - auc: 0.9197 - categorical_accuracy: 0.8975
# Epoch 00032: val_auc improved from 0.72705 to 0.72830, saving model to ../../tmp\checkpoints\20201216-160204\cp-0032.ckpt
# 41/41 [==============================] - 7s 164ms/step - loss: 0.4051 - recall: 0.8980 - precision: 0.8980 - auc: 0.9199 - categorical_accuracy: 0.8980 - val_loss: 0.6798 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7283 - val_categorical_accuracy: 0.7200
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3879 - recall: 0.8800 - precision: 0.8800 - auc: 0.9258 - categorical_accuracy: 0.8800
# Epoch 00033: val_auc improved from 0.72830 to 0.77165, saving model to ../../tmp\checkpoints\20201216-160204\cp-0033.ckpt
# 41/41 [==============================] - 6s 153ms/step - loss: 0.3866 - recall: 0.8806 - precision: 0.8806 - auc: 0.9263 - categorical_accuracy: 0.8806 - val_loss: 0.6597 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7717 - val_categorical_accuracy: 0.7400
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3797 - recall: 0.8975 - precision: 0.8975 - auc: 0.9260 - categorical_accuracy: 0.8975- ETA: 2s - loss: 0.3291 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accurac - ETA: 2s - loss: 0.3158 - recall: 0.9571 - precision: 0.9571 - auc: 0.9658 - ca
# Epoch 00034: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 119ms/step - loss: 0.3795 - recall: 0.8980 - precision: 0.8980 - auc: 0.9262 - categorical_accuracy: 0.8980 - val_loss: 0.6615 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7277 - val_categorical_accuracy: 0.7000
# Epoch 35/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3293 - recall: 0.9100 - precision: 0.9100 - auc: 0.9505 - categorical_accuracy: 0.9100- ETA: 3s - loss: 0.3019 - recall: 0.9333 - precision: 0.9333 - auc: 0.9
# Epoch 00035: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 121ms/step - loss: 0.3288 - recall: 0.9104 - precision: 0.9104 - auc: 0.9508 - categorical_accuracy: 0.9104 - val_loss: 0.6883 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7379 - val_categorical_accuracy: 0.7000
# Epoch 36/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3150 - recall: 0.9350 - precision: 0.9350 - auc: 0.9558 - categorical_accuracy: 0.9350
# Epoch 00036: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 123ms/step - loss: 0.3144 - recall: 0.9353 - precision: 0.9353 - auc: 0.9560 - categorical_accuracy: 0.9353 - val_loss: 0.6550 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7572 - val_categorical_accuracy: 0.6600
# Epoch 37/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2868 - recall: 0.9250 - precision: 0.9250 - auc: 0.9628 - categorical_accuracy: 0.9250
# Epoch 00037: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 119ms/step - loss: 0.2864 - recall: 0.9254 - precision: 0.9254 - auc: 0.9630 - categorical_accuracy: 0.9254 - val_loss: 0.6827 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7220 - val_categorical_accuracy: 0.6700
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2382 - recall: 0.9475 - precision: 0.9475 - auc: 0.9670 - categorical_accuracy: 0.9475
# Epoch 00038: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 122ms/step - loss: 0.2380 - recall: 0.9478 - precision: 0.9478 - auc: 0.9671 - categorical_accuracy: 0.9478 - val_loss: 0.6891 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7498 - val_categorical_accuracy: 0.6900
# Epoch 39/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2238 - recall: 0.9350 - precision: 0.9350 - auc: 0.9778 - categorical_accuracy: 0.9350- ETA: 1s - loss: 0.2101 - recall: 0.9462 - precision: 0.9462 - auc: 0.9854 - categorical_ac
# Epoch 00039: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2236 - recall: 0.9353 - precision: 0.9353 - auc: 0.9779 - categorical_accuracy: 0.9353 - val_loss: 0.6800 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7635 - val_categorical_accuracy: 0.7200
# Epoch 40/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2375 - recall: 0.9575 - precision: 0.9575 - auc: 0.9742 - categorical_accuracy: 0.9575
# Epoch 00040: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 119ms/step - loss: 0.2366 - recall: 0.9577 - precision: 0.9577 - auc: 0.9743 - categorical_accuracy: 0.9577 - val_loss: 0.6883 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7657 - val_categorical_accuracy: 0.7000
# Epoch 41/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2552 - recall: 0.9375 - precision: 0.9375 - auc: 0.9701 - categorical_accuracy: 0.9375
# Epoch 00041: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 126ms/step - loss: 0.2547 - recall: 0.9378 - precision: 0.9378 - auc: 0.9702 - categorical_accuracy: 0.9378 - val_loss: 0.6902 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7245 - val_categorical_accuracy: 0.7000
# Epoch 42/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2379 - recall: 0.9550 - precision: 0.9550 - auc: 0.9750 - categorical_accuracy: 0.9550
# Epoch 00042: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2374 - recall: 0.9552 - precision: 0.9552 - auc: 0.9751 - categorical_accuracy: 0.9552 - val_loss: 0.7051 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7617 - val_categorical_accuracy: 0.7100
# Epoch 43/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2230 - recall: 0.9500 - precision: 0.9500 - auc: 0.9802 - categorical_accuracy: 0.9500
# Epoch 00043: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 115ms/step - loss: 0.2222 - recall: 0.9502 - precision: 0.9502 - auc: 0.9803 - categorical_accuracy: 0.9502 - val_loss: 0.6756 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7559 - val_categorical_accuracy: 0.7200
# Epoch 44/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2090 - recall: 0.9425 - precision: 0.9425 - auc: 0.9812 - categorical_accuracy: 0.9425
# Epoch 00044: val_auc did not improve from 0.77165
# 41/41 [==============================] - 5s 127ms/step - loss: 0.2097 - recall: 0.9403 - precision: 0.9403 - auc: 0.9809 - categorical_accuracy: 0.9403 - val_loss: 0.6627 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7675 - val_categorical_accuracy: 0.7500
# Epoch 45/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2222 - recall: 0.9400 - precision: 0.9400 - auc: 0.9714 - categorical_accuracy: 0.9400
# Epoch 00045: val_auc improved from 0.77165 to 0.77670, saving model to ../../tmp\checkpoints\20201216-160204\cp-0045.ckpt
# 41/41 [==============================] - 6s 158ms/step - loss: 0.2218 - recall: 0.9403 - precision: 0.9403 - auc: 0.9715 - categorical_accuracy: 0.9403 - val_loss: 0.6839 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7767 - val_categorical_accuracy: 0.7400
# Epoch 46/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2433 - recall: 0.9350 - precision: 0.9350 - auc: 0.9720 - categorical_accuracy: 0.9350
# Epoch 00046: val_auc did not improve from 0.77670
# 41/41 [==============================] - 5s 124ms/step - loss: 0.2442 - recall: 0.9328 - precision: 0.9328 - auc: 0.9717 - categorical_accuracy: 0.9328 - val_loss: 0.6972 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7687 - val_categorical_accuracy: 0.7300
# Epoch 47/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1999 - recall: 0.9400 - precision: 0.9400 - auc: 0.9775 - categorical_accuracy: 0.9400
# Epoch 00047: val_auc did not improve from 0.77670
# 41/41 [==============================] - 5s 113ms/step - loss: 0.1994 - recall: 0.9403 - precision: 0.9403 - auc: 0.9776 - categorical_accuracy: 0.9403 - val_loss: 0.7130 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7629 - val_categorical_accuracy: 0.7100
# Epoch 48/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1896 - recall: 0.9425 - precision: 0.9425 - auc: 0.9772 - categorical_accuracy: 0.9425
# Epoch 00048: val_auc did not improve from 0.77670
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1889 - recall: 0.9428 - precision: 0.9428 - auc: 0.9774 - categorical_accuracy: 0.9428 - val_loss: 0.7704 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7714 - val_categorical_accuracy: 0.7000
# Epoch 49/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1742 - recall: 0.9550 - precision: 0.9550 - auc: 0.9893 - categorical_accuracy: 0.9550
# Epoch 00049: val_auc did not improve from 0.77670
# 41/41 [==============================] - 5s 119ms/step - loss: 0.1735 - recall: 0.9552 - precision: 0.9552 - auc: 0.9894 - categorical_accuracy: 0.9552 - val_loss: 0.7646 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7736 - val_categorical_accuracy: 0.6900
# Epoch 50/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1996 - recall: 0.9425 - precision: 0.9425 - auc: 0.9791 - categorical_accuracy: 0.9425
# Epoch 00050: val_auc did not improve from 0.77670
# 41/41 [==============================] - 5s 119ms/step - loss: 0.1987 - recall: 0.9428 - precision: 0.9428 - auc: 0.9793 - categorical_accuracy: 0.9428 - val_loss: 0.7481 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7764 - val_categorical_accuracy: 0.7000
# Epoch 51/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1932 - recall: 0.9450 - precision: 0.9450 - auc: 0.9810 - categorical_accuracy: 0.9450
# Epoch 00051: val_auc improved from 0.77670 to 0.78400, saving model to ../../tmp\checkpoints\20201216-160204\cp-0051.ckpt
# 41/41 [==============================] - 7s 160ms/step - loss: 0.1926 - recall: 0.9453 - precision: 0.9453 - auc: 0.9811 - categorical_accuracy: 0.9453 - val_loss: 0.7458 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7840 - val_categorical_accuracy: 0.7200
# Epoch 52/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1934 - recall: 0.9450 - precision: 0.9450 - auc: 0.9786 - categorical_accuracy: 0.9450
# Epoch 00052: val_auc did not improve from 0.78400
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1939 - recall: 0.9428 - precision: 0.9428 - auc: 0.9785 - categorical_accuracy: 0.9428 - val_loss: 0.7635 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7807 - val_categorical_accuracy: 0.7200
# Epoch 53/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1844 - recall: 0.9325 - precision: 0.9325 - auc: 0.9837 - categorical_accuracy: 0.9325
# Epoch 00053: val_auc improved from 0.78400 to 0.78870, saving model to ../../tmp\checkpoints\20201216-160204\cp-0053.ckpt
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1839 - recall: 0.9328 - precision: 0.9328 - auc: 0.9838 - categorical_accuracy: 0.9328 - val_loss: 0.7741 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7887 - val_categorical_accuracy: 0.7200
# Epoch 54/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1821 - recall: 0.9425 - precision: 0.9425 - auc: 0.9818 - categorical_accuracy: 0.9425
# Epoch 00054: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1814 - recall: 0.9428 - precision: 0.9428 - auc: 0.9819 - categorical_accuracy: 0.9428 - val_loss: 0.7792 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7798 - val_categorical_accuracy: 0.7300
# Epoch 55/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1779 - recall: 0.9525 - precision: 0.9525 - auc: 0.9856 - categorical_accuracy: 0.9525
# Epoch 00055: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 119ms/step - loss: 0.1771 - recall: 0.9527 - precision: 0.9527 - auc: 0.9857 - categorical_accuracy: 0.9527 - val_loss: 0.7719 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7832 - val_categorical_accuracy: 0.7300
# Epoch 56/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1782 - recall: 0.9350 - precision: 0.9350 - auc: 0.9825 - categorical_accuracy: 0.9350
# Epoch 00056: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1778 - recall: 0.9353 - precision: 0.9353 - auc: 0.9826 - categorical_accuracy: 0.9353 - val_loss: 0.7651 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7837 - val_categorical_accuracy: 0.7300
# Epoch 57/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1599 - recall: 0.9625 - precision: 0.9625 - auc: 0.9911 - categorical_accuracy: 0.9625- ETA: 0s - loss: 0.1551 - recall: 0.9611 - precision: 0.9611 - auc: 0.9913 - categorical_accuracy: 0.
# Epoch 00057: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 131ms/step - loss: 0.1594 - recall: 0.9627 - precision: 0.9627 - auc: 0.9911 - categorical_accuracy: 0.9627 - val_loss: 0.7584 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7869 - val_categorical_accuracy: 0.7300
# Epoch 58/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1528 - recall: 0.9625 - precision: 0.9625 - auc: 0.9913 - categorical_accuracy: 0.9625
# Epoch 00058: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 125ms/step - loss: 0.1524 - recall: 0.9627 - precision: 0.9627 - auc: 0.9914 - categorical_accuracy: 0.9627 - val_loss: 0.7552 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7798 - val_categorical_accuracy: 0.7200
# Epoch 59/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1676 - recall: 0.9500 - precision: 0.9500 - auc: 0.9889 - categorical_accuracy: 0.9500
# Epoch 00059: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 114ms/step - loss: 0.1671 - recall: 0.9502 - precision: 0.9502 - auc: 0.9890 - categorical_accuracy: 0.9502 - val_loss: 0.7659 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7843 - val_categorical_accuracy: 0.7300
# Epoch 60/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1602 - recall: 0.9525 - precision: 0.9525 - auc: 0.9820 - categorical_accuracy: 0.9525
# Epoch 00060: val_auc did not improve from 0.78870
# 41/41 [==============================] - 5s 125ms/step - loss: 0.1597 - recall: 0.9527 - precision: 0.9527 - auc: 0.9820 - categorical_accuracy: 0.9527 - val_loss: 0.7579 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7876 - val_categorical_accuracy: 0.7300
# Epoch 61/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1886 - recall: 0.9425 - precision: 0.9425 - auc: 0.9795 - categorical_accuracy: 0.9425
# Epoch 00061: val_auc improved from 0.78870 to 0.79300, saving model to ../../tmp\checkpoints\20201216-160204\cp-0061.ckpt
# 41/41 [==============================] - 7s 161ms/step - loss: 0.1892 - recall: 0.9403 - precision: 0.9403 - auc: 0.9794 - categorical_accuracy: 0.9403 - val_loss: 0.7575 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7930 - val_categorical_accuracy: 0.7300
# Epoch 62/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1601 - recall: 0.9550 - precision: 0.9550 - auc: 0.9854 - categorical_accuracy: 0.9550
# Epoch 00062: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 114ms/step - loss: 0.1597 - recall: 0.9552 - precision: 0.9552 - auc: 0.9855 - categorical_accuracy: 0.9552 - val_loss: 0.7603 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7838 - val_categorical_accuracy: 0.7200
# Epoch 63/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1883 - recall: 0.9500 - precision: 0.9500 - auc: 0.9814 - categorical_accuracy: 0.9500
# Epoch 00063: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1875 - recall: 0.9502 - precision: 0.9502 - auc: 0.9815 - categorical_accuracy: 0.9502 - val_loss: 0.7678 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7840 - val_categorical_accuracy: 0.7200
# Epoch 64/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1880 - recall: 0.9350 - precision: 0.9350 - auc: 0.9806 - categorical_accuracy: 0.9350
# Epoch 00064: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 125ms/step - loss: 0.1872 - recall: 0.9353 - precision: 0.9353 - auc: 0.9807 - categorical_accuracy: 0.9353 - val_loss: 0.7669 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7819 - val_categorical_accuracy: 0.7100
# Epoch 65/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1599 - recall: 0.9450 - precision: 0.9450 - auc: 0.9849 - categorical_accuracy: 0.9450- ETA: 2s - loss: 0.1545 - recall: 0.9250 - precision: 0.9250 - auc: 0.9872 - categ
# Epoch 00065: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1593 - recall: 0.9453 - precision: 0.9453 - auc: 0.9850 - categorical_accuracy: 0.9453 - val_loss: 0.7609 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7802 - val_categorical_accuracy: 0.7100
# Epoch 66/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1795 - recall: 0.9475 - precision: 0.9475 - auc: 0.9799 - categorical_accuracy: 0.9475
# Epoch 00066: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 125ms/step - loss: 0.1789 - recall: 0.9478 - precision: 0.9478 - auc: 0.9800 - categorical_accuracy: 0.9478 - val_loss: 0.7627 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7852 - val_categorical_accuracy: 0.7100
# Epoch 67/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1653 - recall: 0.9525 - precision: 0.9525 - auc: 0.9838 - categorical_accuracy: 0.9525
# Epoch 00067: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1648 - recall: 0.9527 - precision: 0.9527 - auc: 0.9839 - categorical_accuracy: 0.9527 - val_loss: 0.7587 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7869 - val_categorical_accuracy: 0.7100
# Epoch 68/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1604 - recall: 0.9700 - precision: 0.9700 - auc: 0.9860 - categorical_accuracy: 0.9700
# Epoch 00068: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1599 - recall: 0.9701 - precision: 0.9701 - auc: 0.9861 - categorical_accuracy: 0.9701 - val_loss: 0.7566 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7859 - val_categorical_accuracy: 0.7100
# Epoch 69/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1724 - recall: 0.9600 - precision: 0.9600 - auc: 0.9810 - categorical_accuracy: 0.9600
# Epoch 00069: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1717 - recall: 0.9602 - precision: 0.9602 - auc: 0.9811 - categorical_accuracy: 0.9602 - val_loss: 0.7455 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7889 - val_categorical_accuracy: 0.7300
# Epoch 70/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1555 - recall: 0.9525 - precision: 0.9525 - auc: 0.9857 - categorical_accuracy: 0.9525
# Epoch 00070: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 128ms/step - loss: 0.1551 - recall: 0.9527 - precision: 0.9527 - auc: 0.9857 - categorical_accuracy: 0.9527 - val_loss: 0.7351 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7912 - val_categorical_accuracy: 0.7100
# Epoch 71/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1507 - recall: 0.9600 - precision: 0.9600 - auc: 0.9917 - categorical_accuracy: 0.9600
# Epoch 00071: val_auc did not improve from 0.79300
# 41/41 [==============================] - 5s 128ms/step - loss: 0.1512 - recall: 0.9602 - precision: 0.9602 - auc: 0.9916 - categorical_accuracy: 0.9602 - val_loss: 0.7366 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7907 - val_categorical_accuracy: 0.7200
# Epoch 72/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1559 - recall: 0.9600 - precision: 0.9600 - auc: 0.9851 - categorical_accuracy: 0.9600
# Epoch 00072: val_auc improved from 0.79300 to 0.79360, saving model to ../../tmp\checkpoints\20201216-160204\cp-0072.ckpt
# 41/41 [==============================] - 7s 163ms/step - loss: 0.1554 - recall: 0.9602 - precision: 0.9602 - auc: 0.9852 - categorical_accuracy: 0.9602 - val_loss: 0.7380 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7936 - val_categorical_accuracy: 0.7000
# Epoch 73/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1631 - recall: 0.9475 - precision: 0.9475 - auc: 0.9804 - categorical_accuracy: 0.9475
# Epoch 00073: val_auc did not improve from 0.79360
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1624 - recall: 0.9478 - precision: 0.9478 - auc: 0.9805 - categorical_accuracy: 0.9478 - val_loss: 0.7388 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7914 - val_categorical_accuracy: 0.7000
# Epoch 74/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1724 - recall: 0.9450 - precision: 0.9450 - auc: 0.9833 - categorical_accuracy: 0.9450- ETA: 0s - loss: 0.1581 - recall: 0.9500 - precision: 0.9500 - auc: 0.9891 - categorical_accuracy
# Epoch 00074: val_auc did not improve from 0.79360
# 41/41 [==============================] - 5s 119ms/step - loss: 0.1719 - recall: 0.9453 - precision: 0.9453 - auc: 0.9833 - categorical_accuracy: 0.9453 - val_loss: 0.7350 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7934 - val_categorical_accuracy: 0.7000
# Epoch 75/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1828 - recall: 0.9525 - precision: 0.9525 - auc: 0.9801 - categorical_accuracy: 0.9525
# Epoch 00075: val_auc improved from 0.79360 to 0.79540, saving model to ../../tmp\checkpoints\20201216-160204\cp-0075.ckpt
# 41/41 [==============================] - 7s 164ms/step - loss: 0.1825 - recall: 0.9527 - precision: 0.9527 - auc: 0.9802 - categorical_accuracy: 0.9527 - val_loss: 0.7384 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7954 - val_categorical_accuracy: 0.7100
# Epoch 76/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1608 - recall: 0.9575 - precision: 0.9575 - auc: 0.9877 - categorical_accuracy: 0.9575
# Epoch 00076: val_auc improved from 0.79540 to 0.79900, saving model to ../../tmp\checkpoints\20201216-160204\cp-0076.ckpt
# 41/41 [==============================] - 7s 164ms/step - loss: 0.1603 - recall: 0.9577 - precision: 0.9577 - auc: 0.9878 - categorical_accuracy: 0.9577 - val_loss: 0.7295 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7990 - val_categorical_accuracy: 0.7100
# Epoch 77/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1670 - recall: 0.9350 - precision: 0.9350 - auc: 0.9848 - categorical_accuracy: 0.9350
# Epoch 00077: val_auc improved from 0.79900 to 0.79940, saving model to ../../tmp\checkpoints\20201216-160204\cp-0077.ckpt
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1685 - recall: 0.9328 - precision: 0.9328 - auc: 0.9842 - categorical_accuracy: 0.9328 - val_loss: 0.7365 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7994 - val_categorical_accuracy: 0.7000
# Epoch 78/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1676 - recall: 0.9525 - precision: 0.9525 - auc: 0.9851 - categorical_accuracy: 0.9525
# Epoch 00078: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1670 - recall: 0.9527 - precision: 0.9527 - auc: 0.9852 - categorical_accuracy: 0.9527 - val_loss: 0.7359 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7972 - val_categorical_accuracy: 0.7000
# Epoch 79/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1516 - recall: 0.9650 - precision: 0.9650 - auc: 0.9872 - categorical_accuracy: 0.9650
# Epoch 00079: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 124ms/step - loss: 0.1509 - recall: 0.9652 - precision: 0.9652 - auc: 0.9872 - categorical_accuracy: 0.9652 - val_loss: 0.7377 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7989 - val_categorical_accuracy: 0.7000
# Epoch 80/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1796 - recall: 0.9525 - precision: 0.9525 - auc: 0.9835 - categorical_accuracy: 0.9525- ETA: 2s - loss: 0.1531 - recall: 0.9571 - precision: 0.9571 - auc: 0.9931 - categoric
# Epoch 00080: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 124ms/step - loss: 0.1788 - recall: 0.9527 - precision: 0.9527 - auc: 0.9837 - categorical_accuracy: 0.9527 - val_loss: 0.7450 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7954 - val_categorical_accuracy: 0.7000
# Epoch 81/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1677 - recall: 0.9575 - precision: 0.9575 - auc: 0.9822 - categorical_accuracy: 0.9575
# Epoch 00081: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1670 - recall: 0.9577 - precision: 0.9577 - auc: 0.9823 - categorical_accuracy: 0.9577 - val_loss: 0.7478 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7968 - val_categorical_accuracy: 0.7000
# Epoch 82/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1663 - recall: 0.9725 - precision: 0.9725 - auc: 0.9887 - categorical_accuracy: 0.9725
# Epoch 00082: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1656 - recall: 0.9726 - precision: 0.9726 - auc: 0.9887 - categorical_accuracy: 0.9726 - val_loss: 0.7446 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7977 - val_categorical_accuracy: 0.7000
# Epoch 83/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1599 - recall: 0.9700 - precision: 0.9700 - auc: 0.9877 - categorical_accuracy: 0.9700
# Epoch 00083: val_auc did not improve from 0.79940
# 41/41 [==============================] - 6s 137ms/step - loss: 0.1594 - recall: 0.9701 - precision: 0.9701 - auc: 0.9878 - categorical_accuracy: 0.9701 - val_loss: 0.7466 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7962 - val_categorical_accuracy: 0.7000
# Epoch 84/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1714 - recall: 0.9600 - precision: 0.9600 - auc: 0.9850 - categorical_accuracy: 0.9600- ETA: 2s - loss: 0.1355 - recall: 0.9706 - precision: 0.9706 - auc: 0.9967 - categ
# Epoch 00084: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1707 - recall: 0.9602 - precision: 0.9602 - auc: 0.9851 - categorical_accuracy: 0.9602 - val_loss: 0.7530 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7991 - val_categorical_accuracy: 0.7000
# Epoch 85/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1546 - recall: 0.9575 - precision: 0.9575 - auc: 0.9857 - categorical_accuracy: 0.9575- ETA: 2s - loss: 0.1232 - recall: 0.9667 - precision: 0.9667 - auc: 0.9918 - categoric
# Epoch 00085: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1540 - recall: 0.9577 - precision: 0.9577 - auc: 0.9857 - categorical_accuracy: 0.9577 - val_loss: 0.7515 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7988 - val_categorical_accuracy: 0.7000
# Epoch 86/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1540 - recall: 0.9650 - precision: 0.9650 - auc: 0.9899 - categorical_accuracy: 0.9650- ETA: 3s - loss: 0.1246 - recall: 0.9636 - precision: 0.9636 - auc: 0.9979 -
# Epoch 00086: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 118ms/step - loss: 0.1533 - recall: 0.9652 - precision: 0.9652 - auc: 0.9899 - categorical_accuracy: 0.9652 - val_loss: 0.7488 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7989 - val_categorical_accuracy: 0.7000
# Epoch 87/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1654 - recall: 0.9600 - precision: 0.9600 - auc: 0.9826 - categorical_accuracy: 0.9600
# Epoch 00087: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 124ms/step - loss: 0.1650 - recall: 0.9602 - precision: 0.9602 - auc: 0.9827 - categorical_accuracy: 0.9602 - val_loss: 0.7522 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7984 - val_categorical_accuracy: 0.7000
# Epoch 88/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1621 - recall: 0.9675 - precision: 0.9675 - auc: 0.9862 - categorical_accuracy: 0.9675- ETA: 2s - loss: 0.1135 - recall: 0.9667 - precision: 0.9667 - auc:
# Epoch 00088: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1615 - recall: 0.9677 - precision: 0.9677 - auc: 0.9863 - categorical_accuracy: 0.9677 - val_loss: 0.7520 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7993 - val_categorical_accuracy: 0.7000
# Epoch 89/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1375 - recall: 0.9675 - precision: 0.9675 - auc: 0.9883 - categorical_accuracy: 0.9675
# Epoch 00089: val_auc did not improve from 0.79940
# 41/41 [==============================] - 5s 125ms/step - loss: 0.1381 - recall: 0.9677 - precision: 0.9677 - auc: 0.9882 - categorical_accuracy: 0.9677 - val_loss: 0.7498 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7990 - val_categorical_accuracy: 0.7000
# Epoch 90/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1686 - recall: 0.9575 - precision: 0.9575 - auc: 0.9799 - categorical_accuracy: 0.9575
# Epoch 00090: val_auc improved from 0.79940 to 0.80010, saving model to ../../tmp\checkpoints\20201216-160204\cp-0090.ckpt
# 41/41 [==============================] - 7s 166ms/step - loss: 0.1678 - recall: 0.9577 - precision: 0.9577 - auc: 0.9800 - categorical_accuracy: 0.9577 - val_loss: 0.7503 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.8001 - val_categorical_accuracy: 0.7000
# Epoch 91/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1582 - recall: 0.9525 - precision: 0.9525 - auc: 0.9892 - categorical_accuracy: 0.9525- ETA: 0s - loss: 0.1570 - recall: 0.9529 - precision: 0.9529 - auc: 0.9892 - categorical_accuracy:
# Epoch 00091: val_auc did not improve from 0.80010
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1579 - recall: 0.9527 - precision: 0.9527 - auc: 0.9893 - categorical_accuracy: 0.9527 - val_loss: 0.7475 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7987 - val_categorical_accuracy: 0.7000
# Epoch 92/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1551 - recall: 0.9625 - precision: 0.9625 - auc: 0.9842 - categorical_accuracy: 0.9625
# Epoch 00092: val_auc improved from 0.80010 to 0.80260, saving model to ../../tmp\checkpoints\20201216-160204\cp-0092.ckpt
# 41/41 [==============================] - 6s 152ms/step - loss: 0.1547 - recall: 0.9627 - precision: 0.9627 - auc: 0.9842 - categorical_accuracy: 0.9627 - val_loss: 0.7466 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8026 - val_categorical_accuracy: 0.7100
# Epoch 93/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1755 - recall: 0.9625 - precision: 0.9625 - auc: 0.9792 - categorical_accuracy: 0.9625
# Epoch 00093: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 121ms/step - loss: 0.1748 - recall: 0.9627 - precision: 0.9627 - auc: 0.9793 - categorical_accuracy: 0.9627 - val_loss: 0.7481 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8020 - val_categorical_accuracy: 0.7100
# Epoch 94/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1488 - recall: 0.9500 - precision: 0.9500 - auc: 0.9849 - categorical_accuracy: 0.9500
# Epoch 00094: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 128ms/step - loss: 0.1484 - recall: 0.9502 - precision: 0.9502 - auc: 0.9849 - categorical_accuracy: 0.9502 - val_loss: 0.7500 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8019 - val_categorical_accuracy: 0.7100
# Epoch 95/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1524 - recall: 0.9625 - precision: 0.9625 - auc: 0.9886 - categorical_accuracy: 0.9625
# Epoch 00095: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1517 - recall: 0.9627 - precision: 0.9627 - auc: 0.9887 - categorical_accuracy: 0.9627 - val_loss: 0.7508 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8017 - val_categorical_accuracy: 0.7100
# Epoch 96/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1723 - recall: 0.9525 - precision: 0.9525 - auc: 0.9805 - categorical_accuracy: 0.9525
# Epoch 00096: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 134ms/step - loss: 0.1718 - recall: 0.9527 - precision: 0.9527 - auc: 0.9806 - categorical_accuracy: 0.9527 - val_loss: 0.7472 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8011 - val_categorical_accuracy: 0.7100
# Epoch 97/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1559 - recall: 0.9600 - precision: 0.9600 - auc: 0.9834 - categorical_accuracy: 0.9600
# Epoch 00097: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 122ms/step - loss: 0.1554 - recall: 0.9602 - precision: 0.9602 - auc: 0.9834 - categorical_accuracy: 0.9602 - val_loss: 0.7506 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8022 - val_categorical_accuracy: 0.7100
# Epoch 98/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1446 - recall: 0.9625 - precision: 0.9625 - auc: 0.9895 - categorical_accuracy: 0.9625
# Epoch 00098: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1441 - recall: 0.9627 - precision: 0.9627 - auc: 0.9896 - categorical_accuracy: 0.9627 - val_loss: 0.7512 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8025 - val_categorical_accuracy: 0.7100
# Epoch 99/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1432 - recall: 0.9625 - precision: 0.9625 - auc: 0.9932 - categorical_accuracy: 0.9625
# Epoch 00099: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 132ms/step - loss: 0.1429 - recall: 0.9627 - precision: 0.9627 - auc: 0.9932 - categorical_accuracy: 0.9627 - val_loss: 0.7501 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8017 - val_categorical_accuracy: 0.7100
# Epoch 100/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1491 - recall: 0.9675 - precision: 0.9675 - auc: 0.9876 - categorical_accuracy: 0.9675
# Epoch 00100: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 124ms/step - loss: 0.1487 - recall: 0.9677 - precision: 0.9677 - auc: 0.9876 - categorical_accuracy: 0.9677 - val_loss: 0.7489 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8012 - val_categorical_accuracy: 0.7100
# Epoch 101/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1519 - recall: 0.9700 - precision: 0.9700 - auc: 0.9912 - categorical_accuracy: 0.9700
# Epoch 00101: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 128ms/step - loss: 0.1516 - recall: 0.9701 - precision: 0.9701 - auc: 0.9912 - categorical_accuracy: 0.9701 - val_loss: 0.7490 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8002 - val_categorical_accuracy: 0.7100
# Epoch 102/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1277 - recall: 0.9675 - precision: 0.9675 - auc: 0.9940 - categorical_accuracy: 0.9675
# Epoch 00102: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 124ms/step - loss: 0.1274 - recall: 0.9677 - precision: 0.9677 - auc: 0.9940 - categorical_accuracy: 0.9677 - val_loss: 0.7460 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8001 - val_categorical_accuracy: 0.7100
# Epoch 103/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1567 - recall: 0.9675 - precision: 0.9675 - auc: 0.9841 - categorical_accuracy: 0.9675
# Epoch 00103: val_auc did not improve from 0.80260
# 41/41 [==============================] - 6s 136ms/step - loss: 0.1560 - recall: 0.9677 - precision: 0.9677 - auc: 0.9842 - categorical_accuracy: 0.9677 - val_loss: 0.7468 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8006 - val_categorical_accuracy: 0.7100
# Epoch 104/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1556 - recall: 0.9641 - precision: 0.9641 - auc: 0.9830 - categorical_accuracy: 0.9641- ETA: 3s - loss: 0.1034 - recall: 0.9667 - precision: 0.9667 - auc: 0.9973 - cat - ETA: 0s - loss: 0.1542 - recall: 0.9650 - precision: 0.9650 - auc: 0.9835 - categorical_accuracy: 0.9650
# Epoch 00104: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1549 - recall: 0.9652 - precision: 0.9652 - auc: 0.9834 - categorical_accuracy: 0.9652 - val_loss: 0.7459 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8008 - val_categorical_accuracy: 0.7100
# Epoch 105/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1740 - recall: 0.9650 - precision: 0.9650 - auc: 0.9866 - categorical_accuracy: 0.9650
# Epoch 00105: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 132ms/step - loss: 0.1734 - recall: 0.9652 - precision: 0.9652 - auc: 0.9866 - categorical_accuracy: 0.9652 - val_loss: 0.7464 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8002 - val_categorical_accuracy: 0.7100
# Epoch 106/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1683 - recall: 0.9625 - precision: 0.9625 - auc: 0.9857 - categorical_accuracy: 0.9625- ETA: 2s - loss: 0.1404 - recall: 0.9538 - precision: 0.9538 - auc: 0.9949 - c
# Epoch 00106: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 130ms/step - loss: 0.1677 - recall: 0.9627 - precision: 0.9627 - auc: 0.9857 - categorical_accuracy: 0.9627 - val_loss: 0.7463 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8003 - val_categorical_accuracy: 0.7100
# Epoch 107/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1546 - recall: 0.9450 - precision: 0.9450 - auc: 0.9888 - categorical_accuracy: 0.9450
# Epoch 00107: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1540 - recall: 0.9453 - precision: 0.9453 - auc: 0.9889 - categorical_accuracy: 0.9453 - val_loss: 0.7468 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8006 - val_categorical_accuracy: 0.7100
# Epoch 108/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1594 - recall: 0.9525 - precision: 0.9525 - auc: 0.9881 - categorical_accuracy: 0.9525
# Epoch 00108: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 125ms/step - loss: 0.1588 - recall: 0.9527 - precision: 0.9527 - auc: 0.9881 - categorical_accuracy: 0.9527 - val_loss: 0.7459 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8006 - val_categorical_accuracy: 0.7100
# Epoch 109/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1645 - recall: 0.9725 - precision: 0.9725 - auc: 0.9833 - categorical_accuracy: 0.9725
# Epoch 00109: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 130ms/step - loss: 0.1641 - recall: 0.9726 - precision: 0.9726 - auc: 0.9834 - categorical_accuracy: 0.9726 - val_loss: 0.7439 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7994 - val_categorical_accuracy: 0.7100
# Epoch 110/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1503 - recall: 0.9575 - precision: 0.9575 - auc: 0.9873 - categorical_accuracy: 0.9575
# Epoch 00110: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1497 - recall: 0.9577 - precision: 0.9577 - auc: 0.9873 - categorical_accuracy: 0.9577 - val_loss: 0.7483 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8016 - val_categorical_accuracy: 0.7100
# Epoch 111/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1810 - recall: 0.9325 - precision: 0.9325 - auc: 0.9786 - categorical_accuracy: 0.9325
# Epoch 00111: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 131ms/step - loss: 0.1803 - recall: 0.9328 - precision: 0.9328 - auc: 0.9787 - categorical_accuracy: 0.9328 - val_loss: 0.7485 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8011 - val_categorical_accuracy: 0.7100
# Epoch 112/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1734 - recall: 0.9600 - precision: 0.9600 - auc: 0.9798 - categorical_accuracy: 0.9600
# Epoch 00112: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1748 - recall: 0.9577 - precision: 0.9577 - auc: 0.9792 - categorical_accuracy: 0.9577 - val_loss: 0.7487 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8021 - val_categorical_accuracy: 0.7100
# Epoch 113/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1708 - recall: 0.9550 - precision: 0.9550 - auc: 0.9842 - categorical_accuracy: 0.9550
# Epoch 00113: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 132ms/step - loss: 0.1705 - recall: 0.9552 - precision: 0.9552 - auc: 0.9843 - categorical_accuracy: 0.9552 - val_loss: 0.7438 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7996 - val_categorical_accuracy: 0.7100
# Epoch 114/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1575 - recall: 0.9475 - precision: 0.9475 - auc: 0.9871 - categorical_accuracy: 0.9475
# Epoch 00114: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 132ms/step - loss: 0.1572 - recall: 0.9478 - precision: 0.9478 - auc: 0.9871 - categorical_accuracy: 0.9478 - val_loss: 0.7499 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8019 - val_categorical_accuracy: 0.7100
# Epoch 115/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1655 - recall: 0.9450 - precision: 0.9450 - auc: 0.9841 - categorical_accuracy: 0.9450- ETA: 3s - loss: 0.1139 - recall: 0.9429 - precision: 0.9429 - auc: 0.9957 - ca
# Epoch 00115: val_auc did not improve from 0.80260
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1650 - recall: 0.9453 - precision: 0.9453 - auc: 0.9841 - categorical_accuracy: 0.9453 - val_loss: 0.7479 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8013 - val_categorical_accuracy: 0.7100
# Epoch 116/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1325 - recall: 0.9725 - precision: 0.9725 - auc: 0.9876 - categorical_accuracy: 0.9725
# Epoch 00116: val_auc did not improve from 0.80260
# 41/41 [==============================] - 6s 136ms/step - loss: 0.1319 - recall: 0.9726 - precision: 0.9726 - auc: 0.9877 - categorical_accuracy: 0.9726 - val_loss: 0.7461 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8010 - val_categorical_accuracy: 0.7100
# Epoch 117/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1676 - recall: 0.9600 - precision: 0.9600 - auc: 0.9822 - categorical_accuracy: 0.9600
# Epoch 00117: val_auc did not improve from 0.80260
# 41/41 [==============================] - 6s 137ms/step - loss: 0.1669 - recall: 0.9602 - precision: 0.9602 - auc: 0.9823 - categorical_accuracy: 0.9602 - val_loss: 0.7474 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8008 - val_categorical_accuracy: 0.7100
# Wall time: 13min 43s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 155 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.6893972754478455
# recall: 0.7099999785423279
# precision: 0.7099999785423279
# auc: 0.8026000261306763
# categorical_accuracy: 0.7099999785423279
#
# Wall time: 25.8 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.746268656716418
# recall: 0.8064516129032258
# f1-score: 0.7751937984496124
# support: 62
#
#
# CN
# precision: 0.6363636363636364
# recall: 0.5526315789473685
# f1-score: 0.5915492957746479
# support: 38
#
#
# micro avg
# precision: 0.71
# recall: 0.71
# f1-score: 0.7100000000000001
# support: 100
#
#
# macro avg
# precision: 0.6913161465400272
# recall: 0.6795415959252971
# f1-score: 0.6833715471121302
# support: 100
#
#
# weighted avg
# precision: 0.7045047489823609
# recall: 0.71
# f1-score: 0.7054088874331259
# support: 100
#
#
# samples avg
# precision: 0.71
# recall: 0.71
# f1-score: 0.71
# support: 100
#
#
# F1
# micro: 0.7100000000000001
# macro: 0.6833715471121302
#
#
# accuracy_score: 0.71
# sensitivity_score: 0.8064516129032258
# specificity_score: 0.5526315789473685
#
#
# Wall time: 22.6 s
