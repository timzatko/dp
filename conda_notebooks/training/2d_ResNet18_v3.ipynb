# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise) + Dropout (0.5)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201216-145809
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet18'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
    'dropout': 0.5,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
    # https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 104, 128, 104)     0
# _________________________________________________________________
# my_res_net (MyResNet)        (None, 1024)              12032960
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 12,689,602
# Trainable params: 12,680,002
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201216-145809
# checkpoint dir: ../../tmp\checkpoints\20201216-145809
# log dir: ../../tmp\logs\20201216-145809
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 1.0719 - recall: 0.4677 - precision: 0.4677 - auc: 0.4584 - categorical_accuracy: 0.4677
# Epoch 00001: val_auc improved from -inf to 0.33820, saving model to ../../tmp\checkpoints\20201216-145809\cp-0001.ckpt
# 41/41 [==============================] - 6s 153ms/step - loss: 1.0719 - recall: 0.4677 - precision: 0.4677 - auc: 0.4584 - categorical_accuracy: 0.4677 - val_loss: 0.7624 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3382 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 41/41 [==============================] - ETA: 0s - loss: 0.8874 - recall: 0.4925 - precision: 0.4925 - auc: 0.5048 - categorical_accuracy: 0.4925
# Epoch 00002: val_auc improved from 0.33820 to 0.38030, saving model to ../../tmp\checkpoints\20201216-145809\cp-0002.ckpt
# 41/41 [==============================] - 6s 134ms/step - loss: 0.8874 - recall: 0.4925 - precision: 0.4925 - auc: 0.5048 - categorical_accuracy: 0.4925 - val_loss: 0.7642 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3803 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.8318 - recall: 0.5100 - precision: 0.5100 - auc: 0.5185 - categorical_accuracy: 0.5100
# Epoch 00003: val_auc did not improve from 0.38030
# 41/41 [==============================] - 5s 117ms/step - loss: 0.8310 - recall: 0.5075 - precision: 0.5075 - auc: 0.5177 - categorical_accuracy: 0.5075 - val_loss: 0.7753 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3163 - val_categorical_accuracy: 0.3800
# Epoch 4/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7361 - recall: 0.5500 - precision: 0.5500 - auc: 0.5902 - categorical_accuracy: 0.5500
# Epoch 00004: val_auc improved from 0.38030 to 0.43040, saving model to ../../tmp\checkpoints\20201216-145809\cp-0004.ckpt
# 41/41 [==============================] - 5s 133ms/step - loss: 0.7397 - recall: 0.5473 - precision: 0.5473 - auc: 0.5853 - categorical_accuracy: 0.5473 - val_loss: 0.8154 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4304 - val_categorical_accuracy: 0.3800
# Epoch 5/200
# 41/41 [==============================] - ETA: 0s - loss: 0.7365 - recall: 0.5572 - precision: 0.5572 - auc: 0.6010 - categorical_accuracy: 0.5572
# Epoch 00005: val_auc improved from 0.43040 to 0.45440, saving model to ../../tmp\checkpoints\20201216-145809\cp-0005.ckpt
# 41/41 [==============================] - 5s 130ms/step - loss: 0.7365 - recall: 0.5572 - precision: 0.5572 - auc: 0.6010 - categorical_accuracy: 0.5572 - val_loss: 0.8451 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4544 - val_categorical_accuracy: 0.3800
# Epoch 6/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6488 - recall: 0.6575 - precision: 0.6575 - auc: 0.7146 - categorical_accuracy: 0.6575
# Epoch 00006: val_auc improved from 0.45440 to 0.46960, saving model to ../../tmp\checkpoints\20201216-145809\cp-0006.ckpt
# 41/41 [==============================] - 6s 139ms/step - loss: 0.6466 - recall: 0.6592 - precision: 0.6592 - auc: 0.7166 - categorical_accuracy: 0.6592 - val_loss: 0.8323 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4696 - val_categorical_accuracy: 0.3800
# Epoch 7/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5664 - recall: 0.6750 - precision: 0.6750 - auc: 0.7740 - categorical_accuracy: 0.6750
# Epoch 00007: val_auc did not improve from 0.46960
# 41/41 [==============================] - 5s 112ms/step - loss: 0.5644 - recall: 0.6766 - precision: 0.6766 - auc: 0.7758 - categorical_accuracy: 0.6766 - val_loss: 0.7621 - val_recall: 0.3900 - val_precision: 0.3900 - val_auc: 0.4611 - val_categorical_accuracy: 0.3900
# Epoch 8/200
# 41/41 [==============================] - ETA: 0s - loss: 0.5703 - recall: 0.7438 - precision: 0.7438 - auc: 0.8061 - categorical_accuracy: 0.7438
# Epoch 00008: val_auc improved from 0.46960 to 0.59780, saving model to ../../tmp\checkpoints\20201216-145809\cp-0008.ckpt
# 41/41 [==============================] - 5s 129ms/step - loss: 0.5703 - recall: 0.7438 - precision: 0.7438 - auc: 0.8061 - categorical_accuracy: 0.7438 - val_loss: 1.9838 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.5978 - val_categorical_accuracy: 0.6200
# Epoch 9/200
# 41/41 [==============================] - ETA: 0s - loss: 0.4673 - recall: 0.7861 - precision: 0.7861 - auc: 0.8577 - categorical_accuracy: 0.7861
# Epoch 00009: val_auc did not improve from 0.59780
# 41/41 [==============================] - 5s 114ms/step - loss: 0.4673 - recall: 0.7861 - precision: 0.7861 - auc: 0.8577 - categorical_accuracy: 0.7861 - val_loss: 0.8706 - val_recall: 0.4000 - val_precision: 0.4000 - val_auc: 0.4570 - val_categorical_accuracy: 0.4000
# Epoch 10/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3346 - recall: 0.8483 - precision: 0.8483 - auc: 0.9300 - categorical_accuracy: 0.8483
# Epoch 00010: val_auc did not improve from 0.59780
# 41/41 [==============================] - 5s 122ms/step - loss: 0.3346 - recall: 0.8483 - precision: 0.8483 - auc: 0.9300 - categorical_accuracy: 0.8483 - val_loss: 0.9238 - val_recall: 0.5000 - val_precision: 0.5000 - val_auc: 0.5829 - val_categorical_accuracy: 0.5000
# Epoch 11/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4599 - recall: 0.8100 - precision: 0.8100 - auc: 0.8853 - categorical_accuracy: 0.8100
# Epoch 00011: val_auc did not improve from 0.59780
# 41/41 [==============================] - 5s 111ms/step - loss: 0.4604 - recall: 0.8085 - precision: 0.8085 - auc: 0.8846 - categorical_accuracy: 0.8085 - val_loss: 0.9036 - val_recall: 0.4800 - val_precision: 0.4800 - val_auc: 0.5161 - val_categorical_accuracy: 0.4800
# Epoch 12/200
# 41/41 [==============================] - ETA: 0s - loss: 0.3618 - recall: 0.8209 - precision: 0.8209 - auc: 0.9167 - categorical_accuracy: 0.8209- ETA: 2s - loss: 0.3889 - recall: 0.8211 - precision: 0.8211 - auc: 0.8979 - categoric
# Epoch 00012: val_auc improved from 0.59780 to 0.70050, saving model to ../../tmp\checkpoints\20201216-145809\cp-0012.ckpt
# 41/41 [==============================] - 5s 131ms/step - loss: 0.3618 - recall: 0.8209 - precision: 0.8209 - auc: 0.9167 - categorical_accuracy: 0.8209 - val_loss: 0.6559 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.7005 - val_categorical_accuracy: 0.6400
# Epoch 13/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2255 - recall: 0.9200 - precision: 0.9200 - auc: 0.9648 - categorical_accuracy: 0.9200
# Epoch 00013: val_auc did not improve from 0.70050
# 41/41 [==============================] - 4s 109ms/step - loss: 0.2247 - recall: 0.9204 - precision: 0.9204 - auc: 0.9650 - categorical_accuracy: 0.9204 - val_loss: 0.6874 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.6932 - val_categorical_accuracy: 0.6600
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2127 - recall: 0.8950 - precision: 0.8950 - auc: 0.9703 - categorical_accuracy: 0.8950
# Epoch 00014: val_auc did not improve from 0.70050
# 41/41 [==============================] - 5s 111ms/step - loss: 0.2117 - recall: 0.8955 - precision: 0.8955 - auc: 0.9706 - categorical_accuracy: 0.8955 - val_loss: 1.8316 - val_recall: 0.6500 - val_precision: 0.6500 - val_auc: 0.6930 - val_categorical_accuracy: 0.6500
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1542 - recall: 0.9375 - precision: 0.9375 - auc: 0.9838 - categorical_accuracy: 0.9375
# Epoch 00015: val_auc improved from 0.70050 to 0.75350, saving model to ../../tmp\checkpoints\20201216-145809\cp-0015.ckpt
# 41/41 [==============================] - 6s 138ms/step - loss: 0.1544 - recall: 0.9378 - precision: 0.9378 - auc: 0.9837 - categorical_accuracy: 0.9378 - val_loss: 0.9239 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7535 - val_categorical_accuracy: 0.7000
# Epoch 16/200
# 41/41 [==============================] - ETA: 0s - loss: 0.1197 - recall: 0.9527 - precision: 0.9527 - auc: 0.9910 - categorical_accuracy: 0.9527
# Epoch 00016: val_auc improved from 0.75350 to 0.83090, saving model to ../../tmp\checkpoints\20201216-145809\cp-0016.ckpt
# 41/41 [==============================] - 6s 137ms/step - loss: 0.1197 - recall: 0.9527 - precision: 0.9527 - auc: 0.9910 - categorical_accuracy: 0.9527 - val_loss: 0.7629 - val_recall: 0.7700 - val_precision: 0.7700 - val_auc: 0.8309 - val_categorical_accuracy: 0.7700
# Epoch 17/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0908 - recall: 0.9577 - precision: 0.9577 - auc: 0.9959 - categorical_accuracy: 0.9577
# Epoch 00017: val_auc did not improve from 0.83090
# 41/41 [==============================] - 5s 112ms/step - loss: 0.0908 - recall: 0.9577 - precision: 0.9577 - auc: 0.9959 - categorical_accuracy: 0.9577 - val_loss: 0.9573 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8200 - val_categorical_accuracy: 0.7200
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0601 - recall: 0.9725 - precision: 0.9725 - auc: 0.9983 - categorical_accuracy: 0.9725
# Epoch 00018: val_auc improved from 0.83090 to 0.83570, saving model to ../../tmp\checkpoints\20201216-145809\cp-0018.ckpt
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0715 - recall: 0.9701 - precision: 0.9701 - auc: 0.9947 - categorical_accuracy: 0.9701 - val_loss: 0.7879 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8357 - val_categorical_accuracy: 0.7500
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0663 - recall: 0.9800 - precision: 0.9800 - auc: 0.9971 - categorical_accuracy: 0.9800
# Epoch 00019: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0659 - recall: 0.9801 - precision: 0.9801 - auc: 0.9971 - categorical_accuracy: 0.9801 - val_loss: 1.5042 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7704 - val_categorical_accuracy: 0.6900
# Epoch 20/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0440 - recall: 0.9876 - precision: 0.9876 - auc: 0.9981 - categorical_accuracy: 0.9876
# Epoch 00020: val_auc did not improve from 0.83570
# 41/41 [==============================] - 4s 106ms/step - loss: 0.0440 - recall: 0.9876 - precision: 0.9876 - auc: 0.9981 - categorical_accuracy: 0.9876 - val_loss: 1.0302 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8309 - val_categorical_accuracy: 0.7100
# Epoch 21/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0315 - recall: 0.9900 - precision: 0.9900 - auc: 0.9998 - categorical_accuracy: 0.9900
# Epoch 00021: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 113ms/step - loss: 0.0348 - recall: 0.9876 - precision: 0.9876 - auc: 0.9996 - categorical_accuracy: 0.9876 - val_loss: 1.9470 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7469 - val_categorical_accuracy: 0.7000
# Epoch 22/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0252 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925
# Epoch 00022: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0251 - recall: 0.9925 - precision: 0.9925 - auc: 0.9999 - categorical_accuracy: 0.9925 - val_loss: 1.4549 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7897 - val_categorical_accuracy: 0.7100
# Epoch 23/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0107 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00023: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 111ms/step - loss: 0.0107 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1164 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8035 - val_categorical_accuracy: 0.7200
# Epoch 24/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0086 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00024: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 122ms/step - loss: 0.0086 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0419 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8107 - val_categorical_accuracy: 0.7300
# Epoch 25/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0058 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00025: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 112ms/step - loss: 0.0058 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0874 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.8032 - val_categorical_accuracy: 0.7100
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0054 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00026: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0053 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.1216 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7962 - val_categorical_accuracy: 0.6900
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0095 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975
# Epoch 00027: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0095 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975 - val_loss: 1.3582 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7802 - val_categorical_accuracy: 0.7300
# Epoch 28/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0182 - recall: 0.9925 - precision: 0.9925 - auc: 0.9998 - categorical_accuracy: 0.9925
# Epoch 00028: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 126ms/step - loss: 0.0182 - recall: 0.9925 - precision: 0.9925 - auc: 0.9998 - categorical_accuracy: 0.9925 - val_loss: 1.1127 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7977 - val_categorical_accuracy: 0.7200
# Epoch 29/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0146 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975
# Epoch 00029: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 115ms/step - loss: 0.0146 - recall: 0.9975 - precision: 0.9975 - auc: 0.9999 - categorical_accuracy: 0.9975 - val_loss: 1.4116 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7827 - val_categorical_accuracy: 0.7000
# Epoch 30/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0120 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950
# Epoch 00030: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0120 - recall: 0.9950 - precision: 0.9950 - auc: 1.0000 - categorical_accuracy: 0.9950 - val_loss: 1.1432 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.7749 - val_categorical_accuracy: 0.7500
# Epoch 31/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0048 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00031: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0048 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0545 - val_recall: 0.7500 - val_precision: 0.7500 - val_auc: 0.8206 - val_categorical_accuracy: 0.7500
# Epoch 32/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0023 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00032: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 115ms/step - loss: 0.0023 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.0394 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.8191 - val_categorical_accuracy: 0.7200
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0069 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975- ETA: 1s - loss: 0.0015 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_ac - ETA: 0s - loss: 0.0022 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0
# Epoch 00033: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 113ms/step - loss: 0.0069 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.1358 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7974 - val_categorical_accuracy: 0.7100
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0097 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00034: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 112ms/step - loss: 0.0096 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2973 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7983 - val_categorical_accuracy: 0.7200
# Epoch 35/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0039 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00035: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 119ms/step - loss: 0.0039 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3371 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.8000 - val_categorical_accuracy: 0.7300
# Epoch 36/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0035 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00036: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 115ms/step - loss: 0.0035 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3623 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7830 - val_categorical_accuracy: 0.7100
# Epoch 37/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0023 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000- ETA: 1s - loss: 0.0016 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accura
# Epoch 00037: val_auc did not improve from 0.83570
# 41/41 [==============================] - 4s 109ms/step - loss: 0.0023 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.3386 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7708 - val_categorical_accuracy: 0.7200
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0051 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00038: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0051 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.2917 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7677 - val_categorical_accuracy: 0.7100
# Epoch 39/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0033 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975
# Epoch 00039: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0033 - recall: 0.9975 - precision: 0.9975 - auc: 1.0000 - categorical_accuracy: 0.9975 - val_loss: 1.2482 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7808 - val_categorical_accuracy: 0.7300
# Epoch 40/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0017 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00040: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0017 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2482 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7844 - val_categorical_accuracy: 0.7400
# Epoch 41/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.0018 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00041: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0018 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2618 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7853 - val_categorical_accuracy: 0.7400
# Epoch 42/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0018 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00042: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 112ms/step - loss: 0.0018 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2823 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7858 - val_categorical_accuracy: 0.7400
# Epoch 43/200
# 41/41 [==============================] - ETA: 0s - loss: 0.0019 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000
# Epoch 00043: val_auc did not improve from 0.83570
# 41/41 [==============================] - 5s 115ms/step - loss: 0.0019 - recall: 1.0000 - precision: 1.0000 - auc: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 1.2959 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7920 - val_categorical_accuracy: 0.7300
# Wall time: 4min 44s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 143 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.6795288324356079
# recall: 0.75
# precision: 0.75
# auc: 0.8357000350952148
# categorical_accuracy: 0.75
#
# Wall time: 25.1 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.7605633802816901
# recall: 0.8709677419354839
# f1-score: 0.8120300751879699
# support: 62
#
#
# CN
# precision: 0.7241379310344828
# recall: 0.5526315789473685
# f1-score: 0.6268656716417911
# support: 38
#
#
# micro avg
# precision: 0.75
# recall: 0.75
# f1-score: 0.75
# support: 100
#
#
# macro avg
# precision: 0.7423506556580864
# recall: 0.7117996604414262
# f1-score: 0.7194478734148805
# support: 100
#
#
# weighted avg
# precision: 0.7467217095677513
# recall: 0.75
# f1-score: 0.7416676018404219
# support: 100
#
#
# samples avg
# precision: 0.75
# recall: 0.75
# f1-score: 0.75
# support: 100
#
#
# F1
# micro: 0.75
# macro: 0.7194478734148805
#
#
# accuracy_score: 0.75
# sensitivity_score: 0.8709677419354839
# specificity_score: 0.5526315789473685
#
#
# Wall time: 22.3 s
