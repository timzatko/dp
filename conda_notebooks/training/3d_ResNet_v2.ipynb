# %% [markdown]
# # 3D ResNet

# %% [markdown]
# Basic + Augmentations (invert, rotate, zoom, blur, noise)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')

import datetime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np

from src.data import train_test_split, MRISequence
from src.model import create_model, compile_model, load_checkpoint
from src.model.training import train
from src.model.evaluation import plot_training_history, show_simple_metrics, show_metrics

# %%
import tensorflow as tf

RANDOM_SEED = 792379571013149
tf.random.set_seed(RANDOM_SEED)

print(tf.version.VERSION)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.3.1
# Num GPUs Available:  1

# %% [markdown]
# ## Setup

# %%
# %%time

ROOT_DIR = '../../tmp'
DEFAULT_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'checkpoints')
DEFAULT_BCKP_CHECKPOINT_DIRECTORY_LOCAL = os.path.join(ROOT_DIR, 'bckp-checkpoints')

LOG_DIRECTORY = os.path.join(ROOT_DIR, 'logs')
CHECKPOINT_DIRECTORY = DEFAULT_CHECKPOINT_DIRECTORY_LOCAL

LOG_DIRECTORY_LOCAL = LOG_DIRECTORY
CHECKPOINT_DIRECTORY_LOCAL = CHECKPOINT_DIRECTORY

DATA_DIR_NAME = 'data-v3'
DATA_DIR = os.path.join(ROOT_DIR, DATA_DIR_NAME)

saliencies_and_segmentations_v2_path = os.path.join(ROOT_DIR, 'saliencies_and_segmentations_v2')

if not os.path.exists(CHECKPOINT_DIRECTORY):
    os.mkdir(CHECKPOINT_DIRECTORY)

if not os.path.exists(LOG_DIRECTORY):
    os.mkdir(LOG_DIRECTORY)

val = False
    
class_names = ['AD', 'CN']

# get paths to data
train_dir, test_dir, val_dir = train_test_split(
    saliencies_and_segmentations_v2_path, 
    ROOT_DIR, 
    split=(0.8, 0.15, 0.05), 
    dirname=DATA_DIR_NAME)

# set the batch size for mri seq
batch_size = 12
input_shape = (104, 128, 104, 1) # (112, 112, 105, 1)
resize_img = True
crop_img = True

# if y is one-hot encoded or just scalar number
one_hot = True

# class weights (see analysis notebook)
class_weights = {0: 0.8072289156626505, 1: 1.3137254901960784}

# description statistics of the dataset
desc = {'mean': -3.6344006e-09, 'std': 1.0000092, 'min': -1.4982183, 'max': 10.744175}

if 'desc' not in locals():
    print('initializing desc...')
    desc = get_description(MRISequence(
        train_dir,
        64,
        class_names=class_names,
        input_shape=input_shape),
        max_samples=None)
    print(desc)


normalization={ 'type':'normalization', 'desc': desc }
# normalization={'type':'standardization', 'desc':desc }

augmentations = None
augmentations_inplace = True
# enable augmentations in mri seq (otherwise it can be enabled in dataset)
# augmentations={ 'random_swap_hemispheres': 0.5 }

# initialize sequences
print('initializing train_seq...')
train_seq = MRISequence(
    train_dir,
    batch_size,
    class_names=class_names,
    augmentations=augmentations,
    augmentations_inplace=augmentations_inplace,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    class_weights=class_weights,
    normalization=normalization)

print('initializing test_seq...')
test_seq = MRISequence(
    test_dir,
    batch_size,
    class_names=class_names,
    input_shape=input_shape,
    resize_img=resize_img,
    crop_img=crop_img,
    one_hot=one_hot,
    normalization=normalization)

if val:
    print('initializing val_seq...')
    val_seq = MRISequence(
        val_dir,
        batch_size,
        class_names=class_names,
        input_shape=input_shape,
        resize_img=resize_img,
        crop_img=crop_img,
        one_hot=one_hot,
        class_weights=class_weights,
        normalization=normalization)
else:
    print('val_seq = test_seq')
    val_seq = test_seq
    
model_key = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = os.path.join(LOG_DIRECTORY, model_key)
print(f'log_dir: {log_dir}')
# Out:
# not copying files since the destination directory already exists
# initializing train_seq...
# initializing test_seq...
# val_seq = test_seq
# log_dir: ../../tmp\logs\20201216-154558
# Wall time: 5 ms

# %%
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#class_weights
# pos / neg
initial_bias = np.log([159/243, 243/159])

model_type = 'ResNet50V2'
model_config = {
    'input_shape': input_shape,
    'class_names': class_names,
#     'l2_beta': 0.001,
#     'l2_beta': 0.0005,
#     'l2_beta': None,
#     'dropout': 0.10,
#     'dropout': None,
    'output_bias': initial_bias,
#     'output_bias': None,
}

compile_config = {
    # default is 0.001
#     'learning_rate': 0.000075,
    'learning_rate': 0.00025,
    'decay_steps': 25,
    'decay_rate': 0.96,
#     'beta_1': 0.85,
    'beta_1': 0.90,
#     'beta_2': 0.990,
    'beta_2': 0.999,
}

train_config = {
    'model_key': model_key,
    'epochs': 200,
    'patience': 25,
    'tensorboard_update_freq': 'epoch',
    'mri_tensorboard_callback': False,
    'model_checkpoint_callback': {'monitor': 'val_auc', 'mode': 'max', 'save_best_only': True},
    'early_stopping_monitor': {'monitor': 'val_auc', 'mode': 'max'},
    'augmentations': {
        'invert': (0.5, None),
        'rotate': (0.2, 5), # probability, degrees
        'zoom': (0.2, 0.015),
        'shear': (0, 2.5), # probability, degrees
        'blur': (0.2, 0.8),
        'noise': (0.2, 0.00025)
    },
#     'augmentations': False,
    'batch_size': 10,
#     'model_checkpoint_callback': False,
}

# %% [markdown]
# ## Train

# %%
model = create_model(model_type, model_config)
model, *_ = compile_model(model, **compile_config)
model.build(input_shape=input_shape)
model.summary()
# Out:
# C:\Users\xzatko\anaconda3\envs\dp-timzatko\lib\site-packages\tensorflow\python\keras\applications\imagenet_utils.py:333: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 104 input channels.
#   str(input_shape[-1]) + ' input channels.')
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 1024)              25979712
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 26,636,354
# Trainable params: 26,590,914
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
# load_checkpoint(model, DEFAULT_CHECKPOINT_DIRECTORY_LOCAL, '20201213-182225', 'cp-0002.ckpt')

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# %%time

model, checkpoint_dir, history = train(
    model,
    train_seq,
    test_seq,
    CHECKPOINT_DIRECTORY,
    LOG_DIRECTORY,
    DATA_DIR,
    **train_config
)
# Out:
# model key: 20201216-154558
# checkpoint dir: ../../tmp\checkpoints\20201216-154558
# log dir: ../../tmp\logs\20201216-154558
# loading ../../tmp\data-v3\train_x.npy, ../../tmp\data-v3\train_y.npy...
# loading ../../tmp\data-v3\val_x.npy, ../../tmp\data-v3\val_y.npy...
# training...
# Epoch 1/200
# 41/41 [==============================] - ETA: 0s - loss: 0.7490 - recall: 0.3806 - precision: 0.3806 - auc: 0.3528 - categorical_accuracy: 0.3806
# Epoch 00001: val_auc improved from -inf to 0.38000, saving model to ../../tmp\checkpoints\20201216-154558\cp-0001.ckpt
# 41/41 [==============================] - 8s 205ms/step - loss: 0.7490 - recall: 0.3806 - precision: 0.3806 - auc: 0.3528 - categorical_accuracy: 0.3806 - val_loss: 0.7223 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.3800 - val_categorical_accuracy: 0.3800
# Epoch 2/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.7042 - recall: 0.4050 - precision: 0.4050 - auc: 0.3663 - categorical_accuracy: 0.4050
# Epoch 00002: val_auc improved from 0.38000 to 0.40800, saving model to ../../tmp\checkpoints\20201216-154558\cp-0002.ckpt
# 41/41 [==============================] - 6s 152ms/step - loss: 0.7035 - recall: 0.4030 - precision: 0.4030 - auc: 0.3655 - categorical_accuracy: 0.4030 - val_loss: 0.6984 - val_recall: 0.3800 - val_precision: 0.3800 - val_auc: 0.4080 - val_categorical_accuracy: 0.3800
# Epoch 3/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6951 - recall: 0.5025 - precision: 0.5025 - auc: 0.5242 - categorical_accuracy: 0.5025
# Epoch 00003: val_auc improved from 0.40800 to 0.62000, saving model to ../../tmp\checkpoints\20201216-154558\cp-0003.ckpt
# 41/41 [==============================] - 6s 155ms/step - loss: 0.6945 - recall: 0.5025 - precision: 0.5025 - auc: 0.5238 - categorical_accuracy: 0.5025 - val_loss: 0.6981 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6200 - val_categorical_accuracy: 0.6200
# Epoch 4/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6907 - recall: 0.5475 - precision: 0.5475 - auc: 0.5704 - categorical_accuracy: 0.5475- ETA: 2s - loss: 0.6750 - recall: 0.5111 - precision: 0.5111 - auc: 0.5366 - catego
# Epoch 00004: val_auc did not improve from 0.62000
# 41/41 [==============================] - 5s 121ms/step - loss: 0.6899 - recall: 0.5473 - precision: 0.5473 - auc: 0.5707 - categorical_accuracy: 0.5473 - val_loss: 0.7139 - val_recall: 0.5400 - val_precision: 0.5400 - val_auc: 0.5878 - val_categorical_accuracy: 0.5400
# Epoch 5/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6895 - recall: 0.5175 - precision: 0.5175 - auc: 0.5647 - categorical_accuracy: 0.5175
# Epoch 00005: val_auc did not improve from 0.62000
# 41/41 [==============================] - 5s 118ms/step - loss: 0.6887 - recall: 0.5174 - precision: 0.5174 - auc: 0.5659 - categorical_accuracy: 0.5174 - val_loss: 0.7023 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6200 - val_categorical_accuracy: 0.6200
# Epoch 6/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6752 - recall: 0.5900 - precision: 0.5900 - auc: 0.6384 - categorical_accuracy: 0.5900
# Epoch 00006: val_auc did not improve from 0.62000
# 41/41 [==============================] - 5s 117ms/step - loss: 0.6744 - recall: 0.5896 - precision: 0.5896 - auc: 0.6391 - categorical_accuracy: 0.5896 - val_loss: 0.7025 - val_recall: 0.4900 - val_precision: 0.4900 - val_auc: 0.5236 - val_categorical_accuracy: 0.4900
# Epoch 7/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6697 - recall: 0.5900 - precision: 0.5900 - auc: 0.6376 - categorical_accuracy: 0.5900
# Epoch 00007: val_auc did not improve from 0.62000
# 41/41 [==============================] - 5s 115ms/step - loss: 0.6683 - recall: 0.5920 - precision: 0.5920 - auc: 0.6405 - categorical_accuracy: 0.5920 - val_loss: 0.6775 - val_recall: 0.5400 - val_precision: 0.5400 - val_auc: 0.5369 - val_categorical_accuracy: 0.5400
# Epoch 8/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6425 - recall: 0.6625 - precision: 0.6625 - auc: 0.7076 - categorical_accuracy: 0.6625- ETA: 2s - loss: 0.5629 - recall: 0.7000 - precision: 0.7000 - auc:
# Epoch 00008: val_auc improved from 0.62000 to 0.63140, saving model to ../../tmp\checkpoints\20201216-154558\cp-0008.ckpt
# 41/41 [==============================] - 7s 162ms/step - loss: 0.6411 - recall: 0.6642 - precision: 0.6642 - auc: 0.7093 - categorical_accuracy: 0.6642 - val_loss: 0.7098 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6314 - val_categorical_accuracy: 0.6200
# Epoch 9/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6594 - recall: 0.6200 - precision: 0.6200 - auc: 0.6600 - categorical_accuracy: 0.6200
# Epoch 00009: val_auc did not improve from 0.63140
# 41/41 [==============================] - 5s 122ms/step - loss: 0.6590 - recall: 0.6194 - precision: 0.6194 - auc: 0.6596 - categorical_accuracy: 0.6194 - val_loss: 0.7525 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6200 - val_categorical_accuracy: 0.6200
# Epoch 10/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6413 - recall: 0.6625 - precision: 0.6625 - auc: 0.6970 - categorical_accuracy: 0.6625
# Epoch 00010: val_auc did not improve from 0.63140
# 41/41 [==============================] - 6s 136ms/step - loss: 0.6408 - recall: 0.6617 - precision: 0.6617 - auc: 0.6976 - categorical_accuracy: 0.6617 - val_loss: 0.7693 - val_recall: 0.6200 - val_precision: 0.6200 - val_auc: 0.6200 - val_categorical_accuracy: 0.6200
# Epoch 11/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.6047 - recall: 0.7300 - precision: 0.7300 - auc: 0.7626 - categorical_accuracy: 0.7300- ETA: 1s - loss: 0.6028 - recall: 0.7276 - precision: 0.7276 - auc: 0.7654 - categorical_accur
# Epoch 00011: val_auc did not improve from 0.63140
# 41/41 [==============================] - 5s 127ms/step - loss: 0.6033 - recall: 0.7313 - precision: 0.7313 - auc: 0.7642 - categorical_accuracy: 0.7313 - val_loss: 0.7589 - val_recall: 0.5500 - val_precision: 0.5500 - val_auc: 0.5708 - val_categorical_accuracy: 0.5500
# Epoch 12/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5614 - recall: 0.7550 - precision: 0.7550 - auc: 0.7930 - categorical_accuracy: 0.7550- ETA: 2s - loss: 0.5227 - recall: 0.7875 - precision: 0.7875 - auc: 0.8431 - categorical_accuracy:  - ETA: 2s - loss: 0.5340 - recall: 0.7636 - precision: 0.7636 - auc: 0.8216 - categorica
# Epoch 00012: val_auc did not improve from 0.63140
# 41/41 [==============================] - 5s 124ms/step - loss: 0.5599 - recall: 0.7562 - precision: 0.7562 - auc: 0.7944 - categorical_accuracy: 0.7562 - val_loss: 0.8203 - val_recall: 0.5100 - val_precision: 0.5100 - val_auc: 0.5323 - val_categorical_accuracy: 0.5100
# Epoch 13/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5731 - recall: 0.7350 - precision: 0.7350 - auc: 0.7896 - categorical_accuracy: 0.7350
# Epoch 00013: val_auc did not improve from 0.63140
# 41/41 [==============================] - 5s 124ms/step - loss: 0.5721 - recall: 0.7363 - precision: 0.7363 - auc: 0.7903 - categorical_accuracy: 0.7363 - val_loss: 0.8274 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.6086 - val_categorical_accuracy: 0.6100
# Epoch 14/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.5214 - recall: 0.7800 - precision: 0.7800 - auc: 0.8415 - categorical_accuracy: 0.7800
# Epoch 00014: val_auc did not improve from 0.63140
# 41/41 [==============================] - 5s 120ms/step - loss: 0.5198 - recall: 0.7811 - precision: 0.7811 - auc: 0.8428 - categorical_accuracy: 0.7811 - val_loss: 0.7773 - val_recall: 0.5900 - val_precision: 0.5900 - val_auc: 0.6139 - val_categorical_accuracy: 0.5900
# Epoch 15/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4663 - recall: 0.8025 - precision: 0.8025 - auc: 0.8787 - categorical_accuracy: 0.8025
# Epoch 00015: val_auc improved from 0.63140 to 0.71440, saving model to ../../tmp\checkpoints\20201216-154558\cp-0015.ckpt
# 41/41 [==============================] - 7s 159ms/step - loss: 0.4649 - recall: 0.8035 - precision: 0.8035 - auc: 0.8795 - categorical_accuracy: 0.8035 - val_loss: 0.7028 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7144 - val_categorical_accuracy: 0.6600
# Epoch 16/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.4142 - recall: 0.8375 - precision: 0.8375 - auc: 0.8935 - categorical_accuracy: 0.8375- ETA: 3s - loss: 0.4785 - recall: 0.7900 - precision: 0.7900 - auc: 0.8325
# Epoch 00016: val_auc improved from 0.71440 to 0.77540, saving model to ../../tmp\checkpoints\20201216-154558\cp-0016.ckpt
# 41/41 [==============================] - 6s 158ms/step - loss: 0.4129 - recall: 0.8383 - precision: 0.8383 - auc: 0.8942 - categorical_accuracy: 0.8383 - val_loss: 0.6556 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7754 - val_categorical_accuracy: 0.6900
# Epoch 17/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3285 - recall: 0.8825 - precision: 0.8825 - auc: 0.9345 - categorical_accuracy: 0.8825
# Epoch 00017: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 117ms/step - loss: 0.3274 - recall: 0.8831 - precision: 0.8831 - auc: 0.9349 - categorical_accuracy: 0.8831 - val_loss: 0.8052 - val_recall: 0.5800 - val_precision: 0.5800 - val_auc: 0.6734 - val_categorical_accuracy: 0.5800
# Epoch 18/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.3236 - recall: 0.8825 - precision: 0.8825 - auc: 0.9385 - categorical_accuracy: 0.8825- ETA: 1s - loss: 0.2785 - recall: 0.9000 - precision: 0.9000 - auc: 0.9436 - categorical
# Epoch 00018: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 121ms/step - loss: 0.3225 - recall: 0.8831 - precision: 0.8831 - auc: 0.9388 - categorical_accuracy: 0.8831 - val_loss: 0.8473 - val_recall: 0.6000 - val_precision: 0.6000 - val_auc: 0.6822 - val_categorical_accuracy: 0.6000
# Epoch 19/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2929 - recall: 0.9000 - precision: 0.9000 - auc: 0.9415 - categorical_accuracy: 0.9000- ETA: 1s - loss: 0.2875 - recall: 0.9000 - precision: 0.9000 - auc: 0.9436 - categorical_accu
# Epoch 00019: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 115ms/step - loss: 0.2920 - recall: 0.9005 - precision: 0.9005 - auc: 0.9417 - categorical_accuracy: 0.9005 - val_loss: 0.8011 - val_recall: 0.6600 - val_precision: 0.6600 - val_auc: 0.7011 - val_categorical_accuracy: 0.6600
# Epoch 20/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2484 - recall: 0.9200 - precision: 0.9200 - auc: 0.9572 - categorical_accuracy: 0.9200
# Epoch 00020: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 121ms/step - loss: 0.2477 - recall: 0.9204 - precision: 0.9204 - auc: 0.9573 - categorical_accuracy: 0.9204 - val_loss: 0.8280 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6753 - val_categorical_accuracy: 0.6400
# Epoch 21/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2295 - recall: 0.9275 - precision: 0.9275 - auc: 0.9667 - categorical_accuracy: 0.9275
# Epoch 00021: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 127ms/step - loss: 0.2289 - recall: 0.9279 - precision: 0.9279 - auc: 0.9668 - categorical_accuracy: 0.9279 - val_loss: 0.7330 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7685 - val_categorical_accuracy: 0.6900
# Epoch 22/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2129 - recall: 0.9400 - precision: 0.9400 - auc: 0.9712 - categorical_accuracy: 0.9400
# Epoch 00022: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 123ms/step - loss: 0.2124 - recall: 0.9403 - precision: 0.9403 - auc: 0.9712 - categorical_accuracy: 0.9403 - val_loss: 0.7830 - val_recall: 0.6100 - val_precision: 0.6100 - val_auc: 0.7186 - val_categorical_accuracy: 0.6100
# Epoch 23/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.2121 - recall: 0.9400 - precision: 0.9400 - auc: 0.9667 - categorical_accuracy: 0.9400
# Epoch 00023: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2116 - recall: 0.9403 - precision: 0.9403 - auc: 0.9667 - categorical_accuracy: 0.9403 - val_loss: 0.7462 - val_recall: 0.6700 - val_precision: 0.6700 - val_auc: 0.7557 - val_categorical_accuracy: 0.6700
# Epoch 24/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1681 - recall: 0.9550 - precision: 0.9550 - auc: 0.9810 - categorical_accuracy: 0.9550
# Epoch 00024: val_auc did not improve from 0.77540
# 41/41 [==============================] - 6s 139ms/step - loss: 0.1678 - recall: 0.9552 - precision: 0.9552 - auc: 0.9810 - categorical_accuracy: 0.9552 - val_loss: 0.8869 - val_recall: 0.6400 - val_precision: 0.6400 - val_auc: 0.6992 - val_categorical_accuracy: 0.6400
# Epoch 25/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1653 - recall: 0.9500 - precision: 0.9500 - auc: 0.9826 - categorical_accuracy: 0.9500- ETA: 0s - loss: 0.1516 - recall: 0.9548 - precision: 0.9548 - auc: 0.9840 - categorical_accurac
# Epoch 00025: val_auc did not improve from 0.77540
# 41/41 [==============================] - 4s 109ms/step - loss: 0.1650 - recall: 0.9502 - precision: 0.9502 - auc: 0.9825 - categorical_accuracy: 0.9502 - val_loss: 0.8276 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7428 - val_categorical_accuracy: 0.7100
# Epoch 26/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1575 - recall: 0.9575 - precision: 0.9575 - auc: 0.9820 - categorical_accuracy: 0.9575
# Epoch 00026: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1572 - recall: 0.9577 - precision: 0.9577 - auc: 0.9820 - categorical_accuracy: 0.9577 - val_loss: 0.7818 - val_recall: 0.6900 - val_precision: 0.6900 - val_auc: 0.7627 - val_categorical_accuracy: 0.6900
# Epoch 27/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1516 - recall: 0.9600 - precision: 0.9600 - auc: 0.9827 - categorical_accuracy: 0.9600
# Epoch 00027: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1514 - recall: 0.9602 - precision: 0.9602 - auc: 0.9827 - categorical_accuracy: 0.9602 - val_loss: 0.8449 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7592 - val_categorical_accuracy: 0.7400
# Epoch 28/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1390 - recall: 0.9625 - precision: 0.9625 - auc: 0.9855 - categorical_accuracy: 0.9625
# Epoch 00028: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 130ms/step - loss: 0.1388 - recall: 0.9627 - precision: 0.9627 - auc: 0.9854 - categorical_accuracy: 0.9627 - val_loss: 0.8880 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7469 - val_categorical_accuracy: 0.7300
# Epoch 29/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1329 - recall: 0.9650 - precision: 0.9650 - auc: 0.9861 - categorical_accuracy: 0.9650
# Epoch 00029: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1328 - recall: 0.9652 - precision: 0.9652 - auc: 0.9860 - categorical_accuracy: 0.9652 - val_loss: 0.9082 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7516 - val_categorical_accuracy: 0.7200
# Epoch 30/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1589 - recall: 0.9525 - precision: 0.9525 - auc: 0.9817 - categorical_accuracy: 0.9525
# Epoch 00030: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 122ms/step - loss: 0.1587 - recall: 0.9527 - precision: 0.9527 - auc: 0.9816 - categorical_accuracy: 0.9527 - val_loss: 0.8550 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7694 - val_categorical_accuracy: 0.7200
# Epoch 31/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1359 - recall: 0.9650 - precision: 0.9650 - auc: 0.9891 - categorical_accuracy: 0.9650
# Epoch 00031: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1357 - recall: 0.9652 - precision: 0.9652 - auc: 0.9891 - categorical_accuracy: 0.9652 - val_loss: 0.8298 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7659 - val_categorical_accuracy: 0.7200
# Epoch 32/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1399 - recall: 0.9600 - precision: 0.9600 - auc: 0.9887 - categorical_accuracy: 0.9600
# Epoch 00032: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1398 - recall: 0.9602 - precision: 0.9602 - auc: 0.9886 - categorical_accuracy: 0.9602 - val_loss: 0.9161 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7539 - val_categorical_accuracy: 0.7200
# Epoch 33/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1197 - recall: 0.9675 - precision: 0.9675 - auc: 0.9905 - categorical_accuracy: 0.9675
# Epoch 00033: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 119ms/step - loss: 0.1197 - recall: 0.9677 - precision: 0.9677 - auc: 0.9904 - categorical_accuracy: 0.9677 - val_loss: 0.9784 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7379 - val_categorical_accuracy: 0.7200
# Epoch 34/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1284 - recall: 0.9650 - precision: 0.9650 - auc: 0.9892 - categorical_accuracy: 0.9650
# Epoch 00034: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1283 - recall: 0.9652 - precision: 0.9652 - auc: 0.9892 - categorical_accuracy: 0.9652 - val_loss: 0.9611 - val_recall: 0.7000 - val_precision: 0.7000 - val_auc: 0.7563 - val_categorical_accuracy: 0.7000
# Epoch 35/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1176 - recall: 0.9700 - precision: 0.9700 - auc: 0.9894 - categorical_accuracy: 0.9700- ETA: 0s - loss: 0.1047 - recall: 0.9737 - precision: 0.9737 - auc: 0.9917 - categorical_accuracy: 0.97
# Epoch 00035: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 123ms/step - loss: 0.1176 - recall: 0.9701 - precision: 0.9701 - auc: 0.9894 - categorical_accuracy: 0.9701 - val_loss: 0.9261 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7605 - val_categorical_accuracy: 0.7100
# Epoch 36/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1217 - recall: 0.9650 - precision: 0.9650 - auc: 0.9908 - categorical_accuracy: 0.9650
# Epoch 00036: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 118ms/step - loss: 0.1217 - recall: 0.9652 - precision: 0.9652 - auc: 0.9907 - categorical_accuracy: 0.9652 - val_loss: 0.9552 - val_recall: 0.7100 - val_precision: 0.7100 - val_auc: 0.7486 - val_categorical_accuracy: 0.7100
# Epoch 37/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1189 - recall: 0.9650 - precision: 0.9650 - auc: 0.9904 - categorical_accuracy: 0.9650
# Epoch 00037: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 118ms/step - loss: 0.1189 - recall: 0.9652 - precision: 0.9652 - auc: 0.9903 - categorical_accuracy: 0.9652 - val_loss: 0.8995 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7685 - val_categorical_accuracy: 0.7200
# Epoch 38/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1064 - recall: 0.9725 - precision: 0.9725 - auc: 0.9915 - categorical_accuracy: 0.9725
# Epoch 00038: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 115ms/step - loss: 0.1065 - recall: 0.9726 - precision: 0.9726 - auc: 0.9915 - categorical_accuracy: 0.9726 - val_loss: 0.9159 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7675 - val_categorical_accuracy: 0.7200
# Epoch 39/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1053 - recall: 0.9725 - precision: 0.9725 - auc: 0.9917 - categorical_accuracy: 0.9725
# Epoch 00039: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 121ms/step - loss: 0.1054 - recall: 0.9726 - precision: 0.9726 - auc: 0.9916 - categorical_accuracy: 0.9726 - val_loss: 0.9178 - val_recall: 0.7400 - val_precision: 0.7400 - val_auc: 0.7694 - val_categorical_accuracy: 0.7400
# Epoch 40/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1041 - recall: 0.9725 - precision: 0.9725 - auc: 0.9923 - categorical_accuracy: 0.9725
# Epoch 00040: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 124ms/step - loss: 0.1042 - recall: 0.9726 - precision: 0.9726 - auc: 0.9922 - categorical_accuracy: 0.9726 - val_loss: 0.9299 - val_recall: 0.7300 - val_precision: 0.7300 - val_auc: 0.7596 - val_categorical_accuracy: 0.7300
# Epoch 41/200
# 40/41 [============================>.] - ETA: 0s - loss: 0.1031 - recall: 0.9725 - precision: 0.9725 - auc: 0.9921 - categorical_accuracy: 0.9725
# Epoch 00041: val_auc did not improve from 0.77540
# 41/41 [==============================] - 5s 134ms/step - loss: 0.1032 - recall: 0.9726 - precision: 0.9726 - auc: 0.9920 - categorical_accuracy: 0.9726 - val_loss: 0.9432 - val_recall: 0.7200 - val_precision: 0.7200 - val_auc: 0.7607 - val_categorical_accuracy: 0.7200
# Wall time: 4min 51s

# %% [markdown]
# ## Evaluation

# %%
# %%time

plot_training_history(history)
# Out:
# Wall time: 137 ms

# %%
# %%time

show_simple_metrics(model, test_seq)
# Out:
# loss: 0.6423198580741882
# recall: 0.6899999976158142
# precision: 0.6899999976158142
# auc: 0.7753999829292297
# categorical_accuracy: 0.6899999976158142
#
# Wall time: 25.9 s

# %%
# %%time

show_metrics(model, test_seq, class_names)
# Out:
# In binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”. (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
# AD
# precision: 0.7719298245614035
# recall: 0.7096774193548387
# f1-score: 0.7394957983193277
# support: 62
#
#
# CN
# precision: 0.5813953488372093
# recall: 0.6578947368421053
# f1-score: 0.6172839506172839
# support: 38
#
#
# micro avg
# precision: 0.69
# recall: 0.69
# f1-score: 0.69
# support: 100
#
#
# macro avg
# precision: 0.6766625866993063
# recall: 0.683786078098472
# f1-score: 0.6783898744683058
# support: 100
#
#
# weighted avg
# precision: 0.6995267237862097
# recall: 0.69
# f1-score: 0.693055296192551
# support: 100
#
#
# samples avg
# precision: 0.69
# recall: 0.69
# f1-score: 0.69
# support: 100
#
#
# F1
# micro: 0.69
# macro: 0.6783898744683058
#
#
# accuracy_score: 0.69
# sensitivity_score: 0.7096774193548387
# specificity_score: 0.6578947368421053
#
#
# Wall time: 22.5 s
